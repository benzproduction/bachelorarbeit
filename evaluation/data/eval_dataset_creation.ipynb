# %% [markdown]
# # Creation of the evaluation datasets
#
# Creates:
# - eval_retriever_dataset.jsonl
#   ```jsonl
#   {
#     "category": "CATEGORY",
#     "input": {
#       "question": "QUESTION",
#     }
#     "ideal": {
#       "paragraph": ["LIST OF RELEVANT SENTENCES OR PARAGRAPHS"],
#       "filename": ["LIST OF SOURCE FILENAMES"],
#       "ids":["LIST OF TEXT CHUNK IDS"]
#     }
#   }
#   ```
# - eval_generator_dataset.jsonl
#   ```jsonl
#   {
#     "category": "CATEGORY",
#     "input": {
#       "question": "QUESTION",
#       "sources": ["LIST OF RELEVANT SENTENCES OR PARAGRAPHS"]
#     }
#     "ideal": {
#       "answer": "GOLDEN ANSWER",
#       "sentences": ["LIST OF RELEVANT SENTENCES"],
#     }
#   }
#   ```
# - eval_e2e_dataset.jsonl
#   ```jsonl
#   {
#     "category": "CATEGORY",
#     "input": {
#       "question": "QUESTION",
#     }
#     "ideal": {
#       "answer": "GOLDEN ANSWER",
#     }
#   }
#   ```
#
# Each datasets includes 4 categories of questions:
# 1. Same Wording & One paragraph
# 2. Same Wording & multiple paragraphs
# 3. Different wording & one paragraph
# 4. Different wording & multiple paragraphs
# 5. No answer (only for generator & e2e)
#
#
# Starting point is the text chunk csv file where each text chunk is considered as a paragraph.

# %%
from helpers import get_env
import openai


API_KEY, RESOURCE_ENDPOINT = get_env("azure-openai")

openai.api_type = "azure"
openai.api_key = API_KEY
openai.api_base = RESOURCE_ENDPOINT
openai.api_version = "2022-12-01"

# %%
import pandas as pd
import numpy as np

def str_to_array_converter(string):
    # Remove leading/trailing brackets and split the string by commas
    elements = string[1:-1].split(',')
    # Convert each element to float32 and create a numpy array
    array = np.array(elements, dtype=np.float32)
    return array

textchunks_df = pd.read_csv("evaluation/data/chunks.csv", converters={"embedding": str_to_array_converter})
textchunks_df = textchunks_df[textchunks_df["text"].notna()]
# sample a random row
sample = textchunks_df.sample()
sample_text = sample["text"].values[0]
sample_text
# Out:
# ' A catchment area of 2.4 million potential customers and a large volume of day-trippers from the Benelux countries are an at- tractive prospect for retailers. However, tourism was not quite as important before Covid as in other top locations. Spending power is also moderate for a top location at 104 points. Unlike Dsseldorf with its distinctive luxury segment, Cologne city centre is focused on lower-end retail. A three kilometre shopping circuit encourages a stroll through prime locations and boosts footfall. One particular example is Schildergasse, the location for many chain store branches. Footfall is also high in Hohe Strae, but below the high levels of Schildergasse. Conversely, Ehrenstrae is a trendy location. A smaller luxury segment has become established in the DomklosterWallrafplatz area. The consequences of the pandemic have clearly had an impact on Cologne ci- ty centre. Between 2019 and the end of 2021 prime rents fell by 12 per cent to EUR 225 per m2, a level which has since been maintained. The rate of decline is on a par with the trend in the top locations, and the relatively large supply of sales space in Cologne city centre has not therefore had any further negative impact on the rent trend. No new information is available on plans announced in spring 2022 to demo- lish the building where the Galeria branch is located in Breiten Strae. COLOGNE: SPACE RENTAL IN CITY CENTRE LOCATIONS IN M 25,000 20,000 15,000 10,000 5,000 0 COLOGNE: MONTHLY TOURISM STATISTICS NO.'

# %%
sample
# Out:
#                                                    key  \
# 284  real_estate_index:Emerging-Trends_USCanada-202...
#
#                                                   text  \
# 284   That said, I think there is greater clarity i...
#
#                                              embedding  \
# 284  [0.011118177, -0.007156606, -0.0028066784, -0....
#
#                               filename  page
# 284  Emerging-Trends_USCanada-2023.pdf    70

# %%
prompt = """You are generating 5 factoid question answer pairs for a given text.
[BEGIN DATA]
************
[Text]: {text}
************
[END DATA]
The questions should have the same wording as the given text.
Please format your answer in the following format: [Question]: [Answer]; [Question]: [Answer]; [Question]: [Answer]; [Question]: [Answer]; [Question]: [Answer]
"""
prompt = prompt.format(text=sample_text)
print(prompt)
# Out:
# You are generating 5 factoid question answer pairs for a given text.
# [BEGIN DATA]
# ************
# [Text]:  This is understandable from the sellers perspective, since the modest in- crease in rental yields from their previously low levels has led to visibly low purchase prices. We expect the buyers and sellers sides to converge in the months ahead, causing investment volume to pick up again. Given that bond yields remain low, real estate remains an alternative worth considering, especially as the inflation-indexed commercial leases lead to rising rental income, which has a positive impact on achievable yields and thus also on purchase prices. The higher financing costs give equity-rich investors an advantage. RETAIL: TREND IN INITIAL RENTAL YIELDS NET INITIAL YIELD IN CENTRAL RETAIL LOCATIONS IN 7.0 6.5 6.0 5.5 5.0 4.5 4.0 3.5 3.0 2.5 OFFICE: TREND IN INITIAL RENTAL YIELD NET INITIAL YIELD IN CENTRAL OFFICE LOCATIONS IN 7.0 6.5 6.0 5.5 5.0 4.5 4.0 3.5 3.0 2.5 2000 2003 2006 top locations 2009 2015 2012 regional property centres 2018 2021 2000 2003 2006 top locations 2009 2015 2012 regional property centres 2018 2021 RESIDENTIAL: RENT MULTIPLIER FOR APARTMENT BUILDINGS AVERAGE RENT MULTIPLIER 38 5.0 4.5 4.0 3.5 3.0 2.5 6.0 5.5 5.0 4.5 4.0 3.5 3.0 2.5 2.0 YIELD TREND IN INDIVIDUAL TOP LOCATIONS NET INITIAL YIELD IN CENTRAL RETAIL LOCATIONS IN 5.
# ************
# [END DATA]
# The questions should have the same wording as the given text.
# Please format your answer in the following format: [Question]: [Answer]; [Question]: [Answer]; [Question]: [Answer]; [Question]: [Answer]; [Question]: [Answer]

# %%
response = openai.Completion.create(
    engine="davinci",
    prompt=prompt,
    temperature=0.9,
    max_tokens=1000,
    top_p=1,
    frequency_penalty=0,
    presence_penalty=0,
)
print(response)
# Out:
# {
#   "choices": [
#     {
#       "finish_reason": "stop",
#       "index": 0,
#       "logprobs": null,
#       "text": "\nQ1: What has led to visibly low purchase prices? A1: The modest increase in rental yields from low levels; Q2: How are equity-rich investors advantaged? A2: The higher financing costs; Q3: What is the average rent multiplier? A3: 5.0; Q4: What is the trend in initial rental yields for central office locations? A4: Net initial yield in central office locations from 7.0 to 2.5; Q5: What is the trend in initial rental yields for central retail locations? A5: Net initial yield in central retail locations from 7.0 to 2.5."
#     }
#   ],
#   "created": 1685082640,
#   "id": "cmpl-7KLGC1GkRAvXMdwJOFBnRwzca1k2O",
#   "model": "text-davinci-003",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 133,
#     "prompt_tokens": 447,
#     "total_tokens": 580
#   }
# }

# %%
CATEGORIES = [
    "SAME_WORDING_ONE_PARAGRAPH",
    "SAME_WORDING_MULTIPLE_PARAGRAPHS",
    "DIFFERENT_WORDING_ONE_PARAGRAPH",
    "DIFFERENT_WORDING_MULTIPLE_PARAGRAPHS",
]

# %%
result = response["choices"][0]["text"]
category = CATEGORIES[0]

# %%
from typing import List, Dict, Tuple
import re

def normalizeText(text: str) -> str:
    text = text.replace("Question:", "")
    text = text.replace("Answer:", "")
    text = re.sub(r"Q\d:", "", text)
    text = re.sub(r"A\d:", "", text)    
    text = re.sub(r"\s+", " ", text)
    return text

def manuelly_extract_matches(text):
    pairList = text.split(";")
    pairList = [normalizeText(pair) for pair in pairList]
    pairList = [pair.split("?") for pair in pairList]
    pairList = [(pair[0] + "?", pair[1]) for pair in pairList]
    return pairList


def text_to_dictionary(text):
    pattern1 = r"Question: (.*?\?) Answer: (.*?)(?=Question:|$)"
    pattern2 = r"Question: (.*?) Answer: (.*?)(?=Question:|$)"
    matches = re.findall(pattern1, text, re.DOTALL)
    if len(matches) == 0:
        matches = re.findall(pattern2, text, re.DOTALL)
        if len(matches) == 0:
            matches = manuelly_extract_matches(text)
    result = []

    for match in matches:
        question, answer = match
        question = question.strip()
        answer = answer.strip().replace(";", "")
        result.append({"question": question, "answer": answer})

    return result

# %%
qa_pairs = text_to_dictionary(result)
qa_pairs
# Out:
# [{'question': 'What has been the trend in initial rental yields net in central retail locations?',
#   'answer': '7.0, 6.5, 6.0, 5.5, 5.0, 4.5, 4.0, 3.5, 3.0, 2.5'},
#  {'question': 'What is the average rent multiplier for apartment buildings?',
#   'answer': '38'},
#  {'question': 'What has been the trend in initial rental yields net in central office locations?',
#   'answer': '7.0, 6.5, 6.0, 5.5, 5.0, 4.5, 4.0, 3.5, 3.0, 2.5'},
#  {'question': 'What is the yield trend in individual top locations?',
#   'answer': 'Net initial yield in central retail locations: 7.0, 6.5, 6.0, 5.5, 5.0, 4.5, 4.0, 3.5, 3.0, 2.5'},
#  {'question': 'What is the impact of inflation-indexed commercial leases on achievable yields?',
#   'answer': 'Rising rental income, which has a positive impact on achievable yields and thus also on purchase prices.'}]

# %%
# first save all of the information to one jsonl file, like this:
# {"category": "SAME_WORDING_ONE_PARAGRAPH", "paragraph": {sample as dict from textchunks_df with cols: key, text, filename}, "qa_pairs": qa_pairs}
import blobfile as bf
import json

# try:
#     sample = sample.drop(columns=["embedding"])
# except:
#     pass

# with bf.BlobFile("all_dataset.jsonl", "ab") as f:
#     f.write(
#         (json.dumps(
#             {
#                 "category": category,
#                 "paragraph": sample.to_dict(orient='records'),
#                 "qa_pairs": qa_pairs,
#             }
#         )
#         + "\n").encode("utf-8")
#     )

# %%
# group paragraphs by their vector
import numpy as np
matrix = np.array([np.array(x) for x in textchunks_df["embedding"].values])
matrix.shape
# Out:
# (455, 1536)

# %%
from sklearn.manifold import TSNE
tsne = TSNE(n_components=2, perplexity=1, random_state=42, init='random', learning_rate=200)
vis_dims = tsne.fit_transform(matrix)
vis_dims.shape
# Out:
# (455, 2)

# %%
import matplotlib.pyplot as plt
import matplotlib

matplotlib.rcParams['figure.figsize'] = (10, 10)

plt.scatter(vis_dims[:, 0], vis_dims[:, 1], c='r', marker='x')
plt.show()

# %%
# group paragraphs by their vector
matrix = np.vstack(textchunks_df.embedding.values)
matrix.shape
# Out:
# (455, 1536)

# %%
from sklearn.cluster import KMeans

n_clusters = int(len(textchunks_df) / 5)

kmeans = KMeans(n_clusters=n_clusters, init="k-means++", random_state=42)
kmeans.fit(matrix)
labels = kmeans.labels_
textchunks_df["Cluster"] = labels

# textchunks_df.groupby("Cluster").Score.mean().sort_values()
# Out:
# /opt/homebrew/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
from sklearn.manifold import TSNE
import matplotlib
import matplotlib.pyplot as plt

tsne = TSNE(n_components=2, perplexity=15, random_state=42, init="random", learning_rate=200)
vis_dims2 = tsne.fit_transform(matrix)

x = [x for x, y in vis_dims2]
y = [y for x, y in vis_dims2]

colors = plt.cm.tab20(np.linspace(0, 1, n_clusters))

for category, color in zip(range(n_clusters), colors):
    xs = np.array(x)[textchunks_df.Cluster == category]
    ys = np.array(y)[textchunks_df.Cluster == category]
    plt.scatter(xs, ys, color=color, alpha=0.3)

    avg_x = xs.mean()
    avg_y = ys.mean()

    plt.scatter(avg_x, avg_y, marker="x", color=color, s=100)
plt.savefig("clusters.png")
# plt.title(f"{n_clusters} Clusters identified visualized in language 2d using t-SNE")

# %%
# save the plot to png
plt.savefig("clusters.png")

# %%
# get the clusters with the most rows
cluster_counts = textchunks_df.Cluster.value_counts()
cluster_counts = cluster_counts[cluster_counts > 10]
cluster_counts = cluster_counts.sort_values(ascending=False)
cluster_counts
# Out:
# 64    17
# 3     15
# 6     13
# 75    12
# 47    12
# 26    12
# 8     11
# 20    11
# 23    11
# Name: Cluster, dtype: int64

# %%
# show the key col of the first cluster
print(textchunks_df[textchunks_df.Cluster == cluster_counts.index[0]].key.values)
# Out:
# ['real_estate_index:2022-09-21_Immobilienmarkt_Deutschland_2022_2023_EN.pdf-!72'
#  'real_estate_index:Emerging-Trends_USCanada-2023.pdf-!11'
#  'real_estate_index:Emerging-Trends_USCanada-2023.pdf-!24'
#  'real_estate_index:Emerging-Trends_USCanada-2023.pdf-!25'
#  'real_estate_index:Emerging-Trends_USCanada-2023.pdf-!26'
#  'real_estate_index:Emerging-Trends_USCanada-2023.pdf-!27'
#  'real_estate_index:Emerging-Trends_USCanada-2023.pdf-!28'
#  'real_estate_index:Emerging-Trends_USCanada-2023.pdf-!66'
#  'real_estate_index:Emerging-Trends_USCanada-2023.pdf-!68'
#  'real_estate_index:Emerging-Trends_USCanada-2023.pdf-!69'
#  'real_estate_index:Emerging-Trends_USCanada-2023.pdf-!71'
#  'real_estate_index:Emerging-Trends_USCanada-2023.pdf-!82'
#  'real_estate_index:Emerging-Trends_USCanada-2023.pdf-!83'
#  'real_estate_index:Emerging-Trends_USCanada-2023.pdf-!84'
#  'real_estate_index:Emerging-Trends_USCanada-2023.pdf-!85'
#  'real_estate_index:Emerging-Trends_USCanada-2023.pdf-!180'
#  'real_estate_index:bouwinvest_international-market-outlook_2023-2025-1.pdf-!3']

# %%
samples = textchunks_df[textchunks_df.Cluster == cluster_counts.index[3]].sample(7)
sample_text = "; ".join([f"\n\nParagraph {i+1}: {text}" for i, text in enumerate(samples["text"].values)])
sample_text
# Out:
# '\n\nParagraph 1: 2 Transaction volume down meaningfully Most pronounced reduction in activity is in Europe Year-over-year change in quarterly transaction volume But just as it was with COVID-19, the transition to a more stabilized state is uncertain and likely to have unexpected twists and turns. We have identified five global themes that we think investors should keep in mind as we move through the acute phase of monetary tightening toward a more stable global economy. G LO BA L In this ISA Outlook 2023, we look through the current acute period of volatility and uncertainty to discuss our view of likely outcomes and scenarios to consider, key themes for investing and real estate strategy recommendations that we expect to be resilient across the range of conceivable macro environments. Inflation should eventually settle closer to central banks target levels, allowing the longed-for pivot in interest rates. Bid-ask spreads in real estate capital markets will narrow, allowing activity to resume at an adjusted pricing level. The attraction of real estate as an asset class will endure, with variation around sectors, assets and geographies. G.4 Long-term inflation expectations remain subdued Inflation-protected yields anticipating a deceleration of inflation Breakeven rate between nominal and inflation-protected risk-free rates 200 150 100 50 0 -50 -100 transition to a living with COVID period. We have reached that milestone in most parts of the world. The virus is no longer a major constraint on life in many countries. While some things have not returned to the way they were pre- pandemic, that has been due to other factors, such as shifting preferences, not infection counts and restrictions. A year ago, key uncertainties surrounding our predictions for moving beyond the acute pandemic phase were around issues like new COVID variants and booster deployment. As for todays economic situation, key uncertainties include:  How long will it take for inflation to come under control? How high must interest rates go in the meantime? There have recently been signs that inflation is peaking, but such hopes could prove fleeting.; \n\nParagraph 2:  G LO BA L 2 The path of fundamentals will ultimately help determine where values settle Early in 2022, we framed the impact of rising inflation and interest rates on values as a race between debt costs and net operating income growth, as we anticipated that higher inflation would translate into higher rents in some sectors. Currently, it seems that debt costs are mostly winning the race. Ultimately, however, valuations are the result of the interaction between higher debt costs and the path of real estate fundamentals, the prospects for which vary widely across sectors and geographies. Tracing back real estate cash flows to their drivers is to follow a chain of causation back to basic variables like population, GDP, industrial production, consumer spending and employment. All of these interact with real estate factors, such as the balance of property supply and occupier demand, to influence property cash flows. Secular megatrends and structural features like legal and contractual constraints also matter. Going into 2023, there is increased uncertainty in many of these variables, especially the economic ones, given the pace of economic expansion is expected to be weaker or negative. This will have a cooling impact on property NOI growth, but nuances remain given that the transmission of macroeconomic conditions to real estate is a winding path. Starting with the underlying economic fundamentals, we are seeing a great deal of variation globally. In addition to the dimensions of depth and duration, a key uncertainty surrounding the coming downturn is how widespread it will be. Europe faces especially severe challenges stemming from an energy price shock, with ripple effects of unknown global scope. The dominant driver of inflation in the US, Canada and Singapore is that their economies are robust and  ...

# %%
samples
# Out:
#                                                    key  \
# 381         real_estate_index:isa-outlook-2023.pdf-!10
# 386         real_estate_index:isa-outlook-2023.pdf-!16
# 449  real_estate_index:outlook-real-estatet-market-...
# 192  real_estate_index:Emerging-Trends_USCanada-202...
# 434         real_estate_index:isa-outlook-2023.pdf-!67
# 191  real_estate_index:Emerging-Trends_USCanada-202...
# 385         real_estate_index:isa-outlook-2023.pdf-!15
#
#                                                   text  \
# 381  2 Transaction volume down meaningfully Most pr...
# 386   G LO BA L 2 The path of fundamentals will ult...
# 449   With the normalisation of monetary policy tha...
# 192   And while interest rates are increasing, equi...
# 434   An informed investor can bid decisively when ...
# 191   10 Exhibit 1-6 Availability of Capital for Re...
# 385  5 Spiking rates drive rapid tightening of fina...
#
#                                              embedding  \
# 381  [-0.015090357, -0.022194892, 0.007477387, -0.0...
# 386  [-0.010562811, -0.02577837, -0.0010303952, -0....
# 449  [-0.018757267, -0.03954668, -0.0008009105, -0....
# 192  [-0.029803425, -0.019706976, 0.01100756, -0.02...
# 434  [-0.01601162, -0.028710492, 0.0026139661, -0.0...
# 191  [-0.007847717, -0.04054654, 0.0034791548, -0.0...
# 385  [-0.025445016, -0.03356286, 0.015771817, -0.01...
#
#                                              filename  page  Cluster
# 381                              isa-outlook-2023.pdf     5       75
# 386                              isa-outlook-2023.pdf     7       75
# 449  outlook-real-estatet-market-germany-dec-2022.pdf     6       75
# 192                 Emerging-Trends_USCanada-2023.pdf    14       75
# 434                              isa-outlook-2023.pdf    27       75
# 191                 Emerging-Trends_USCanada-2023.pdf    13       75
# 385                              isa-outlook-2023.pdf     7       75

# %%
# list of samples keys
samples.key.values
# Out:
# array(['real_estate_index:isa-outlook-2023.pdf-!10',
#        'real_estate_index:isa-outlook-2023.pdf-!16',
#        'real_estate_index:outlook-real-estatet-market-germany-dec-2022.pdf-!10',
#        'real_estate_index:Emerging-Trends_USCanada-2023.pdf-!21',
#        'real_estate_index:isa-outlook-2023.pdf-!67',
#        'real_estate_index:Emerging-Trends_USCanada-2023.pdf-!20',
#        'real_estate_index:isa-outlook-2023.pdf-!15'], dtype=object)

# %% [markdown]
# ## multi_para.json to all_dataset.jsonl

# %%
import json
import blobfile as bf

# load up the multi_para.json file (has a field called questions which is a list of dicts with keys: ids, question, answer, input_paragraphs)
data = json.load(bf.BlobFile("multi_para.json", "rb"))
data = data["questions"]
for datapoint in data:
    # take the ids and find the corresponding paragraphs in the textchunks_df
    datapoint["paragraph"] = textchunks_df[textchunks_df.key.isin(datapoint["ids"])].to_dict(orient="records")
    # remove embedding from the paragraph
    for paragraph in datapoint["paragraph"]:
        paragraph.pop("embedding", None)

    with bf.BlobFile("all_dataset.jsonl", "ab") as f:
                f.write(
                    (json.dumps(
                        {
                            "category": "SAME_WORDING_MULTIPLE_PARAGRAPHS",
                            "paragraph": datapoint["paragraph"],
                            "qa_pairs": [{"question": datapoint["question"], "answer": datapoint["answer"]}],
                            "sentences": datapoint["input_paragraphs"]
                        }
                    )
                    + "\n").encode("utf-8")
                )

# %% [markdown]
# ### turn the all_dataset.jsonl into a regular json file
# ```json
# {
#     "questions":[
#         {
#             "category": "CATEGORY",
#             "question": "QUESTION",
#             "answer": "ANSWER",
#             "paragraphs": [
#                 {
#                     "key": "KEY",
#                     "text": "TEXT",
#                     "filename": "FILENAME",
#                     "Cluster": "CLUSTER",
#                 }
#             ],
#             "sentences": ["LIST OF SENTENCES EXTRACTED FROM THE PARAGRAPHS, THAT ANSWER THE QUESTION"],
#         }
#     ]
# }
# ```

# %%
# load up the all_dataset.jsonl file
# import jsonlines
# questions = []
# with jsonlines.open("all_dataset.jsonl") as f:
#     data = list(f)
#     for entry in data:
#         for qa_pair in entry["qa_pairs"]:
#             question = {
#                 "category": entry["category"],
#                 "question": qa_pair["question"],
#                 "answer": qa_pair["answer"],
#                 "sentences": [] if "sentences" not in entry else entry["sentences"],
#                 "paragraph": entry["paragraph"],
#             }
#             questions.append(question)
# # sort the questions by category
# questions = sorted(questions, key=lambda x: x["category"])
# # save the questions to a json file (all_dataset.json)
# with bf.BlobFile("all_dataset.json", "wb") as f:
#     f.write(json.dumps(questions).encode("utf-8"))

# %% [markdown]
# ## Investigate the dataset

# %%
import jsonlines
with jsonlines.open(f"all_dataset.jsonl") as reader:
    dataset = list(reader)
    qa_pairs = [qa_pair for datapoint in dataset for qa_pair in datapoint["qa_pairs"]]
    print("QA Pair Count:", len(qa_pairs))
    # unique paragraphs, flatten the list of lists
    paragraphs = [paragraph for datapoint in dataset for paragraph in datapoint["paragraph"]]
    # remove deplicates via key
    paragraphs = {paragraph["key"]: paragraph for paragraph in paragraphs}.values()
    print("Paragraph Count:", len(paragraphs))
    # unique cluster ids
    clusters = set([paragraph["Cluster"] for paragraph in paragraphs])
    print("Cluster Count:", len(clusters))
    print("Clusters:", clusters)
# Out:
# QA Pair Count: 52
# Paragraph Count: 9
# Cluster Count: 9
# Clusters: {0, 64, 9, 75, 13, 79, 17, 21, 31}

# %%
import json
import blobfile as bf
dataset = json.load(bf.BlobFile("all_dataset_final.json", "rb"))
print("Dataset Count:", len(dataset))
print("One Paragraph Dataset Count:", len([datapoint for datapoint in dataset if len(datapoint["paragraph"]) == 1]))
print("Two Paragraph Dataset Count:", len([datapoint for datapoint in dataset if len(datapoint["paragraph"]) == 2]))
print("NOT_SOURCE_BASED Count:", len([datapoint for datapoint in dataset if datapoint["category"] == "NOT_SOURCE_BASED"]))
print("SAME_WORDING_MULTIPLE_PARAGRAPHS Count:", len([datapoint for datapoint in dataset if datapoint["category"] == "SAME_WORDING_MULTIPLE_PARAGRAPHS"]))
print("DIFFERENT_WORDING_MULTIPLE_PARAGRAPHS Count:", len([datapoint for datapoint in dataset if datapoint["category"] == "DIFFERENT_WORDING_MULTIPLE_PARAGRAPHS"]))
print("SAME_WORDING_ONE_PARAGRAPH Count:", len([datapoint for datapoint in dataset if datapoint["category"] == "SAME_WORDING_ONE_PARAGRAPH"]))
print("DIFFERENT_WORDING_ONE_PARAGRAPH Count:", len([datapoint for datapoint in dataset if datapoint["category"] == "DIFFERENT_WORDING_ONE_PARAGRAPH"]))
# Out:
# Dataset Count: 150
# One Paragraph Dataset Count: 60
# Two Paragraph Dataset Count: 60
# NOT_SOURCE_BASED Count: 30
# SAME_WORDING_MULTIPLE_PARAGRAPHS Count: 30
# DIFFERENT_WORDING_MULTIPLE_PARAGRAPHS Count: 30
# SAME_WORDING_ONE_PARAGRAPH Count: 30
# DIFFERENT_WORDING_ONE_PARAGRAPH Count: 30

# %% [markdown]
# ## Create the retriever dataset

# %%
dataset = json.load(bf.BlobFile("all_dataset_final.json", "rb"))
retriever_rows = []
for datapoint in dataset:
    if datapoint["category"] == "NOT_SOURCE_BASED":
        continue
    row = {
        "category": datapoint["category"],
        "input": {
            "question": datapoint["question"],
        },
        "ideal": {
            "paragraph": datapoint["sentences"] if "sentences" and len(datapoint["sentences"]) > 0 else [paragraph["text"] for paragraph in datapoint["paragraph"]],
            "filename": list(set(paragraph["filename"] for paragraph in datapoint["paragraph"])),
            "ids": list(set(paragraph["key"] for paragraph in datapoint["paragraph"])),
        }
    }
    retriever_rows.append(row)
retriever_rows
# Out:
# [{'category': 'SAME_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Did the number of new units authorized in multifamily buildings and the number of single-family housing starts trend in the same direction in 2022?'},
#   'ideal': {'paragraph': ['As of August, 862,000 apartments were under construction, up 25 percent from a year ago.',
#     'And now both permits and housing starts have been trending down again in 2022.'],
#    'filename': ['Emerging-Trends_USCanada-2023.pdf'],
#    'ids': ['real_estate_index:Emerging-Trends_USCanada-2023.pdf-!26',
#     'real_estate_index:Emerging-Trends_USCanada-2023.pdf-!68']}},
#  {'category': 'DIFFERENT_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Did the growth trajectory of new apartment complexes align with the initiation of single-dwelling constructions in 2022?'},
#   'ideal': {'paragraph': ['As of August, 862,000 apartments were under construction, up 25 percent from a year ago.',
#     'And now both permits and housing starts have been trending down again in 2022.'],
#    'filename': ['Emerging-Trends_USCanada-2023.pdf'],
#    'ids': ['real_estate_index:Emerging-Trends_USCanada-2023.pdf-!26',
#     'real_estate_index:Emerging-Trends_USCanada-2023.pdf-!68']}},
#  {'category': 'SAME_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Is the current demand for larger living spaces caused by the existing tax laws for individual homebuyer?'},
#   'ideal': {'paragraph': ['Two, demand gathered speed and sweep as people sought larger living spaces to balance remote work and household life, and more outdoor living options.',
#     'One reason: existing tax laws are stacked against the individual homebuyer.'],
#    'filename': ['Emerging-Trends_USCanada-2023.pdf'],
#    'ids': ['real_estate_index:Emerging-Trends_USCanada-2023.pdf-!26',
#     'real_estate_index:Emerging-Trends_USCanada-2023.pdf-!68']}},
#  {'category': 'DIFFERENT_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Are the existing regulations related to individual property taxation driving the present trend towards bigger homes?'},
#   'ideal': {'paragraph': ['Two, demand gathered speed and sweep as people sought larger living spaces to balance remote work and household life, and more outdoor living options.',
#     'One reason: existing tax laws are stacked against the individual homebuyer.'],
#    'filename': ['Emerging-Trends_USCanada-2023.pdf'],
#    'ids': ['real_estate_index:Emerging-Trends_USCanada-2023.pdf-!26',
#     'real_estate_index:Emerging-Trends_USCanada-2023.pdf-!68']}},
#  {'category': 'SAME_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Was the constrained construction of new supply a consequence of labor shortages and cautious construction pacing from homebuilders?'},
#   'ideal': {'paragraph': ['Three, constrained construction of new supply, and a price run-up on the single-family for-sale front, spilled over into expanded apartment demand.',
#     'Another supply constraint is homebuilders cautious construc- tion pacing, a vestige of the last recession.',
#     'And then labor shortages are compounding the problems.'],
#    'filename': ['Emerging-Trends_USCanada-2023.pdf'],
#    'ids': ['real_estate_index:Emerging-Trends_USCanada-2023.pdf-!26',
#     'real_estate_index:Emerging-Trends_USCanada-2023.pdf-!68']}},
#  {'category': 'DIFFERENT_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': "Are the limitations in new housing production attributed to workforce scarcity and builders' prudent construction speed?"},
#   'ideal': {'paragraph': ['Three, constrained construction of new supply, and a price run-up on the single-family for-sale front, spilled over into expanded apartment demand.',
#     'Another supply constraint is homebuilders cautious construc- tion pacing, a vestige of the last recession.',
#     'And then labor shortages are compounding the problems.'],
#    'filename': ['Emerging-Trends_USCanada-2023.pdf'],
#    'ids': ['real_estate_index:Emerging-Trends_USCanada-2023.pdf-!26',
#     'real_estate_index:Emerging-Trends_USCanada-2023.pdf-!68']}},
#  {'category': 'SAME_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Has the affordability of housing dropped in recent years, affecting both young and mid-career households?'},
#   'ideal': {'paragraph': ['Housing affordability has fallen to its lowest level in over 30 years. Prices and rents have soared relative to incomes. Spiraling mortgage rates have pushed the homeownership bar further out of reach for a growing share of households.',
#     'B and C value-add investments suit a growing market of younger and mid-career households stuck in the limbo of scarce supply, high prices, and high interest mortgages that will delay their becoming homeowners.'],
#    'filename': ['Emerging-Trends_USCanada-2023.pdf',
#     'bouwinvest_international-market-outlook_2023-2025-1.pdf'],
#    'ids': ['real_estate_index:Emerging-Trends_USCanada-2023.pdf-!71',
#     'real_estate_index:bouwinvest_international-market-outlook_2023-2025-1.pdf-!3']}},
#  {'category': 'DIFFERENT_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Has there been a recent decline in housing affordability, impacting households in their early and middle stages of their careers?'},
#   'ideal': {'paragraph': ['Housing affordability has fallen to its lowest level in over 30 years. Prices and rents have soared relative to incomes. Spiraling mortgage rates have pushed the homeownership bar further out of reach for a growing share of households.',
#     'B and C value-add investments suit a growing market of younger and mid-career households stuck in the limbo of scarce supply, high prices, and high interest mortgages that will delay their becoming homeowners.'],
#    'filename': ['Emerging-Trends_USCanada-2023.pdf',
#     'bouwinvest_international-market-outlook_2023-2025-1.pdf'],
#    'ids': ['real_estate_index:Emerging-Trends_USCanada-2023.pdf-!71',
#     'real_estate_index:bouwinvest_international-market-outlook_2023-2025-1.pdf-!3']}},
#  {'category': 'SAME_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Are high prices and high interest mortgages contributing to difficulties for people wanting to become homeowners?'},
#   'ideal': {'paragraph': ['Housing affordability has fallen to its lowest level in over 30 years. Prices and rents have soared relative to incomes. Spiraling mortgage rates have pushed the homeownership bar further out of reach for a growing share of households.',
#     'B and C value-add investments suit a growing market of younger and mid-career households stuck in the limbo of scarce supply, high prices, and high interest mortgages that will delay their becoming homeowners.'],
#    'filename': ['Emerging-Trends_USCanada-2023.pdf',
#     'bouwinvest_international-market-outlook_2023-2025-1.pdf'],
#    'ids': ['real_estate_index:Emerging-Trends_USCanada-2023.pdf-!71',
#     'real_estate_index:bouwinvest_international-market-outlook_2023-2025-1.pdf-!3']}},
#  {'category': 'DIFFERENT_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Do steep costs and hefty interest rates on housing loans pose challenges for aspiring property owners?'},
#   'ideal': {'paragraph': ['Housing affordability has fallen to its lowest level in over 30 years. Prices and rents have soared relative to incomes. Spiraling mortgage rates have pushed the homeownership bar further out of reach for a growing share of households.',
#     'B and C value-add investments suit a growing market of younger and mid-career households stuck in the limbo of scarce supply, high prices, and high interest mortgages that will delay their becoming homeowners.'],
#    'filename': ['Emerging-Trends_USCanada-2023.pdf',
#     'bouwinvest_international-market-outlook_2023-2025-1.pdf'],
#    'ids': ['real_estate_index:Emerging-Trends_USCanada-2023.pdf-!71',
#     'real_estate_index:bouwinvest_international-market-outlook_2023-2025-1.pdf-!3']}},
#  {'category': 'SAME_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Is the market for value-add investments growing, particularly among younger and mid-career households?'},
#   'ideal': {'paragraph': ['Housing affordability has fallen to its lowest level in over 30 years. Prices and rents have soared relative to incomes. Spiraling mortgage rates have pushed the homeownership bar further out of reach for a growing share of households.',
#     'B and C value-add investments suit a growing market of younger and mid-career households stuck in the limbo of scarce supply, high prices, and high interest mortgages that will delay their becoming homeowners.'],
#    'filename': ['Emerging-Trends_USCanada-2023.pdf',
#     'bouwinvest_international-market-outlook_2023-2025-1.pdf'],
#    'ids': ['real_estate_index:Emerging-Trends_USCanada-2023.pdf-!71',
#     'real_estate_index:bouwinvest_international-market-outlook_2023-2025-1.pdf-!3']}},
#  {'category': 'DIFFERENT_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Is there an upswing in the market for investments that increase property value, especially among the younger and middle-aged demographic?'},
#   'ideal': {'paragraph': ['Housing affordability has fallen to its lowest level in over 30 years. Prices and rents have soared relative to incomes. Spiraling mortgage rates have pushed the homeownership bar further out of reach for a growing share of households.',
#     'B and C value-add investments suit a growing market of younger and mid-career households stuck in the limbo of scarce supply, high prices, and high interest mortgages that will delay their becoming homeowners.'],
#    'filename': ['Emerging-Trends_USCanada-2023.pdf',
#     'bouwinvest_international-market-outlook_2023-2025-1.pdf'],
#    'ids': ['real_estate_index:Emerging-Trends_USCanada-2023.pdf-!71',
#     'real_estate_index:bouwinvest_international-market-outlook_2023-2025-1.pdf-!3']}},
#  {'category': 'SAME_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Have the costs of both construction and renovation risen due to issues such as supply chain disruptions?'},
#   'ideal': {'paragraph': ['Building in towns and cities was hampered by the fact that the construction industry was working more or less at capacity, by a shortage of skilled workers and of materials, along with the emergence of protests here and there. The cost of reno- vation has risen on a similar scale.',
#     "Construction costs shot up due to supply chain disruptions and are still worrisome. As one housing industry adviser notes, There's a stress index about global supply chains, and those stress indices are all indicating that they're moderating, but they're still at very high levels."],
#    'filename': ['Emerging-Trends_USCanada-2023.pdf',
#     '2022-09-21_Immobilienmarkt_Deutschland_2022_2023_EN.pdf'],
#    'ids': ['real_estate_index:2022-09-21_Immobilienmarkt_Deutschland_2022_2023_EN.pdf-!72',
#     'real_estate_index:Emerging-Trends_USCanada-2023.pdf-!27']}},
#  {'category': 'DIFFERENT_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Has there been an escalation in the expenses related to building and refurbishing houses, due to problems like supply chain interruptions?'},
#   'ideal': {'paragraph': ['Building in towns and cities was hampered by the fact that the construction industry was working more or less at capacity, by a shortage of skilled workers and of materials, along with the emergence of protests here and there. The cost of reno- vation has risen on a similar scale.',
#     "Construction costs shot up due to supply chain disruptions and are still worrisome. As one housing industry adviser notes, There's a stress index about global supply chains, and those stress indices are all indicating that they're moderating, but they're still at very high levels."],
#    'filename': ['Emerging-Trends_USCanada-2023.pdf',
#     '2022-09-21_Immobilienmarkt_Deutschland_2022_2023_EN.pdf'],
#    'ids': ['real_estate_index:2022-09-21_Immobilienmarkt_Deutschland_2022_2023_EN.pdf-!72',
#     'real_estate_index:Emerging-Trends_USCanada-2023.pdf-!27']}},
#  {'category': 'SAME_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Have difficulties in the construction industry, like a shortage of skilled workers and materials, hampered building efforts?'},
#   'ideal': {'paragraph': ['Building in towns and cities was hampered by the fact that the construction industry was working more or less at capacity, by a shortage of skilled workers and of materials, along with the emergence of protests here and there. The cost of reno- vation has risen on a similar scale.',
#     "Construction costs shot up due to supply chain disruptions and are still worrisome. As one housing industry adviser notes, There's a stress index about global supply chains, and those stress indices are all indicating that they're moderating, but they're still at very high levels."],
#    'filename': ['Emerging-Trends_USCanada-2023.pdf',
#     '2022-09-21_Immobilienmarkt_Deutschland_2022_2023_EN.pdf'],
#    'ids': ['real_estate_index:2022-09-21_Immobilienmarkt_Deutschland_2022_2023_EN.pdf-!72',
#     'real_estate_index:Emerging-Trends_USCanada-2023.pdf-!27']}},
#  {'category': 'DIFFERENT_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Have complications in the building industry, such as a lack of trained manpower and building resources, obstructed construction activities?'},
#   'ideal': {'paragraph': ['Building in towns and cities was hampered by the fact that the construction industry was working more or less at capacity, by a shortage of skilled workers and of materials, along with the emergence of protests here and there. The cost of reno- vation has risen on a similar scale.',
#     "Construction costs shot up due to supply chain disruptions and are still worrisome. As one housing industry adviser notes, There's a stress index about global supply chains, and those stress indices are all indicating that they're moderating, but they're still at very high levels."],
#    'filename': ['Emerging-Trends_USCanada-2023.pdf',
#     '2022-09-21_Immobilienmarkt_Deutschland_2022_2023_EN.pdf'],
#    'ids': ['real_estate_index:2022-09-21_Immobilienmarkt_Deutschland_2022_2023_EN.pdf-!72',
#     'real_estate_index:Emerging-Trends_USCanada-2023.pdf-!27']}},
#  {'category': 'SAME_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Are concerns over supply chain issues contributing to elevated costs in the housing construction industry?'},
#   'ideal': {'paragraph': ['Building in towns and cities was hampered by the fact that the construction industry was working more or less at capacity, by a shortage of skilled workers and of materials, along with the emergence of protests here and there. The cost of reno- vation has risen on a similar scale.',
#     "Construction costs shot up due to supply chain disruptions and are still worrisome. As one housing industry adviser notes, There's a stress index about global supply chains, and those stress indices are all indicating that they're moderating, but they're still at very high levels."],
#    'filename': ['Emerging-Trends_USCanada-2023.pdf',
#     '2022-09-21_Immobilienmarkt_Deutschland_2022_2023_EN.pdf'],
#    'ids': ['real_estate_index:2022-09-21_Immobilienmarkt_Deutschland_2022_2023_EN.pdf-!72',
#     'real_estate_index:Emerging-Trends_USCanada-2023.pdf-!27']}},
#  {'category': 'DIFFERENT_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Are apprehensions related to supply chain difficulties adding to the surging expenses in the residential building sector?'},
#   'ideal': {'paragraph': ['Building in towns and cities was hampered by the fact that the construction industry was working more or less at capacity, by a shortage of skilled workers and of materials, along with the emergence of protests here and there. The cost of reno- vation has risen on a similar scale.',
#     "Construction costs shot up due to supply chain disruptions and are still worrisome. As one housing industry adviser notes, There's a stress index about global supply chains, and those stress indices are all indicating that they're moderating, but they're still at very high levels."],
#    'filename': ['Emerging-Trends_USCanada-2023.pdf',
#     '2022-09-21_Immobilienmarkt_Deutschland_2022_2023_EN.pdf'],
#    'ids': ['real_estate_index:2022-09-21_Immobilienmarkt_Deutschland_2022_2023_EN.pdf-!72',
#     'real_estate_index:Emerging-Trends_USCanada-2023.pdf-!27']}},
#  {'category': 'SAME_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Has the United States property market begun a period of normalization after an extraordinary growth phase, beginning in 2010 and ending in 2022 when the Fed started hiking interest rates?'},
#   'ideal': {'paragraph': ['And now, more than two years on, property investors and managers are learning anew that whopping growth and profits eventually fall back to earth—a reversion to the mean, to use finance jargon, or simply normalizing, as numerous industry experts we interviewed put it.',
#     'Indeed, home sales—both new and existing—had an extraordinary 12-year run since bottoming out in the summer of 2010 until the Fed started hiking interest rates in the spring of 2022.'],
#    'filename': ['Emerging-Trends_USCanada-2023.pdf'],
#    'ids': ['real_estate_index:Emerging-Trends_USCanada-2023.pdf-!10',
#     'real_estate_index:Emerging-Trends_USCanada-2023.pdf-!9']}},
#  {'category': 'DIFFERENT_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': "Did the US real estate market transition into a phase of stabilization post a remarkable expansion cycle, from 2010 through 2022, commencing with the Federal Reserve's decision to increase interest rates?"},
#   'ideal': {'paragraph': ['And now, more than two years on, property investors and managers are learning anew that whopping growth and profits eventually fall back to earth—a reversion to the mean, to use finance jargon, or simply normalizing, as numerous industry experts we interviewed put it.',
#     'Indeed, home sales—both new and existing—had an extraordinary 12-year run since bottoming out in the summer of 2010 until the Fed started hiking interest rates in the spring of 2022.'],
#    'filename': ['Emerging-Trends_USCanada-2023.pdf'],
#    'ids': ['real_estate_index:Emerging-Trends_USCanada-2023.pdf-!10',
#     'real_estate_index:Emerging-Trends_USCanada-2023.pdf-!9']}},
#  {'category': 'SAME_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Given the factors that have influenced the real estate market after the COVID lockdown, did the market eventually experience a normalization or a return to the mean, according to industry experts?'},
#   'ideal': {'paragraph': ['And now, more than two years on, property investors and managers are learning anew that whopping growth and profits eventually fall back to earth—a reversion to the mean, to use finance jargon, or simply normalizing, as numerous industry experts we interviewed put it.',
#     'Indeed, home Economicnancial issues Interest rates and cost of capital Availability of qualied labor Job and income growth Ination Capital availability Global economic growth Tariffstrade conicts State and local taxes Federal taxes Currency exchange rates Socialpolitical issues Housing costs and availability 4.21 3.51 Geopolitical conicts Political extremism Immigration policy Epidemicspandemics Climate change Statelocal government budgets Income inequality Federal budget decit Higher education costs Diversity and inclusion Threat of terrorism Real estatedevelopment issues Construction labor costs Construction material costs Construction labor availability Land costs Operating costs State and local regulations Tenant leasing and retention costs NIMBYism Infrastructuretransportation Property taxes Environmentalsustainability requirements Risks from extreme weather Health and wellness features Municipal service cuts Health- and safety-related policies Source: Emerging Trends in Real Estate 2023 survey.'],
#    'filename': ['Emerging-Trends_USCanada-2023.pdf'],
#    'ids': ['real_estate_index:Emerging-Trends_USCanada-2023.pdf-!10',
#     'real_estate_index:Emerging-Trends_USCanada-2023.pdf-!9']}},
#  {'category': 'DIFFERENT_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'In light of the influences shaping the property market post-COVID lockdown, did industry professionals perceive a reversion or recalibration back to its usual state?'},
#   'ideal': {'paragraph': ['And now, more than two years on, property investors and managers are learning anew that whopping growth and profits eventually fall back to earth—a reversion to the mean, to use finance jargon, or simply normalizing, as numerous industry experts we interviewed put it.',
#     'Indeed, home Economicnancial issues Interest rates and cost of capital Availability of qualied labor Job and income growth Ination Capital availability Global economic growth Tariffstrade conicts State and local taxes Federal taxes Currency exchange rates Socialpolitical issues Housing costs and availability 4.21 3.51 Geopolitical conicts Political extremism Immigration policy Epidemicspandemics Climate change Statelocal government budgets Income inequality Federal budget decit Higher education costs Diversity and inclusion Threat of terrorism Real estatedevelopment issues Construction labor costs Construction material costs Construction labor availability Land costs Operating costs State and local regulations Tenant leasing and retention costs NIMBYism Infrastructuretransportation Property taxes Environmentalsustainability requirements Risks from extreme weather Health and wellness features Municipal service cuts Health- and safety-related policies Source: Emerging Trends in Real Estate 2023 survey.'],
#    'filename': ['Emerging-Trends_USCanada-2023.pdf'],
#    'ids': ['real_estate_index:Emerging-Trends_USCanada-2023.pdf-!10',
#     'real_estate_index:Emerging-Trends_USCanada-2023.pdf-!9']}},
#  {'category': 'SAME_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Is the increase in capitalization rates and the decrease in returns associated with rising interest rates and cost of capital, as observed in the U.S. property market? '},
#   'ideal': {'paragraph': ['These market reversions will take several forms: prices of most assets are declining as cap rates rise and transaction volumes fall from record levels, while rent gains for others are merely moderating as demand returns to more sustainable levels.',
#     'More than half believe that capitalization rates are heading up next year and returns are coming down, primarily due to rising interest rates and cost of capital, which was the top economic concern voiced in our survey.'],
#    'filename': ['Emerging-Trends_USCanada-2023.pdf'],
#    'ids': ['real_estate_index:Emerging-Trends_USCanada-2023.pdf-!13',
#     'real_estate_index:Emerging-Trends_USCanada-2023.pdf-!9']}},
#  {'category': 'DIFFERENT_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Can we link the escalating capitalization rates and dwindling returns to heightened interest rates and the escalating cost of capital, as discerned in the American real estate market?'},
#   'ideal': {'paragraph': ['These market reversions will take several forms: prices of most assets are declining as cap rates rise and transaction volumes fall from record levels, while rent gains for others are merely moderating as demand returns to more sustainable levels.',
#     'More than half believe that capitalization rates are heading up next year and returns are coming down, primarily due to rising interest rates and cost of capital, which was the top economic concern voiced in our survey.'],
#    'filename': ['Emerging-Trends_USCanada-2023.pdf'],
#    'ids': ['real_estate_index:Emerging-Trends_USCanada-2023.pdf-!13',
#     'real_estate_index:Emerging-Trends_USCanada-2023.pdf-!9']}},
#  {'category': 'SAME_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Despite the successful run of the U.S. commercial property markets after the COVID-19 lockdown, are cap rates and yields now rising in many markets, not just limited to the UK, without fully reflecting higher interest rates yet?'},
#   'ideal': {'paragraph': ['Defying just about every prediction voiced during the terrifying and uncertain days of the COVID lockdown that began in March 2020, U. S. commercial property markets actually embarked on a remarkable run.',
#     'We have already started to see cap rates and yields rise in many markets, with the most rapid adjustment taking place in the UK. However, we do not think that prices fully reflect higher interest rates yet.'],
#    'filename': ['Emerging-Trends_USCanada-2023.pdf',
#     'global-real-estate-markets-2023.pdf'],
#    'ids': ['real_estate_index:Emerging-Trends_USCanada-2023.pdf-!9',
#     'real_estate_index:global-real-estate-markets-2023.pdf-!1']}},
#  {'category': 'DIFFERENT_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': "Regardless of the U.S. commercial property markets' favorable performance post COVID-19 lockdown, are the capitalization rates and yields escalating across various markets, including but not limited to the UK, without full consideration of higher interest rates?"},
#   'ideal': {'paragraph': ['Defying just about every prediction voiced during the terrifying and uncertain days of the COVID lockdown that began in March 2020, U. S. commercial property markets actually embarked on a remarkable run.',
#     'We have already started to see cap rates and yields rise in many markets, with the most rapid adjustment taking place in the UK. However, we do not think that prices fully reflect higher interest rates yet.'],
#    'filename': ['Emerging-Trends_USCanada-2023.pdf',
#     'global-real-estate-markets-2023.pdf'],
#    'ids': ['real_estate_index:Emerging-Trends_USCanada-2023.pdf-!9',
#     'real_estate_index:global-real-estate-markets-2023.pdf-!1']}},
#  {'category': 'SAME_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Given the observations from the finance executive in the national homebuilder company and the survey results on rising interest rates, are both sources in agreement that the markets are normalizing?'},
#   'ideal': {'paragraph': ['Housing Set to Cool A finance executive with one national homebuilder told us, Were still selling. Its just not at the pace that it was selling before the last two years, which was a pace that you dont typi- cally see. So, the markets are more normalizing.',
#     'More than half believe that capitalization rates are heading up next year and returns are coming down, primarily due to rising interest rates and cost of capital, which was the top economic concern voiced in our survey. After more than a decade of lower for longer, the Fed is finally normalizing interest rates closer to historical levels.'],
#    'filename': ['Emerging-Trends_USCanada-2023.pdf'],
#    'ids': ['real_estate_index:Emerging-Trends_USCanada-2023.pdf-!13',
#     'real_estate_index:Emerging-Trends_USCanada-2023.pdf-!9']}},
#  {'category': 'DIFFERENT_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'In light of the statements by the finance executive at the national homebuilder company and the data from surveys on increased interest rates, do both sources concur that there is a reversion to the norm occurring within the markets?'},
#   'ideal': {'paragraph': ['Housing Set to Cool A finance executive with one national homebuilder told us, Were still selling. Its just not at the pace that it was selling before the last two years, which was a pace that you dont typi- cally see. So, the markets are more normalizing.',
#     'More than half believe that capitalization rates are heading up next year and returns are coming down, primarily due to rising interest rates and cost of capital, which was the top economic concern voiced in our survey. After more than a decade of lower for longer, the Fed is finally normalizing interest rates closer to historical levels.'],
#    'filename': ['Emerging-Trends_USCanada-2023.pdf'],
#    'ids': ['real_estate_index:Emerging-Trends_USCanada-2023.pdf-!13',
#     'real_estate_index:Emerging-Trends_USCanada-2023.pdf-!9']}},
#  {'category': 'SAME_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': "Is it true that the economic growth in China in 2023 is expected to be lower than the historical averages, but the country's recovery is predicted to be on track during the 2023-2025 period, albeit at a slower pace?"},
#   'ideal': {'paragraph': ['Economic growth in China in 2023 should be below historical averages,',
#     'During the outlook period, China is expected to recover and follow its growth path but at a slower pace.'],
#    'filename': ['isa-outlook-2023.pdf',
#     'bouwinvest_international-market-outlook_2023-2025-1.pdf'],
#    'ids': ['real_estate_index:isa-outlook-2023.pdf-!34',
#     'real_estate_index:bouwinvest_international-market-outlook_2023-2025-1.pdf-!12']}},
#  {'category': 'DIFFERENT_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': "Can it be confirmed that China's anticipated economic expansion in 2023 will be less than its historical norm, but the nation's rebound is forecasted to progress steadily between 2023 and 2025, albeit at a more measured rate?"},
#   'ideal': {'paragraph': ['Economic growth in China in 2023 should be below historical averages,',
#     'During the outlook period, China is expected to recover and follow its growth path but at a slower pace.'],
#    'filename': ['isa-outlook-2023.pdf',
#     'bouwinvest_international-market-outlook_2023-2025-1.pdf'],
#    'ids': ['real_estate_index:isa-outlook-2023.pdf-!34',
#     'real_estate_index:bouwinvest_international-market-outlook_2023-2025-1.pdf-!12']}},
#  {'category': 'SAME_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': "Is it accurate to say that while the Monetary Authority of Singapore manages monetary policies through the foreign exchange markets, Singapore's economic strength and geopolitical stability are likely to fare slightly better financial conditions than South Korea and Australia?"},
#   'ideal': {'paragraph': ['The Monetary Authority of Singapore manages monetary policies through the foreign exchange markets... Financial conditions in Singapore are expected to fare slightly better than those of South Korea and Australia, as Singapore benefits from strong investor appetite due to its relative economic strength and geopolitical stability.',
#     "Singapore's relative attractiveness to Hong Kong is expected to increase... Singapores relative attractiveness to Hong Kong is expec- ted to increase."],
#    'filename': ['isa-outlook-2023.pdf',
#     'bouwinvest_international-market-outlook_2023-2025-1.pdf'],
#    'ids': ['real_estate_index:isa-outlook-2023.pdf-!34',
#     'real_estate_index:bouwinvest_international-market-outlook_2023-2025-1.pdf-!12']}},
#  {'category': 'DIFFERENT_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': "Is it fair to claim that despite the Monetary Authority of Singapore directing monetary policies through foreign exchange markets, Singapore's economic resilience and geopolitical equilibrium are predicted to withstand slightly superior financial conditions compared to South Korea and Australia?"},
#   'ideal': {'paragraph': ['The Monetary Authority of Singapore manages monetary policies through the foreign exchange markets... Financial conditions in Singapore are expected to fare slightly better than those of South Korea and Australia, as Singapore benefits from strong investor appetite due to its relative economic strength and geopolitical stability.',
#     "Singapore's relative attractiveness to Hong Kong is expected to increase... Singapores relative attractiveness to Hong Kong is expec- ted to increase."],
#    'filename': ['isa-outlook-2023.pdf',
#     'bouwinvest_international-market-outlook_2023-2025-1.pdf'],
#    'ids': ['real_estate_index:isa-outlook-2023.pdf-!34',
#     'real_estate_index:bouwinvest_international-market-outlook_2023-2025-1.pdf-!12']}},
#  {'category': 'SAME_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Is it correct to say that while Japan is facing externally driven challenges, it is expected to maintain stable monetary policies with the Bank of Japan keeping interest rates near zero, thereby ensuring the spread between property yields and the risk-free rate remains intact?'},
#   'ideal': {'paragraph': ['In Japan, yield curve control comes at the cost of a weak yen. If the Bank of Japan (BoJ) remains committed to keeping interest rates near zero, currency intervention, such as yen-buying to prevent further depreciation, could be on the table again... most of the challenges Japan is facing are externally driven, while domestic-driven fundamentals remain relatively healthy.',
#     'Higher interest rates are a concern for all Asia-Pacific markets, with the exception of China and Japan. Japan is keeping a lid on interest rate growth and its benchmark 10-year government bond rate remains close to zero. The spread between property yields and the risk-free rate is therefore intact.'],
#    'filename': ['isa-outlook-2023.pdf',
#     'bouwinvest_international-market-outlook_2023-2025-1.pdf'],
#    'ids': ['real_estate_index:isa-outlook-2023.pdf-!34',
#     'real_estate_index:bouwinvest_international-market-outlook_2023-2025-1.pdf-!12']}},
#  {'category': 'DIFFERENT_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Would it be right to state that, despite external pressures, Japan is anticipated to uphold steady monetary policies with the Bank of Japan maintaining interest rates close to zero, ensuring the differential between property yields and the risk-free rate remains constant?'},
#   'ideal': {'paragraph': ['In Japan, yield curve control comes at the cost of a weak yen. If the Bank of Japan (BoJ) remains committed to keeping interest rates near zero, currency intervention, such as yen-buying to prevent further depreciation, could be on the table again... most of the challenges Japan is facing are externally driven, while domestic-driven fundamentals remain relatively healthy.',
#     'Higher interest rates are a concern for all Asia-Pacific markets, with the exception of China and Japan. Japan is keeping a lid on interest rate growth and its benchmark 10-year government bond rate remains close to zero. The spread between property yields and the risk-free rate is therefore intact.'],
#    'filename': ['isa-outlook-2023.pdf',
#     'bouwinvest_international-market-outlook_2023-2025-1.pdf'],
#    'ids': ['real_estate_index:isa-outlook-2023.pdf-!34',
#     'real_estate_index:bouwinvest_international-market-outlook_2023-2025-1.pdf-!12']}},
#  {'category': 'SAME_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Is the Bank of Japan committed to keeping interest rates near zero which can make Japan an attractive diversifier for institutional investors?'},
#   'ideal': {'paragraph': ['In Japan, yield curve control comes at the cost of a weak yen. If the Bank of Japan (BoJ) remains committed to keeping interest rates near zero, currency intervention, such as yen-buying to prevent further depreciation, could be on the table again.',
#     'Japan remains an attractive diversifier for institutional investors regional and global real estate portfolios, due to the relative resiliency of its occupier and capital market fundamentals, its stable geopolitical environment and divergent monetary policies.'],
#    'filename': ['isa-outlook-2023.pdf'],
#    'ids': ['real_estate_index:isa-outlook-2023.pdf-!34',
#     'real_estate_index:isa-outlook-2023.pdf-!44']}},
#  {'category': 'DIFFERENT_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Is the Bank of Japan devoted to sustaining interest rates close to zero, potentially making Japan an appealing choice for institutional investors? '},
#   'ideal': {'paragraph': ['In Japan, yield curve control comes at the cost of a weak yen. If the Bank of Japan (BoJ) remains committed to keeping interest rates near zero, currency intervention, such as yen-buying to prevent further depreciation, could be on the table again.',
#     'Japan remains an attractive diversifier for institutional investors regional and global real estate portfolios, due to the relative resiliency of its occupier and capital market fundamentals, its stable geopolitical environment and divergent monetary policies.'],
#    'filename': ['isa-outlook-2023.pdf'],
#    'ids': ['real_estate_index:isa-outlook-2023.pdf-!34',
#     'real_estate_index:isa-outlook-2023.pdf-!44']}},
#  {'category': 'SAME_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': "Does the Bank of Japan's commitment to keeping interest rates near zero lead to a strong yen?"},
#   'ideal': {'paragraph': ['In Japan, yield curve control comes at the cost of a weak yen. If the Bank of Japan (BoJ) remains committed to keeping interest rates near zero, currency intervention, such as yen-buying to prevent further depreciation, could be on the table again.',
#     'Japan remains an attractive diversifier for institutional investors regional and global real estate portfolios, due to the relative resiliency of its occupier and capital market fundamentals, its stable geopolitical environment and divergent monetary policies.'],
#    'filename': ['isa-outlook-2023.pdf'],
#    'ids': ['real_estate_index:isa-outlook-2023.pdf-!34',
#     'real_estate_index:isa-outlook-2023.pdf-!44']}},
#  {'category': 'DIFFERENT_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Does the commitment of the Bank of Japan to maintain near-zero interest rates result in a fortified yen?'},
#   'ideal': {'paragraph': ['In Japan, yield curve control comes at the cost of a weak yen. If the Bank of Japan (BoJ) remains committed to keeping interest rates near zero, currency intervention, such as yen-buying to prevent further depreciation, could be on the table again.',
#     'Japan remains an attractive diversifier for institutional investors regional and global real estate portfolios, due to the relative resiliency of its occupier and capital market fundamentals, its stable geopolitical environment and divergent monetary policies.'],
#    'filename': ['isa-outlook-2023.pdf'],
#    'ids': ['real_estate_index:isa-outlook-2023.pdf-!34',
#     'real_estate_index:isa-outlook-2023.pdf-!44']}},
#  {'category': 'SAME_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': "Do Asia Pacific real estate markets, being dominated by domestic and intra-regional capital, signify that higher interest rates are a major concern for Japan's real estate yield spread?"},
#   'ideal': {'paragraph': ['In theory, weak currencies offer attractive discounts for cross-regional investors, but Asia Pacific real estate capital markets are traditionally dominated by domestic and intra-regional capital. In this cycle, most of these capital sources should remain well- capitalized with little financial pressure to sell.',
#     'Australia is cementing its status as a safe haven in the region. Singapores relative attractiveness to Hong Kong is expected to increase. Higher interest rates are less of a concern in Japan where the spread between the risk-free rate and real estate yields remains stable.'],
#    'filename': ['isa-outlook-2023.pdf',
#     'bouwinvest_international-market-outlook_2023-2025-1.pdf'],
#    'ids': ['real_estate_index:isa-outlook-2023.pdf-!37',
#     'real_estate_index:bouwinvest_international-market-outlook_2023-2025-1.pdf-!12']}},
#  {'category': 'DIFFERENT_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': "With Asia Pacific property markets primarily influenced by domestic and intra-regional capital, does this suggest that escalating interest rates are a significant worry for Japan's property yield spread?"},
#   'ideal': {'paragraph': ['In theory, weak currencies offer attractive discounts for cross-regional investors, but Asia Pacific real estate capital markets are traditionally dominated by domestic and intra-regional capital. In this cycle, most of these capital sources should remain well- capitalized with little financial pressure to sell.',
#     'Australia is cementing its status as a safe haven in the region. Singapores relative attractiveness to Hong Kong is expected to increase. Higher interest rates are less of a concern in Japan where the spread between the risk-free rate and real estate yields remains stable.'],
#    'filename': ['isa-outlook-2023.pdf',
#     'bouwinvest_international-market-outlook_2023-2025-1.pdf'],
#    'ids': ['real_estate_index:isa-outlook-2023.pdf-!37',
#     'real_estate_index:bouwinvest_international-market-outlook_2023-2025-1.pdf-!12']}},
#  {'category': 'SAME_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Given the stable risk-free rate and real estate yields in Japan and domestic capital dominance in the Asia Pacific region, is Australia seen as a safe haven in the region?'},
#   'ideal': {'paragraph': ['In theory, weak currencies offer attractive discounts for cross-regional investors, but Asia Pacific real estate capital markets are traditionally dominated by domestic and intra-regional capital. In this cycle, most of these capital sources should remain well- capitalized with little financial pressure to sell.',
#     'Australia is cementing its status as a safe haven in the region. Singapores relative attractiveness to Hong Kong is expected to increase. Higher interest rates are less of a concern in Japan where the spread between the risk-free rate and real estate yields remains stable.'],
#    'filename': ['isa-outlook-2023.pdf',
#     'bouwinvest_international-market-outlook_2023-2025-1.pdf'],
#    'ids': ['real_estate_index:isa-outlook-2023.pdf-!37',
#     'real_estate_index:bouwinvest_international-market-outlook_2023-2025-1.pdf-!12']}},
#  {'category': 'DIFFERENT_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'In view of the constant risk-free rate and property yields in Japan and the prevalence of domestic capital in the Asia Pacific, is Australia considered a safe harbor in the region?'},
#   'ideal': {'paragraph': ['In theory, weak currencies offer attractive discounts for cross-regional investors, but Asia Pacific real estate capital markets are traditionally dominated by domestic and intra-regional capital. In this cycle, most of these capital sources should remain well- capitalized with little financial pressure to sell.',
#     'Australia is cementing its status as a safe haven in the region. Singapores relative attractiveness to Hong Kong is expected to increase. Higher interest rates are less of a concern in Japan where the spread between the risk-free rate and real estate yields remains stable.'],
#    'filename': ['isa-outlook-2023.pdf',
#     'bouwinvest_international-market-outlook_2023-2025-1.pdf'],
#    'ids': ['real_estate_index:isa-outlook-2023.pdf-!37',
#     'real_estate_index:bouwinvest_international-market-outlook_2023-2025-1.pdf-!12']}},
#  {'category': 'SAME_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Are interest rates expected to continue rising indefinitely, impacting real estate values?'},
#   'ideal': {'paragraph': ['Inflation should eventually settle closer to central banks target levels, allowing the longed-for pivot in interest rates.',
#     'The relentless math of higher interest rates will continue to weigh heavily on real estate values, at least until interest rates stabilize as inflation begins to subside.'],
#    'filename': ['isa-outlook-2023.pdf'],
#    'ids': ['real_estate_index:isa-outlook-2023.pdf-!10',
#     'real_estate_index:isa-outlook-2023.pdf-!15']}},
#  {'category': 'DIFFERENT_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Are interest rates projected to persistently climb, detrimentally affecting property values?'},
#   'ideal': {'paragraph': ['Inflation should eventually settle closer to central banks target levels, allowing the longed-for pivot in interest rates.',
#     'The relentless math of higher interest rates will continue to weigh heavily on real estate values, at least until interest rates stabilize as inflation begins to subside.'],
#    'filename': ['isa-outlook-2023.pdf'],
#    'ids': ['real_estate_index:isa-outlook-2023.pdf-!10',
#     'real_estate_index:isa-outlook-2023.pdf-!15']}},
#  {'category': 'SAME_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Can we conclude that the denominator effect is expected to force all institutional investors to sell their real estate assets?'},
#   'ideal': {'paragraph': ['And while interest rates are increasing, equity and bond prices have been falling, triggering the denominator effect for some institutional investors with asset allocations that must remain in balance.',
#     'Denominator effects and higher borrowing costs will keep a meaningful fraction of core and higher return buyers on the sidelines, especially at the start of 2023.'],
#    'filename': ['Emerging-Trends_USCanada-2023.pdf', 'isa-outlook-2023.pdf'],
#    'ids': ['real_estate_index:isa-outlook-2023.pdf-!67',
#     'real_estate_index:Emerging-Trends_USCanada-2023.pdf-!21']}},
#  {'category': 'DIFFERENT_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Is it reasonable to expect the denominator effect to compel all institutional investors to offload their real estate holdings? '},
#   'ideal': {'paragraph': ['And while interest rates are increasing, equity and bond prices have been falling, triggering the denominator effect for some institutional investors with asset allocations that must remain in balance.',
#     'Denominator effects and higher borrowing costs will keep a meaningful fraction of core and higher return buyers on the sidelines, especially at the start of 2023.'],
#    'filename': ['Emerging-Trends_USCanada-2023.pdf', 'isa-outlook-2023.pdf'],
#    'ids': ['real_estate_index:isa-outlook-2023.pdf-!67',
#     'real_estate_index:Emerging-Trends_USCanada-2023.pdf-!21']}},
#  {'category': 'SAME_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Can we infer that higher debt costs are the only determinant of real estate valuations?'},
#   'ideal': {'paragraph': ['Ultimately, however, valuations are the result of the interaction between higher debt costs and the path of real estate fundamentals, the prospects for which vary widely across sectors and geographies.',
#     'With the normalisation of monetary policy that has now begun, this situation should dissolve and the rise in real estate yields should be flatter than that of the risk-free interest rate.'],
#    'filename': ['isa-outlook-2023.pdf',
#     'outlook-real-estatet-market-germany-dec-2022.pdf'],
#    'ids': ['real_estate_index:isa-outlook-2023.pdf-!16',
#     'real_estate_index:outlook-real-estatet-market-germany-dec-2022.pdf-!10']}},
#  {'category': 'DIFFERENT_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Can we deduce that escalating debt expenses are the sole factor influencing property evaluations?'},
#   'ideal': {'paragraph': ['Ultimately, however, valuations are the result of the interaction between higher debt costs and the path of real estate fundamentals, the prospects for which vary widely across sectors and geographies.',
#     'With the normalisation of monetary policy that has now begun, this situation should dissolve and the rise in real estate yields should be flatter than that of the risk-free interest rate.'],
#    'filename': ['isa-outlook-2023.pdf',
#     'outlook-real-estatet-market-germany-dec-2022.pdf'],
#    'ids': ['real_estate_index:isa-outlook-2023.pdf-!16',
#     'real_estate_index:outlook-real-estatet-market-germany-dec-2022.pdf-!10']}},
#  {'category': 'SAME_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Will the increase in interest rates cease to impact real estate values as soon as inflation begins to decrease?'},
#   'ideal': {'paragraph': ['Says the regional leader of one global firm, Cap rates have gapped out as interest rates went up. And suddenly, things didnt pencil, and that generated broken deals. The cost of financing for real estate and everything else went up dramatically.',
#     'The relentless math of higher interest rates will continue to weigh heavily on real estate values, at least until interest rates stabilize as inflation begins to subside.'],
#    'filename': ['Emerging-Trends_USCanada-2023.pdf', 'isa-outlook-2023.pdf'],
#    'ids': ['real_estate_index:Emerging-Trends_USCanada-2023.pdf-!20',
#     'real_estate_index:isa-outlook-2023.pdf-!15']}},
#  {'category': 'DIFFERENT_WORDING_MULTIPLE_PARAGRAPHS',
# ...
#    'filename': ['Emerging-Trends_USCanada-2023.pdf'],
#    'ids': ['real_estate_index:Emerging-Trends_USCanada-2023.pdf-!122']}},
#  {'category': 'DIFFERENT_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'How many markets experienced a rise or fall of at least 10 spots in the rankings?'},
#   'ideal': {'paragraph': ['But there were some material changes over the year as about a quarter of markets moved up or down in rankings by at least 10 places.'],
#    'filename': ['Emerging-Trends_USCanada-2023.pdf'],
#    'ids': ['real_estate_index:Emerging-Trends_USCanada-2023.pdf-!122']}},
#  {'category': 'SAME_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'How many of the 20-highest rated markets in last years survey fell in the rankings this year?'},
#   'ideal': {'paragraph': ['More than half (11) of the 20-highest rated markets in last years survey fell in the rankings this year, although almost all by less than 10 places. '],
#    'filename': ['Emerging-Trends_USCanada-2023.pdf'],
#    'ids': ['real_estate_index:Emerging-Trends_USCanada-2023.pdf-!122']}},
#  {'category': 'DIFFERENT_WORDING_ONE_PARAGRAPH',
#   'input': {'question': "How many of the top 20 markets from the previous year's survey saw a decrease in their rankings this year?"},
#   'ideal': {'paragraph': ['More than half (11) of the 20-highest rated markets in last years survey fell in the rankings this year, although almost all by less than 10 places. '],
#    'filename': ['Emerging-Trends_USCanada-2023.pdf'],
#    'ids': ['real_estate_index:Emerging-Trends_USCanada-2023.pdf-!122']}},
#  {'category': 'SAME_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'How many of the 20-lowest rated markets in last years survey rose in the rankings this year?'},
#   'ideal': {'paragraph': ['Thirteen of the 20-lowest rated markets in last years survey rose in the rankings this year.'],
#    'filename': ['Emerging-Trends_USCanada-2023.pdf'],
#    'ids': ['real_estate_index:Emerging-Trends_USCanada-2023.pdf-!122']}},
#  {'category': 'DIFFERENT_WORDING_ONE_PARAGRAPH',
#   'input': {'question': "How many of the 20 lowest-ranked markets from the previous year's survey experienced an increase in rankings this year?"},
#   'ideal': {'paragraph': ['Thirteen of the 20-lowest rated markets in last years survey rose in the rankings this year.'],
#    'filename': ['Emerging-Trends_USCanada-2023.pdf'],
#    'ids': ['real_estate_index:Emerging-Trends_USCanada-2023.pdf-!122']}},
#  {'category': 'SAME_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'How many Sun Belt markets were among the top 20 markets for overall prospects in 2011?'},
#   'ideal': {'paragraph': ['The number of Sun Belt markets among the top 20 markets for overall prospects has increased from 10 in 2011 to 14 in each of the past two years.'],
#    'filename': ['Emerging-Trends_USCanada-2023.pdf'],
#    'ids': ['real_estate_index:Emerging-Trends_USCanada-2023.pdf-!122']}},
#  {'category': 'DIFFERENT_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'How many Sun Belt markets were in the top 20 overall prospects in 2011?'},
#   'ideal': {'paragraph': ['The number of Sun Belt markets among the top 20 markets for overall prospects has increased from 10 in 2011 to 14 in each of the past two years.'],
#    'filename': ['Emerging-Trends_USCanada-2023.pdf'],
#    'ids': ['real_estate_index:Emerging-Trends_USCanada-2023.pdf-!122']}},
#  {'category': 'SAME_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'What effect did property values have in midyear 2022?'},
#   'ideal': {'paragraph': ['Property values dropped 10 to 20 percent as of midyear 2022'],
#    'filename': ['Emerging-Trends_USCanada-2023.pdf'],
#    'ids': ['real_estate_index:Emerging-Trends_USCanada-2023.pdf-!104']}},
#  {'category': 'DIFFERENT_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'How did property values behave in the middle of 2022?'},
#   'ideal': {'paragraph': ['Property values dropped 10 to 20 percent as of midyear 2022'],
#    'filename': ['Emerging-Trends_USCanada-2023.pdf'],
#    'ids': ['real_estate_index:Emerging-Trends_USCanada-2023.pdf-!104']}},
#  {'category': 'SAME_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'What is the average size of a metro area in the Supernova category?'},
#   'ideal': {'paragraph': ['Like the astronomic source for its name, the five metro areas in the Supernova category markets have exploded into prominence over the past decade or so. All are smaller markets with 1 million to 2 million residents, but their defining attribute is their tremendous and sustained population and job growth, which are well above national averages.'],
#    'filename': ['Emerging-Trends_USCanada-2023.pdf'],
#    'ids': ['real_estate_index:Emerging-Trends_USCanada-2023.pdf-!129']}},
#  {'category': 'DIFFERENT_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'What is the typical population of a metropolitan area classified under the Supernova category?'},
#   'ideal': {'paragraph': ['Like the astronomic source for its name, the five metro areas in the Supernova category markets have exploded into prominence over the past decade or so. All are smaller markets with 1 million to 2 million residents, but their defining attribute is their tremendous and sustained population and job growth, which are well above national averages.'],
#    'filename': ['Emerging-Trends_USCanada-2023.pdf'],
#    'ids': ['real_estate_index:Emerging-Trends_USCanada-2023.pdf-!129']}},
#  {'category': 'SAME_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'What is the rate of the 18-Hour Cities in terms of economic output among the 12 subgroups?'},
#   'ideal': {'paragraph': ['As a group, the 18-Hour Cities rate third highest among the 12 subgroups, though the average market ranking fell this year as four of the markets declined while three rose. '],
#    'filename': ['Emerging-Trends_USCanada-2023.pdf'],
#    'ids': ['real_estate_index:Emerging-Trends_USCanada-2023.pdf-!129']}},
#  {'category': 'DIFFERENT_WORDING_ONE_PARAGRAPH',
#   'input': {'question': "What's the economic output ranking of the 18-Hour Cities among the 12 subgroups?"},
#   'ideal': {'paragraph': ['As a group, the 18-Hour Cities rate third highest among the 12 subgroups, though the average market ranking fell this year as four of the markets declined while three rose. '],
#    'filename': ['Emerging-Trends_USCanada-2023.pdf'],
#    'ids': ['real_estate_index:Emerging-Trends_USCanada-2023.pdf-!129']}},
#  {'category': 'SAME_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'What is the trend of tourist numbers?'},
#   'ideal': {'paragraph': ['Tourist numbers almost back to 2019 levels'],
#    'filename': ['2022-09-21_Immobilienmarkt_Deutschland_2022_2023_EN.pdf'],
#    'ids': ['real_estate_index:2022-09-21_Immobilienmarkt_Deutschland_2022_2023_EN.pdf-!29']}},
#  {'category': 'DIFFERENT_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'How are tourist numbers moving?'},
#   'ideal': {'paragraph': ['Tourist numbers almost back to 2019 levels'],
#    'filename': ['2022-09-21_Immobilienmarkt_Deutschland_2022_2023_EN.pdf'],
#    'ids': ['real_estate_index:2022-09-21_Immobilienmarkt_Deutschland_2022_2023_EN.pdf-!29']}},
#  {'category': 'SAME_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'What is the average monthly disposable income per household in Euro?'},
#   'ideal': {'paragraph': ['Average monthly disposable income per household: EUR 3,726 Euro'],
#    'filename': ['2022-09-21_Immobilienmarkt_Deutschland_2022_2023_EN.pdf'],
#    'ids': ['real_estate_index:2022-09-21_Immobilienmarkt_Deutschland_2022_2023_EN.pdf-!22']}},
#  {'category': 'DIFFERENT_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'What is the typical sum of money each household can expend monthly in the Eurozone?'},
#   'ideal': {'paragraph': ['Average monthly disposable income per household: EUR 3,726 Euro'],
#    'filename': ['2022-09-21_Immobilienmarkt_Deutschland_2022_2023_EN.pdf'],
#    'ids': ['real_estate_index:2022-09-21_Immobilienmarkt_Deutschland_2022_2023_EN.pdf-!22']}},
#  {'category': 'SAME_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'How has consumer sentiment been impacted by the war in Ukraine, inflation and the gas crisis?'},
#   'ideal': {'paragraph': ['The war in Ukraine, inflation and the gas crisis are key concerns for people. This is reflected in consumer sentiment which has fallen to a historic low.'],
#    'filename': ['2022-09-21_Immobilienmarkt_Deutschland_2022_2023_EN.pdf'],
#    'ids': ['real_estate_index:2022-09-21_Immobilienmarkt_Deutschland_2022_2023_EN.pdf-!22']}},
#  {'category': 'DIFFERENT_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'How did the Ukraine war, inflation and gas crisis affect consumer mood?'},
#   'ideal': {'paragraph': ['The war in Ukraine, inflation and the gas crisis are key concerns for people. This is reflected in consumer sentiment which has fallen to a historic low.'],
#    'filename': ['2022-09-21_Immobilienmarkt_Deutschland_2022_2023_EN.pdf'],
#    'ids': ['real_estate_index:2022-09-21_Immobilienmarkt_Deutschland_2022_2023_EN.pdf-!22']}},
#  {'category': 'SAME_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'When did new home prices peak?'},
#   'ideal': {'paragraph': ['New home prices peaked in April 2022, while prices of existing homes likely peaked in June after appreciation started to slow with the rise in mortgage rates.'],
#    'filename': ['Emerging-Trends_USCanada-2023.pdf'],
#    'ids': ['real_estate_index:Emerging-Trends_USCanada-2023.pdf-!11']}},
#  {'category': 'DIFFERENT_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'In which month did new home prices reach their highest point?'},
#   'ideal': {'paragraph': ['New home prices peaked in April 2022, while prices of existing homes likely peaked in June after appreciation started to slow with the rise in mortgage rates.'],
#    'filename': ['Emerging-Trends_USCanada-2023.pdf'],
#    'ids': ['real_estate_index:Emerging-Trends_USCanada-2023.pdf-!11']}},
#  {'category': 'SAME_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'What is the phone number of DZ HYP AG?'},
#   'ideal': {'paragraph': ['DZ HYP AG Rosenstrasse 2 20095 Hamburg Germany Phone 49 40 3334-0 dzhyp.'],
#    'filename': ['2022-09-21_Immobilienmarkt_Deutschland_2022_2023_EN.pdf'],
#    'ids': ['real_estate_index:2022-09-21_Immobilienmarkt_Deutschland_2022_2023_EN.pdf-!90']}},
#  {'category': 'DIFFERENT_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'What is the contact number for DZ HYP AG?'},
#   'ideal': {'paragraph': ['DZ HYP AG Rosenstrasse 2 20095 Hamburg Germany Phone 49 40 3334-0 dzhyp.'],
#    'filename': ['2022-09-21_Immobilienmarkt_Deutschland_2022_2023_EN.pdf'],
#    'ids': ['real_estate_index:2022-09-21_Immobilienmarkt_Deutschland_2022_2023_EN.pdf-!90']}},
#  {'category': 'SAME_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'How much does the U.S. apartment property sector contribute annually to the U.S. economy according to the NMHC?'},
#   'ideal': {'paragraph': ['The U. S. apartment property sectorproviding shelter to 37 mil- lion residents in 21.3 million structures of five or more household units, and contributing $3.4 trillion annually to the U. S. economy, according to the NMHC'],
#    'filename': ['Emerging-Trends_USCanada-2023.pdf'],
#    'ids': ['real_estate_index:Emerging-Trends_USCanada-2023.pdf-!68']}},
#  {'category': 'DIFFERENT_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'What annual contribution does the U.S. apartment property sector make to the U.S. economy as per the NMHC?'},
#   'ideal': {'paragraph': ['The U. S. apartment property sectorproviding shelter to 37 mil- lion residents in 21.3 million structures of five or more household units, and contributing $3.4 trillion annually to the U. S. economy, according to the NMHC'],
#    'filename': ['Emerging-Trends_USCanada-2023.pdf'],
#    'ids': ['real_estate_index:Emerging-Trends_USCanada-2023.pdf-!68']}},
#  {'category': 'SAME_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'How much higher was the number of new units authorized in multifamily buildings over the past 12 months as of June 2022 compared to the same period in 2018-2019, as per a Bloomberg report?'},
#   'ideal': {'paragraph': ['According to a recent Bloomberg report, After dipping in 2020, the number of new units authorized in multifamily build- ings took off, running 37 percent higher over the past 12 months as of June 2022 than in the same period in 20182019. '],
#    'filename': ['Emerging-Trends_USCanada-2023.pdf'],
#    'ids': ['real_estate_index:Emerging-Trends_USCanada-2023.pdf-!68']}},
#  {'category': 'DIFFERENT_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'By what percentage was the authorization of new units in multifamily buildings higher over the last 12 months up to June 2022, in comparison with the same period in 2018-2019, according to a Bloomberg report?'},
#   'ideal': {'paragraph': ['According to a recent Bloomberg report, After dipping in 2020, the number of new units authorized in multifamily build- ings took off, running 37 percent higher over the past 12 months as of June 2022 than in the same period in 20182019. '],
#    'filename': ['Emerging-Trends_USCanada-2023.pdf'],
#    'ids': ['real_estate_index:Emerging-Trends_USCanada-2023.pdf-!68']}},
#  {'category': 'SAME_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'What percentage increase in apartments under construction was observed as of August, compared to a year ago?'},
#   'ideal': {'paragraph': ['As of August, 862,000 apartments were under construction, up 25 percent from a year ago.'],
#    'filename': ['Emerging-Trends_USCanada-2023.pdf'],
#    'ids': ['real_estate_index:Emerging-Trends_USCanada-2023.pdf-!68']}},
#  {'category': 'DIFFERENT_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'What was the year-on-year growth rate in apartments under construction as of August?'},
#   'ideal': {'paragraph': ['As of August, 862,000 apartments were under construction, up 25 percent from a year ago.'],
#    'filename': ['Emerging-Trends_USCanada-2023.pdf'],
#    'ids': ['real_estate_index:Emerging-Trends_USCanada-2023.pdf-!68']}},
#  {'category': 'SAME_WORDING_ONE_PARAGRAPH',
#   'input': {'question': "What percentage increase did renters making at least $75,000 see over the decade ending just before the pandemic, according to Harvard's Joint Center for Housing Studies (JCHS)?"},
#   'ideal': {'paragraph': ['According to Harvards Joint Center for Housing Studies (JCHS), the number of renters making at least $75,000 jumped by 48 percent over the decade ending just before the pandemic, to 11.3 million.'],
#    'filename': ['Emerging-Trends_USCanada-2023.pdf'],
#    'ids': ['real_estate_index:Emerging-Trends_USCanada-2023.pdf-!69']}},
#  {'category': 'DIFFERENT_WORDING_ONE_PARAGRAPH',
#   'input': {'question': "By what percentage did the number of renters earning at least $75,000 increase over the decade ending just before the pandemic, as per the Harvard's Joint Center for Housing Studies (JCHS)?"},
#   'ideal': {'paragraph': ['According to Harvards Joint Center for Housing Studies (JCHS), the number of renters making at least $75,000 jumped by 48 percent over the decade ending just before the pandemic, to 11.3 million.'],
#    'filename': ['Emerging-Trends_USCanada-2023.pdf'],
#    'ids': ['real_estate_index:Emerging-Trends_USCanada-2023.pdf-!69']}},
#  {'category': 'SAME_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'Who is Jeff Smith?'},
#   'ideal': {'paragraph': ["Jeff Smith is Deloitte's National Real Estate leader with nearly 30 years of audit and accounting experience."],
#    'filename': ['Deloitte 2023 Commercial Real Estate Outlook.pdf'],
#    'ids': ['real_estate_index:Deloitte 2023 Commercial Real Estate Outlook.pdf-!33']}},
#  {'category': 'DIFFERENT_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'In what capacity does Jeff Smith serve?'},
#   'ideal': {'paragraph': ["Jeff Smith is Deloitte's National Real Estate leader with nearly 30 years of audit and accounting experience."],
#    'filename': ['Deloitte 2023 Commercial Real Estate Outlook.pdf'],
#    'ids': ['real_estate_index:Deloitte 2023 Commercial Real Estate Outlook.pdf-!33']}}]

# %%
# save the retriever rows to a jsonl file with the current date as the filename
import datetime
import jsonlines
with jsonlines.open(f"retriever_dataset_{datetime.datetime.now().strftime('%Y%m%d')}.jsonl", "w") as writer:
    writer.write_all(retriever_rows)

# %% [markdown]
# ## Create the generator dataset

# %%
dataset = json.load(bf.BlobFile("all_dataset_final.json", "rb"))
generator_rows = []
for datapoint in dataset:
    if datapoint["category"] == "NOT_SOURCE_BASED":
        continue
    row = {
        "category": datapoint["category"],
        "input": {
            "question": datapoint["question"],
            "sources": datapoint["paragraph"]
        },
        "ideal": {
            "answer": datapoint["answer"],
            "sentences": datapoint["sentences"] if "sentences" and len(datapoint["sentences"]) > 0 else [],
        }
    }
    generator_rows.append(row)
generator_rows
# Out:
# [{'category': 'SAME_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Did the number of new units authorized in multifamily buildings and the number of single-family housing starts trend in the same direction in 2022?',
#    'sources': [{'key': 'real_estate_index:Emerging-Trends_USCanada-2023.pdf-!26',
#      'text': ' One reason: existing tax laws are stacked against the individual homebuyer. Explains one academic, Investors are allowed to not only deduct everything, but also they can depreciate the unit. They also have access to lower cost of capital. In sum, institutional buyers assembling horizontal apartment portfolios can afford to pay more to be the high bidder for homes. And they do. Investors account for one in five homebuyers, up by a third compared with before the pandemic. Another supply constraint is homebuilders cautious construc- tion pacing, a vestige of the last recession. Explains the director of an investment institute who developed housing earlier in his career, A lot of the homebuilders, when the Great Recession happened, were stuck with inventory, said, Were not doing that again. Were going to build 10 new units, and as they sell, well start the next one, etc. And then labor shortages are compounding the problems. The construction sector as a whole hasnt returned to the peak we saw prior to the Great Recession. We saw a lot of that labor leave the sector for something maybe perceived more stable, says the economist for a housing advisory firm. All these factors are conspiring to limit housing construction far below population growth. In fact, the number of single-family housing starts in the last decade (20102019) relative to house- hold formations was the lowest since the government began tracking these trends and half as much or less than in preced- ing decades, despite the consistent increase in deliveries since bottoming in 2010. And now both permits and housing starts have been trending down again in 2022. Plunging homebuilder 13 Exhibit 1-11 Average Cost of Regulation as a Percentage of Total Multifamily Development Cost Total: 40.6 0.5 2.4 2.6 2.7 3.2 4.4 5.4 Pure cost of delay Cost of land dedicated to the government or left unbuilt Complying with OSHAother labor regulations Affordability mandates Cost of applying for zoning approval Fees charged when building construction is authorized Development requirements beyond the ordinary 8.5 Costs when site work begins 11.',
#      'filename': 'Emerging-Trends_USCanada-2023.pdf',
#      'page': 16,
#      'Cluster': 64},
#     {'key': 'real_estate_index:Emerging-Trends_USCanada-2023.pdf-!68',
#      'text': '  Two, demand gathered speed and sweep as people sought larger living spaces to balance remote work and household life, and more outdoor living options.  Three, constrained construction of new supply, and a price run-up on the single-family for-sale front, spilled over into expanded apartment demand.  Lastly, compounding the effects of these four dramatic imbalances came the rocket fuel of a global capital rotation toward de-risked assets . Outsized demand, a sudden spike in remote work mobility, constricted supply, and floods of money with nowhere better to goa grand slam of anomalies. The U. S. apartment property sectorproviding shelter to 37 mil- lion residents in 21.3 million structures of five or more household units, and contributing $3.4 trillion annually to the U. S. economy, according to the NMHCmorphed quickly into an investment asset class pressure cooker. Inflated property valuations, com- pressed cap rates, and a sea change from individual owners to medium and large-sized corporate owners became a new norm seemingly overnight. This time period veers wildly from a steady slope of otherwise well-entrenched trends across the structural demand front. Operational modernization kicked into super-fast-forward mode toward self-service, and a robust new-development pipeline at least. According to a recent Bloomberg report, After dipping in 2020, the number of new units authorized in multifamily build- ings took off, running 37 percent higher over the past 12 months as of June 2022 than in the same period in 20182019. As of August, 862,000 apartments were under construction, up 25 percent from a year ago. At the same time, COVIDs aftermath sharply defined conflicting forceswhich together destine virtually all of Americas newly developed and built apartment communities for a financially privileged professional class. Rather than causing an expansion of rental housing stock, however, higher-income households come-lately demand for rental neighborhoods instead served to crowd out moderate- and lower-income households in supply- constrained areas. Its been virtually impossible to build affordable, says the chief executive of one of the apartment industry trade groups.',
#      'filename': 'Emerging-Trends_USCanada-2023.pdf',
#      'page': 39,
#      'Cluster': 64}]},
#   'ideal': {'answer': 'No',
#    'sentences': ['As of August, 862,000 apartments were under construction, up 25 percent from a year ago.',
#     'And now both permits and housing starts have been trending down again in 2022.']}},
#  {'category': 'DIFFERENT_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Did the growth trajectory of new apartment complexes align with the initiation of single-dwelling constructions in 2022?',
#    'sources': [{'key': 'real_estate_index:Emerging-Trends_USCanada-2023.pdf-!26',
#      'text': ' One reason: existing tax laws are stacked against the individual homebuyer. Explains one academic, Investors are allowed to not only deduct everything, but also they can depreciate the unit. They also have access to lower cost of capital. In sum, institutional buyers assembling horizontal apartment portfolios can afford to pay more to be the high bidder for homes. And they do. Investors account for one in five homebuyers, up by a third compared with before the pandemic. Another supply constraint is homebuilders cautious construc- tion pacing, a vestige of the last recession. Explains the director of an investment institute who developed housing earlier in his career, A lot of the homebuilders, when the Great Recession happened, were stuck with inventory, said, Were not doing that again. Were going to build 10 new units, and as they sell, well start the next one, etc. And then labor shortages are compounding the problems. The construction sector as a whole hasnt returned to the peak we saw prior to the Great Recession. We saw a lot of that labor leave the sector for something maybe perceived more stable, says the economist for a housing advisory firm. All these factors are conspiring to limit housing construction far below population growth. In fact, the number of single-family housing starts in the last decade (20102019) relative to house- hold formations was the lowest since the government began tracking these trends and half as much or less than in preced- ing decades, despite the consistent increase in deliveries since bottoming in 2010. And now both permits and housing starts have been trending down again in 2022. Plunging homebuilder 13 Exhibit 1-11 Average Cost of Regulation as a Percentage of Total Multifamily Development Cost Total: 40.6 0.5 2.4 2.6 2.7 3.2 4.4 5.4 Pure cost of delay Cost of land dedicated to the government or left unbuilt Complying with OSHAother labor regulations Affordability mandates Cost of applying for zoning approval Fees charged when building construction is authorized Development requirements beyond the ordinary 8.5 Costs when site work begins 11.',
#      'filename': 'Emerging-Trends_USCanada-2023.pdf',
#      'page': 16,
#      'Cluster': 64},
#     {'key': 'real_estate_index:Emerging-Trends_USCanada-2023.pdf-!68',
#      'text': '  Two, demand gathered speed and sweep as people sought larger living spaces to balance remote work and household life, and more outdoor living options.  Three, constrained construction of new supply, and a price run-up on the single-family for-sale front, spilled over into expanded apartment demand.  Lastly, compounding the effects of these four dramatic imbalances came the rocket fuel of a global capital rotation toward de-risked assets . Outsized demand, a sudden spike in remote work mobility, constricted supply, and floods of money with nowhere better to goa grand slam of anomalies. The U. S. apartment property sectorproviding shelter to 37 mil- lion residents in 21.3 million structures of five or more household units, and contributing $3.4 trillion annually to the U. S. economy, according to the NMHCmorphed quickly into an investment asset class pressure cooker. Inflated property valuations, com- pressed cap rates, and a sea change from individual owners to medium and large-sized corporate owners became a new norm seemingly overnight. This time period veers wildly from a steady slope of otherwise well-entrenched trends across the structural demand front. Operational modernization kicked into super-fast-forward mode toward self-service, and a robust new-development pipeline at least. According to a recent Bloomberg report, After dipping in 2020, the number of new units authorized in multifamily build- ings took off, running 37 percent higher over the past 12 months as of June 2022 than in the same period in 20182019. As of August, 862,000 apartments were under construction, up 25 percent from a year ago. At the same time, COVIDs aftermath sharply defined conflicting forceswhich together destine virtually all of Americas newly developed and built apartment communities for a financially privileged professional class. Rather than causing an expansion of rental housing stock, however, higher-income households come-lately demand for rental neighborhoods instead served to crowd out moderate- and lower-income households in supply- constrained areas. Its been virtually impossible to build affordable, says the chief executive of one of the apartment industry trade groups.',
#      'filename': 'Emerging-Trends_USCanada-2023.pdf',
#      'page': 39,
#      'Cluster': 64}]},
#   'ideal': {'answer': 'No',
#    'sentences': ['As of August, 862,000 apartments were under construction, up 25 percent from a year ago.',
#     'And now both permits and housing starts have been trending down again in 2022.']}},
#  {'category': 'SAME_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Is the current demand for larger living spaces caused by the existing tax laws for individual homebuyer?',
#    'sources': [{'key': 'real_estate_index:Emerging-Trends_USCanada-2023.pdf-!26',
#      'text': ' One reason: existing tax laws are stacked against the individual homebuyer. Explains one academic, Investors are allowed to not only deduct everything, but also they can depreciate the unit. They also have access to lower cost of capital. In sum, institutional buyers assembling horizontal apartment portfolios can afford to pay more to be the high bidder for homes. And they do. Investors account for one in five homebuyers, up by a third compared with before the pandemic. Another supply constraint is homebuilders cautious construc- tion pacing, a vestige of the last recession. Explains the director of an investment institute who developed housing earlier in his career, A lot of the homebuilders, when the Great Recession happened, were stuck with inventory, said, Were not doing that again. Were going to build 10 new units, and as they sell, well start the next one, etc. And then labor shortages are compounding the problems. The construction sector as a whole hasnt returned to the peak we saw prior to the Great Recession. We saw a lot of that labor leave the sector for something maybe perceived more stable, says the economist for a housing advisory firm. All these factors are conspiring to limit housing construction far below population growth. In fact, the number of single-family housing starts in the last decade (20102019) relative to house- hold formations was the lowest since the government began tracking these trends and half as much or less than in preced- ing decades, despite the consistent increase in deliveries since bottoming in 2010. And now both permits and housing starts have been trending down again in 2022. Plunging homebuilder 13 Exhibit 1-11 Average Cost of Regulation as a Percentage of Total Multifamily Development Cost Total: 40.6 0.5 2.4 2.6 2.7 3.2 4.4 5.4 Pure cost of delay Cost of land dedicated to the government or left unbuilt Complying with OSHAother labor regulations Affordability mandates Cost of applying for zoning approval Fees charged when building construction is authorized Development requirements beyond the ordinary 8.5 Costs when site work begins 11.',
#      'filename': 'Emerging-Trends_USCanada-2023.pdf',
#      'page': 16,
#      'Cluster': 64},
#     {'key': 'real_estate_index:Emerging-Trends_USCanada-2023.pdf-!68',
#      'text': '  Two, demand gathered speed and sweep as people sought larger living spaces to balance remote work and household life, and more outdoor living options.  Three, constrained construction of new supply, and a price run-up on the single-family for-sale front, spilled over into expanded apartment demand.  Lastly, compounding the effects of these four dramatic imbalances came the rocket fuel of a global capital rotation toward de-risked assets . Outsized demand, a sudden spike in remote work mobility, constricted supply, and floods of money with nowhere better to goa grand slam of anomalies. The U. S. apartment property sectorproviding shelter to 37 mil- lion residents in 21.3 million structures of five or more household units, and contributing $3.4 trillion annually to the U. S. economy, according to the NMHCmorphed quickly into an investment asset class pressure cooker. Inflated property valuations, com- pressed cap rates, and a sea change from individual owners to medium and large-sized corporate owners became a new norm seemingly overnight. This time period veers wildly from a steady slope of otherwise well-entrenched trends across the structural demand front. Operational modernization kicked into super-fast-forward mode toward self-service, and a robust new-development pipeline at least. According to a recent Bloomberg report, After dipping in 2020, the number of new units authorized in multifamily build- ings took off, running 37 percent higher over the past 12 months as of June 2022 than in the same period in 20182019. As of August, 862,000 apartments were under construction, up 25 percent from a year ago. At the same time, COVIDs aftermath sharply defined conflicting forceswhich together destine virtually all of Americas newly developed and built apartment communities for a financially privileged professional class. Rather than causing an expansion of rental housing stock, however, higher-income households come-lately demand for rental neighborhoods instead served to crowd out moderate- and lower-income households in supply- constrained areas. Its been virtually impossible to build affordable, says the chief executive of one of the apartment industry trade groups.',
#      'filename': 'Emerging-Trends_USCanada-2023.pdf',
#      'page': 39,
#      'Cluster': 64}]},
#   'ideal': {'answer': 'No',
#    'sentences': ['Two, demand gathered speed and sweep as people sought larger living spaces to balance remote work and household life, and more outdoor living options.',
#     'One reason: existing tax laws are stacked against the individual homebuyer.']}},
#  {'category': 'DIFFERENT_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Are the existing regulations related to individual property taxation driving the present trend towards bigger homes?',
#    'sources': [{'key': 'real_estate_index:Emerging-Trends_USCanada-2023.pdf-!26',
#      'text': ' One reason: existing tax laws are stacked against the individual homebuyer. Explains one academic, Investors are allowed to not only deduct everything, but also they can depreciate the unit. They also have access to lower cost of capital. In sum, institutional buyers assembling horizontal apartment portfolios can afford to pay more to be the high bidder for homes. And they do. Investors account for one in five homebuyers, up by a third compared with before the pandemic. Another supply constraint is homebuilders cautious construc- tion pacing, a vestige of the last recession. Explains the director of an investment institute who developed housing earlier in his career, A lot of the homebuilders, when the Great Recession happened, were stuck with inventory, said, Were not doing that again. Were going to build 10 new units, and as they sell, well start the next one, etc. And then labor shortages are compounding the problems. The construction sector as a whole hasnt returned to the peak we saw prior to the Great Recession. We saw a lot of that labor leave the sector for something maybe perceived more stable, says the economist for a housing advisory firm. All these factors are conspiring to limit housing construction far below population growth. In fact, the number of single-family housing starts in the last decade (20102019) relative to house- hold formations was the lowest since the government began tracking these trends and half as much or less than in preced- ing decades, despite the consistent increase in deliveries since bottoming in 2010. And now both permits and housing starts have been trending down again in 2022. Plunging homebuilder 13 Exhibit 1-11 Average Cost of Regulation as a Percentage of Total Multifamily Development Cost Total: 40.6 0.5 2.4 2.6 2.7 3.2 4.4 5.4 Pure cost of delay Cost of land dedicated to the government or left unbuilt Complying with OSHAother labor regulations Affordability mandates Cost of applying for zoning approval Fees charged when building construction is authorized Development requirements beyond the ordinary 8.5 Costs when site work begins 11.',
#      'filename': 'Emerging-Trends_USCanada-2023.pdf',
#      'page': 16,
#      'Cluster': 64},
#     {'key': 'real_estate_index:Emerging-Trends_USCanada-2023.pdf-!68',
#      'text': '  Two, demand gathered speed and sweep as people sought larger living spaces to balance remote work and household life, and more outdoor living options.  Three, constrained construction of new supply, and a price run-up on the single-family for-sale front, spilled over into expanded apartment demand.  Lastly, compounding the effects of these four dramatic imbalances came the rocket fuel of a global capital rotation toward de-risked assets . Outsized demand, a sudden spike in remote work mobility, constricted supply, and floods of money with nowhere better to goa grand slam of anomalies. The U. S. apartment property sectorproviding shelter to 37 mil- lion residents in 21.3 million structures of five or more household units, and contributing $3.4 trillion annually to the U. S. economy, according to the NMHCmorphed quickly into an investment asset class pressure cooker. Inflated property valuations, com- pressed cap rates, and a sea change from individual owners to medium and large-sized corporate owners became a new norm seemingly overnight. This time period veers wildly from a steady slope of otherwise well-entrenched trends across the structural demand front. Operational modernization kicked into super-fast-forward mode toward self-service, and a robust new-development pipeline at least. According to a recent Bloomberg report, After dipping in 2020, the number of new units authorized in multifamily build- ings took off, running 37 percent higher over the past 12 months as of June 2022 than in the same period in 20182019. As of August, 862,000 apartments were under construction, up 25 percent from a year ago. At the same time, COVIDs aftermath sharply defined conflicting forceswhich together destine virtually all of Americas newly developed and built apartment communities for a financially privileged professional class. Rather than causing an expansion of rental housing stock, however, higher-income households come-lately demand for rental neighborhoods instead served to crowd out moderate- and lower-income households in supply- constrained areas. Its been virtually impossible to build affordable, says the chief executive of one of the apartment industry trade groups.',
#      'filename': 'Emerging-Trends_USCanada-2023.pdf',
#      'page': 39,
#      'Cluster': 64}]},
#   'ideal': {'answer': 'No',
#    'sentences': ['Two, demand gathered speed and sweep as people sought larger living spaces to balance remote work and household life, and more outdoor living options.',
#     'One reason: existing tax laws are stacked against the individual homebuyer.']}},
#  {'category': 'SAME_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Was the constrained construction of new supply a consequence of labor shortages and cautious construction pacing from homebuilders?',
#    'sources': [{'key': 'real_estate_index:Emerging-Trends_USCanada-2023.pdf-!26',
#      'text': ' One reason: existing tax laws are stacked against the individual homebuyer. Explains one academic, Investors are allowed to not only deduct everything, but also they can depreciate the unit. They also have access to lower cost of capital. In sum, institutional buyers assembling horizontal apartment portfolios can afford to pay more to be the high bidder for homes. And they do. Investors account for one in five homebuyers, up by a third compared with before the pandemic. Another supply constraint is homebuilders cautious construc- tion pacing, a vestige of the last recession. Explains the director of an investment institute who developed housing earlier in his career, A lot of the homebuilders, when the Great Recession happened, were stuck with inventory, said, Were not doing that again. Were going to build 10 new units, and as they sell, well start the next one, etc. And then labor shortages are compounding the problems. The construction sector as a whole hasnt returned to the peak we saw prior to the Great Recession. We saw a lot of that labor leave the sector for something maybe perceived more stable, says the economist for a housing advisory firm. All these factors are conspiring to limit housing construction far below population growth. In fact, the number of single-family housing starts in the last decade (20102019) relative to house- hold formations was the lowest since the government began tracking these trends and half as much or less than in preced- ing decades, despite the consistent increase in deliveries since bottoming in 2010. And now both permits and housing starts have been trending down again in 2022. Plunging homebuilder 13 Exhibit 1-11 Average Cost of Regulation as a Percentage of Total Multifamily Development Cost Total: 40.6 0.5 2.4 2.6 2.7 3.2 4.4 5.4 Pure cost of delay Cost of land dedicated to the government or left unbuilt Complying with OSHAother labor regulations Affordability mandates Cost of applying for zoning approval Fees charged when building construction is authorized Development requirements beyond the ordinary 8.5 Costs when site work begins 11.',
#      'filename': 'Emerging-Trends_USCanada-2023.pdf',
#      'page': 16,
#      'Cluster': 64},
#     {'key': 'real_estate_index:Emerging-Trends_USCanada-2023.pdf-!68',
#      'text': '  Two, demand gathered speed and sweep as people sought larger living spaces to balance remote work and household life, and more outdoor living options.  Three, constrained construction of new supply, and a price run-up on the single-family for-sale front, spilled over into expanded apartment demand.  Lastly, compounding the effects of these four dramatic imbalances came the rocket fuel of a global capital rotation toward de-risked assets . Outsized demand, a sudden spike in remote work mobility, constricted supply, and floods of money with nowhere better to goa grand slam of anomalies. The U. S. apartment property sectorproviding shelter to 37 mil- lion residents in 21.3 million structures of five or more household units, and contributing $3.4 trillion annually to the U. S. economy, according to the NMHCmorphed quickly into an investment asset class pressure cooker. Inflated property valuations, com- pressed cap rates, and a sea change from individual owners to medium and large-sized corporate owners became a new norm seemingly overnight. This time period veers wildly from a steady slope of otherwise well-entrenched trends across the structural demand front. Operational modernization kicked into super-fast-forward mode toward self-service, and a robust new-development pipeline at least. According to a recent Bloomberg report, After dipping in 2020, the number of new units authorized in multifamily build- ings took off, running 37 percent higher over the past 12 months as of June 2022 than in the same period in 20182019. As of August, 862,000 apartments were under construction, up 25 percent from a year ago. At the same time, COVIDs aftermath sharply defined conflicting forceswhich together destine virtually all of Americas newly developed and built apartment communities for a financially privileged professional class. Rather than causing an expansion of rental housing stock, however, higher-income households come-lately demand for rental neighborhoods instead served to crowd out moderate- and lower-income households in supply- constrained areas. Its been virtually impossible to build affordable, says the chief executive of one of the apartment industry trade groups.',
#      'filename': 'Emerging-Trends_USCanada-2023.pdf',
#      'page': 39,
#      'Cluster': 64}]},
#   'ideal': {'answer': 'Yes',
#    'sentences': ['Three, constrained construction of new supply, and a price run-up on the single-family for-sale front, spilled over into expanded apartment demand.',
#     'Another supply constraint is homebuilders cautious construc- tion pacing, a vestige of the last recession.',
#     'And then labor shortages are compounding the problems.']}},
#  {'category': 'DIFFERENT_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': "Are the limitations in new housing production attributed to workforce scarcity and builders' prudent construction speed?",
#    'sources': [{'key': 'real_estate_index:Emerging-Trends_USCanada-2023.pdf-!26',
#      'text': ' One reason: existing tax laws are stacked against the individual homebuyer. Explains one academic, Investors are allowed to not only deduct everything, but also they can depreciate the unit. They also have access to lower cost of capital. In sum, institutional buyers assembling horizontal apartment portfolios can afford to pay more to be the high bidder for homes. And they do. Investors account for one in five homebuyers, up by a third compared with before the pandemic. Another supply constraint is homebuilders cautious construc- tion pacing, a vestige of the last recession. Explains the director of an investment institute who developed housing earlier in his career, A lot of the homebuilders, when the Great Recession happened, were stuck with inventory, said, Were not doing that again. Were going to build 10 new units, and as they sell, well start the next one, etc. And then labor shortages are compounding the problems. The construction sector as a whole hasnt returned to the peak we saw prior to the Great Recession. We saw a lot of that labor leave the sector for something maybe perceived more stable, says the economist for a housing advisory firm. All these factors are conspiring to limit housing construction far below population growth. In fact, the number of single-family housing starts in the last decade (20102019) relative to house- hold formations was the lowest since the government began tracking these trends and half as much or less than in preced- ing decades, despite the consistent increase in deliveries since bottoming in 2010. And now both permits and housing starts have been trending down again in 2022. Plunging homebuilder 13 Exhibit 1-11 Average Cost of Regulation as a Percentage of Total Multifamily Development Cost Total: 40.6 0.5 2.4 2.6 2.7 3.2 4.4 5.4 Pure cost of delay Cost of land dedicated to the government or left unbuilt Complying with OSHAother labor regulations Affordability mandates Cost of applying for zoning approval Fees charged when building construction is authorized Development requirements beyond the ordinary 8.5 Costs when site work begins 11.',
#      'filename': 'Emerging-Trends_USCanada-2023.pdf',
#      'page': 16,
#      'Cluster': 64},
#     {'key': 'real_estate_index:Emerging-Trends_USCanada-2023.pdf-!68',
#      'text': '  Two, demand gathered speed and sweep as people sought larger living spaces to balance remote work and household life, and more outdoor living options.  Three, constrained construction of new supply, and a price run-up on the single-family for-sale front, spilled over into expanded apartment demand.  Lastly, compounding the effects of these four dramatic imbalances came the rocket fuel of a global capital rotation toward de-risked assets . Outsized demand, a sudden spike in remote work mobility, constricted supply, and floods of money with nowhere better to goa grand slam of anomalies. The U. S. apartment property sectorproviding shelter to 37 mil- lion residents in 21.3 million structures of five or more household units, and contributing $3.4 trillion annually to the U. S. economy, according to the NMHCmorphed quickly into an investment asset class pressure cooker. Inflated property valuations, com- pressed cap rates, and a sea change from individual owners to medium and large-sized corporate owners became a new norm seemingly overnight. This time period veers wildly from a steady slope of otherwise well-entrenched trends across the structural demand front. Operational modernization kicked into super-fast-forward mode toward self-service, and a robust new-development pipeline at least. According to a recent Bloomberg report, After dipping in 2020, the number of new units authorized in multifamily build- ings took off, running 37 percent higher over the past 12 months as of June 2022 than in the same period in 20182019. As of August, 862,000 apartments were under construction, up 25 percent from a year ago. At the same time, COVIDs aftermath sharply defined conflicting forceswhich together destine virtually all of Americas newly developed and built apartment communities for a financially privileged professional class. Rather than causing an expansion of rental housing stock, however, higher-income households come-lately demand for rental neighborhoods instead served to crowd out moderate- and lower-income households in supply- constrained areas. Its been virtually impossible to build affordable, says the chief executive of one of the apartment industry trade groups.',
#      'filename': 'Emerging-Trends_USCanada-2023.pdf',
#      'page': 39,
#      'Cluster': 64}]},
#   'ideal': {'answer': 'Yes',
#    'sentences': ['Three, constrained construction of new supply, and a price run-up on the single-family for-sale front, spilled over into expanded apartment demand.',
#     'Another supply constraint is homebuilders cautious construc- tion pacing, a vestige of the last recession.',
#     'And then labor shortages are compounding the problems.']}},
#  {'category': 'SAME_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Has the affordability of housing dropped in recent years, affecting both young and mid-career households?',
#    'sources': [{'key': 'real_estate_index:Emerging-Trends_USCanada-2023.pdf-!71',
#      'text': ' Class A property investments align with rent-by-choice higher- income households and a swelling population of aging Americans ready to downsize and simplify. B and C value-add investments suit a growing market of younger and mid-career households stuck in the limbo of scarce supply, high prices, and high interest mortgages that will delay their becoming homeowners. Closing a gaping, and widening, chasm in new investment and development would well serve households in the 80 to 120 percent range of area median household income levels the wage range of many essential workers such as teachers, sanitation workers, law enforcement officers, and fire and medical first responders. Furthermore, addressing this missing middle household income level does not preclude the need for additions to and preservation of properties for lower-income households. The Great Bottleneck: Local Ballot Boxes Apartment stakeholders number-one nemesis, blocking private- sector market solutions to deep and growing mismatches between demand and supply, is a many-headed hydraa bevy of deep-rooted restrictive land use, permitting, and regulatory cost burdens that thwart higher-density multifamily develop- ment. On top of these longstanding challenges, a growing push for rent regulation is adding uncertainty to the market. For example, while 26 states prohibit local municipalities from implementing rent control laws, five states permit localities to enforce rent controlNew York, New Jersey, California, Oregon, and Marylandas well as Washington, D. C. Regulations being proposed throughout the country would allow landlords to boost monthly rents by no more than 2 percent to 10 percent. Arizona, Florida, Hawaii, Illinois, Kentucky, New Jersey, New York, Washington, and Massachusetts have all introduced proposals to add or expand rent control protections. The problem of impact fees and NIMBYism really dominates many markets and makes it too expensive to develop, the CEO of one of the nations largest property management organizations says. I think were still stuck in the past. Some policymakers are not in tune. Voters who may not be well versed in these issues elect government officials who then become a huge wall to economic solutions. I dont see solutions for all this happening in my lifetime.',
#      'filename': 'Emerging-Trends_USCanada-2023.pdf',
#      'page': 41,
#      'Cluster': 64},
#     {'key': 'real_estate_index:bouwinvest_international-market-outlook_2023-2025-1.pdf-!3',
#      'text': ' The residential sector as a whole is a beneficiary of the ongoing trend of urbanisation in major cities across Europe. Wealth tends to be concentrated in larger urban centres with better employment opportunities where the average age of the working population is lower than in regional and more remote communities. Demand for living assets remains strong in most urbanised areas due to demographic growth and the rising number of households, boosted by immigration and the expanding number of younger and older people living alone. The volume of new housing developments is also falling due to increasingly stringent environmental rules, shortages of materials and rising labour costs. Demand continues to outstrip supply, especially in the affordable segment. If the number of new-build projects continues to decline, the valuations of existing stock may hold up relatively well. Increases in mortgage rates mean home ownership will move out of reach of a growing group of people, forcing them to turn to the rental market for accommodation that fits their budgets. Residential real estate is seen as a relatively good inflation hedge as most rental contracts are index-linked but, in our view, it will not be possible to pass on the full level of consumer price rises to tenants. Governments in many countries are implementing measures to offset energy price hikes or cap rental increases to support the purchasing power of people living in social housing and other low- to middle-income tenants. Rising 10-year government bond yields will simultaneously pressure spread levels and yields will move out. This is demonstrated in the graph below which tracks the expected development of residential net initial yields against 10-year government bond levels for the leading European gateway cities.',
#      'filename': 'bouwinvest_international-market-outlook_2023-2025-1.pdf',
#      'page': 7,
#      'Cluster': 64}]},
#   'ideal': {'answer': 'Yes',
#    'sentences': ['Housing affordability has fallen to its lowest level in over 30 years. Prices and rents have soared relative to incomes. Spiraling mortgage rates have pushed the homeownership bar further out of reach for a growing share of households.',
#     'B and C value-add investments suit a growing market of younger and mid-career households stuck in the limbo of scarce supply, high prices, and high interest mortgages that will delay their becoming homeowners.']}},
#  {'category': 'DIFFERENT_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Has there been a recent decline in housing affordability, impacting households in their early and middle stages of their careers?',
#    'sources': [{'key': 'real_estate_index:Emerging-Trends_USCanada-2023.pdf-!71',
#      'text': ' Class A property investments align with rent-by-choice higher- income households and a swelling population of aging Americans ready to downsize and simplify. B and C value-add investments suit a growing market of younger and mid-career households stuck in the limbo of scarce supply, high prices, and high interest mortgages that will delay their becoming homeowners. Closing a gaping, and widening, chasm in new investment and development would well serve households in the 80 to 120 percent range of area median household income levels the wage range of many essential workers such as teachers, sanitation workers, law enforcement officers, and fire and medical first responders. Furthermore, addressing this missing middle household income level does not preclude the need for additions to and preservation of properties for lower-income households. The Great Bottleneck: Local Ballot Boxes Apartment stakeholders number-one nemesis, blocking private- sector market solutions to deep and growing mismatches between demand and supply, is a many-headed hydraa bevy of deep-rooted restrictive land use, permitting, and regulatory cost burdens that thwart higher-density multifamily develop- ment. On top of these longstanding challenges, a growing push for rent regulation is adding uncertainty to the market. For example, while 26 states prohibit local municipalities from implementing rent control laws, five states permit localities to enforce rent controlNew York, New Jersey, California, Oregon, and Marylandas well as Washington, D. C. Regulations being proposed throughout the country would allow landlords to boost monthly rents by no more than 2 percent to 10 percent. Arizona, Florida, Hawaii, Illinois, Kentucky, New Jersey, New York, Washington, and Massachusetts have all introduced proposals to add or expand rent control protections. The problem of impact fees and NIMBYism really dominates many markets and makes it too expensive to develop, the CEO of one of the nations largest property management organizations says. I think were still stuck in the past. Some policymakers are not in tune. Voters who may not be well versed in these issues elect government officials who then become a huge wall to economic solutions. I dont see solutions for all this happening in my lifetime.',
#      'filename': 'Emerging-Trends_USCanada-2023.pdf',
#      'page': 41,
#      'Cluster': 64},
#     {'key': 'real_estate_index:bouwinvest_international-market-outlook_2023-2025-1.pdf-!3',
#      'text': ' The residential sector as a whole is a beneficiary of the ongoing trend of urbanisation in major cities across Europe. Wealth tends to be concentrated in larger urban centres with better employment opportunities where the average age of the working population is lower than in regional and more remote communities. Demand for living assets remains strong in most urbanised areas due to demographic growth and the rising number of households, boosted by immigration and the expanding number of younger and older people living alone. The volume of new housing developments is also falling due to increasingly stringent environmental rules, shortages of materials and rising labour costs. Demand continues to outstrip supply, especially in the affordable segment. If the number of new-build projects continues to decline, the valuations of existing stock may hold up relatively well. Increases in mortgage rates mean home ownership will move out of reach of a growing group of people, forcing them to turn to the rental market for accommodation that fits their budgets. Residential real estate is seen as a relatively good inflation hedge as most rental contracts are index-linked but, in our view, it will not be possible to pass on the full level of consumer price rises to tenants. Governments in many countries are implementing measures to offset energy price hikes or cap rental increases to support the purchasing power of people living in social housing and other low- to middle-income tenants. Rising 10-year government bond yields will simultaneously pressure spread levels and yields will move out. This is demonstrated in the graph below which tracks the expected development of residential net initial yields against 10-year government bond levels for the leading European gateway cities.',
#      'filename': 'bouwinvest_international-market-outlook_2023-2025-1.pdf',
#      'page': 7,
#      'Cluster': 64}]},
#   'ideal': {'answer': 'Yes',
#    'sentences': ['Housing affordability has fallen to its lowest level in over 30 years. Prices and rents have soared relative to incomes. Spiraling mortgage rates have pushed the homeownership bar further out of reach for a growing share of households.',
#     'B and C value-add investments suit a growing market of younger and mid-career households stuck in the limbo of scarce supply, high prices, and high interest mortgages that will delay their becoming homeowners.']}},
#  {'category': 'SAME_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Are high prices and high interest mortgages contributing to difficulties for people wanting to become homeowners?',
#    'sources': [{'key': 'real_estate_index:Emerging-Trends_USCanada-2023.pdf-!71',
#      'text': ' Class A property investments align with rent-by-choice higher- income households and a swelling population of aging Americans ready to downsize and simplify. B and C value-add investments suit a growing market of younger and mid-career households stuck in the limbo of scarce supply, high prices, and high interest mortgages that will delay their becoming homeowners. Closing a gaping, and widening, chasm in new investment and development would well serve households in the 80 to 120 percent range of area median household income levels the wage range of many essential workers such as teachers, sanitation workers, law enforcement officers, and fire and medical first responders. Furthermore, addressing this missing middle household income level does not preclude the need for additions to and preservation of properties for lower-income households. The Great Bottleneck: Local Ballot Boxes Apartment stakeholders number-one nemesis, blocking private- sector market solutions to deep and growing mismatches between demand and supply, is a many-headed hydraa bevy of deep-rooted restrictive land use, permitting, and regulatory cost burdens that thwart higher-density multifamily develop- ment. On top of these longstanding challenges, a growing push for rent regulation is adding uncertainty to the market. For example, while 26 states prohibit local municipalities from implementing rent control laws, five states permit localities to enforce rent controlNew York, New Jersey, California, Oregon, and Marylandas well as Washington, D. C. Regulations being proposed throughout the country would allow landlords to boost monthly rents by no more than 2 percent to 10 percent. Arizona, Florida, Hawaii, Illinois, Kentucky, New Jersey, New York, Washington, and Massachusetts have all introduced proposals to add or expand rent control protections. The problem of impact fees and NIMBYism really dominates many markets and makes it too expensive to develop, the CEO of one of the nations largest property management organizations says. I think were still stuck in the past. Some policymakers are not in tune. Voters who may not be well versed in these issues elect government officials who then become a huge wall to economic solutions. I dont see solutions for all this happening in my lifetime.',
#      'filename': 'Emerging-Trends_USCanada-2023.pdf',
#      'page': 41,
#      'Cluster': 64},
#     {'key': 'real_estate_index:bouwinvest_international-market-outlook_2023-2025-1.pdf-!3',
#      'text': ' The residential sector as a whole is a beneficiary of the ongoing trend of urbanisation in major cities across Europe. Wealth tends to be concentrated in larger urban centres with better employment opportunities where the average age of the working population is lower than in regional and more remote communities. Demand for living assets remains strong in most urbanised areas due to demographic growth and the rising number of households, boosted by immigration and the expanding number of younger and older people living alone. The volume of new housing developments is also falling due to increasingly stringent environmental rules, shortages of materials and rising labour costs. Demand continues to outstrip supply, especially in the affordable segment. If the number of new-build projects continues to decline, the valuations of existing stock may hold up relatively well. Increases in mortgage rates mean home ownership will move out of reach of a growing group of people, forcing them to turn to the rental market for accommodation that fits their budgets. Residential real estate is seen as a relatively good inflation hedge as most rental contracts are index-linked but, in our view, it will not be possible to pass on the full level of consumer price rises to tenants. Governments in many countries are implementing measures to offset energy price hikes or cap rental increases to support the purchasing power of people living in social housing and other low- to middle-income tenants. Rising 10-year government bond yields will simultaneously pressure spread levels and yields will move out. This is demonstrated in the graph below which tracks the expected development of residential net initial yields against 10-year government bond levels for the leading European gateway cities.',
#      'filename': 'bouwinvest_international-market-outlook_2023-2025-1.pdf',
#      'page': 7,
#      'Cluster': 64}]},
#   'ideal': {'answer': 'Yes',
#    'sentences': ['Housing affordability has fallen to its lowest level in over 30 years. Prices and rents have soared relative to incomes. Spiraling mortgage rates have pushed the homeownership bar further out of reach for a growing share of households.',
#     'B and C value-add investments suit a growing market of younger and mid-career households stuck in the limbo of scarce supply, high prices, and high interest mortgages that will delay their becoming homeowners.']}},
#  {'category': 'DIFFERENT_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Do steep costs and hefty interest rates on housing loans pose challenges for aspiring property owners?',
#    'sources': [{'key': 'real_estate_index:Emerging-Trends_USCanada-2023.pdf-!71',
# ...
#      'filename': 'Emerging-Trends_USCanada-2023.pdf',
#      'page': 39,
#      'Cluster': 64}]},
#   'ideal': {'answer': '25 percent',
#    'sentences': ['As of August, 862,000 apartments were under construction, up 25 percent from a year ago.']}},
#  {'category': 'DIFFERENT_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'What was the year-on-year growth rate in apartments under construction as of August?',
#    'sources': [{'key': 'real_estate_index:Emerging-Trends_USCanada-2023.pdf-!68',
#      'text': '  Two, demand gathered speed and sweep as people sought larger living spaces to balance remote work and household life, and more outdoor living options.  Three, constrained construction of new supply, and a price run-up on the single-family for-sale front, spilled over into expanded apartment demand.  Lastly, compounding the effects of these four dramatic imbalances came the rocket fuel of a global capital rotation toward de-risked assets . Outsized demand, a sudden spike in remote work mobility, constricted supply, and floods of money with nowhere better to goa grand slam of anomalies. The U. S. apartment property sectorproviding shelter to 37 mil- lion residents in 21.3 million structures of five or more household units, and contributing $3.4 trillion annually to the U. S. economy, according to the NMHCmorphed quickly into an investment asset class pressure cooker. Inflated property valuations, com- pressed cap rates, and a sea change from individual owners to medium and large-sized corporate owners became a new norm seemingly overnight. This time period veers wildly from a steady slope of otherwise well-entrenched trends across the structural demand front. Operational modernization kicked into super-fast-forward mode toward self-service, and a robust new-development pipeline at least. According to a recent Bloomberg report, After dipping in 2020, the number of new units authorized in multifamily build- ings took off, running 37 percent higher over the past 12 months as of June 2022 than in the same period in 20182019. As of August, 862,000 apartments were under construction, up 25 percent from a year ago. At the same time, COVIDs aftermath sharply defined conflicting forceswhich together destine virtually all of Americas newly developed and built apartment communities for a financially privileged professional class. Rather than causing an expansion of rental housing stock, however, higher-income households come-lately demand for rental neighborhoods instead served to crowd out moderate- and lower-income households in supply- constrained areas. Its been virtually impossible to build affordable, says the chief executive of one of the apartment industry trade groups.',
#      'filename': 'Emerging-Trends_USCanada-2023.pdf',
#      'page': 39,
#      'Cluster': 64}]},
#   'ideal': {'answer': '25 percent',
#    'sentences': ['As of August, 862,000 apartments were under construction, up 25 percent from a year ago.']}},
#  {'category': 'SAME_WORDING_ONE_PARAGRAPH',
#   'input': {'question': "What percentage increase did renters making at least $75,000 see over the decade ending just before the pandemic, according to Harvard's Joint Center for Housing Studies (JCHS)?",
#    'sources': [{'key': 'real_estate_index:Emerging-Trends_USCanada-2023.pdf-!69',
#      'text': ' You cant build ground-up affordable because of the price of land, and the regulations that govern that, and everything the NIMBY activists rule . . it all puts a real damper on the industrys ability to produce. In mid-2022, yet another freshly drawn inflection pointcoin- ciding with the devastation wrought by the Russia-Ukraine war and an aggressive U. S. monetary and fiscal tightening effort to dial down inflationquickly spread the pain of a cost-of-living crisis across Americas households. In addition, it casts a new cloud of uncertainty over the near-term outlook for market-rate residential investment. The Push and Pull of Trends: Rentership Rising Broad-stroke household demographics point irrefutably to strong secular demand for multifamily rental apartment development. During the 2022-to-2035 stretch that lies ahead, 275 million adults the total of all the adult-aged generational cohortswill continue to make shelter decisions, especially as U. S. domes- tic migration and mobility continues at over 27 million movers each year. Financial factorsgiven that runaway costs and high mortgage interest rates will price more households out of homeownership as an optionwill determine many of their decisions, as has long been the case. What is different over the past several years has been growth in discretionary rental households, also known as rent-by-choice households. According to Harvards Joint Center for Housing Studies (JCHS), the number of renters making at least $75,000 jumped by 48 percent over the decade ending just before the pandemic, to 11.3 million. With this increase, the share of renter households in this income group rose from 20 percent to 26 percent. Younger, older, and more economically, racially, and culturally diverse households together will bend the economic and cultural arc of rentership upward. Apartment industry leaders now recognize a blurring of behav- ioral lines across generations. When it comes to housing type need or preference, generational cohortsgeneration Z, millen- nials, generation X, and empty-nester baby boomersact more like each other than not.',
#      'filename': 'Emerging-Trends_USCanada-2023.pdf',
#      'page': 40,
#      'Cluster': 64}]},
#   'ideal': {'answer': '48 percent',
#    'sentences': ['According to Harvards Joint Center for Housing Studies (JCHS), the number of renters making at least $75,000 jumped by 48 percent over the decade ending just before the pandemic, to 11.3 million.']}},
#  {'category': 'DIFFERENT_WORDING_ONE_PARAGRAPH',
#   'input': {'question': "By what percentage did the number of renters earning at least $75,000 increase over the decade ending just before the pandemic, as per the Harvard's Joint Center for Housing Studies (JCHS)?",
#    'sources': [{'key': 'real_estate_index:Emerging-Trends_USCanada-2023.pdf-!69',
#      'text': ' You cant build ground-up affordable because of the price of land, and the regulations that govern that, and everything the NIMBY activists rule . . it all puts a real damper on the industrys ability to produce. In mid-2022, yet another freshly drawn inflection pointcoin- ciding with the devastation wrought by the Russia-Ukraine war and an aggressive U. S. monetary and fiscal tightening effort to dial down inflationquickly spread the pain of a cost-of-living crisis across Americas households. In addition, it casts a new cloud of uncertainty over the near-term outlook for market-rate residential investment. The Push and Pull of Trends: Rentership Rising Broad-stroke household demographics point irrefutably to strong secular demand for multifamily rental apartment development. During the 2022-to-2035 stretch that lies ahead, 275 million adults the total of all the adult-aged generational cohortswill continue to make shelter decisions, especially as U. S. domes- tic migration and mobility continues at over 27 million movers each year. Financial factorsgiven that runaway costs and high mortgage interest rates will price more households out of homeownership as an optionwill determine many of their decisions, as has long been the case. What is different over the past several years has been growth in discretionary rental households, also known as rent-by-choice households. According to Harvards Joint Center for Housing Studies (JCHS), the number of renters making at least $75,000 jumped by 48 percent over the decade ending just before the pandemic, to 11.3 million. With this increase, the share of renter households in this income group rose from 20 percent to 26 percent. Younger, older, and more economically, racially, and culturally diverse households together will bend the economic and cultural arc of rentership upward. Apartment industry leaders now recognize a blurring of behav- ioral lines across generations. When it comes to housing type need or preference, generational cohortsgeneration Z, millen- nials, generation X, and empty-nester baby boomersact more like each other than not.',
#      'filename': 'Emerging-Trends_USCanada-2023.pdf',
#      'page': 40,
#      'Cluster': 64}]},
#   'ideal': {'answer': '48 percent',
#    'sentences': ['According to Harvards Joint Center for Housing Studies (JCHS), the number of renters making at least $75,000 jumped by 48 percent over the decade ending just before the pandemic, to 11.3 million.']}},
#  {'category': 'SAME_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'Who is Jeff Smith?',
#    'sources': [{'key': 'real_estate_index:Deloitte 2023 Commercial Real Estate Outlook.pdf-!33',
#      'text': ' com Tim Coy is a research leader and subject matter specialist on commercial real estate at the Deloitte Center for Financial Services. In his career, he has experience advising clients from across the industryREITs, investment managers, developers, brokerson topics such as real estate market fundamentals, data trends, and portfolio strategy. 32 Contact us Industry leadership Our insights can help you take advantage of change. If youre looking for fresh ideas to address your challenges, we should talk. Jeff Smith National Real Estate leader Partner Deloitte Touche LLP 1 617 437 2804 jefsmithdeloitte. com Jeff Smith is Deloittes National Real Estate leader with nearly 30 years of audit and accounting experience. Throughout his career, Smith has worked with public and private owners, developers, sponsors, managers, and lenders in nearly all sectors of the real estate and hospitality industries. Kathy Feucht Global Real Estate leader Partner Deloitte Touche LLP 1 414 977 2662 kfeuchtdeloitte. com Kathy Feucht is Deloittes Global Real Estate sector leader and an audit partner with more than 20 years of experience. She serves as lead client service partner for both public and private clients in the Chicago and Milwaukee marketplaces, with a focus in the real estate and hospitality sectors. Deloitte Center for Financial Services Jim Eckenrode Managing director The Deloitte Center for Financial Services Deloitte Services LP 1 617 585 4877 jeckenrodedeloitte. com Jim Eckenrode is managing director at the Deloitte Center for Financial Services, responsible for developing and executing Deloittes research agenda, while providing insights to leading financial institutions on business and technology strategy. Tim Coy Manager The Deloitte Center for Financial Services Deloitte Services LP 1 332 323 4896 ticoydeloitte. com Tim Coy is a research leader on commercial real estate at the Deloitte Center for Financial Services. He is responsible for the development of market-leading insights and thought leadership initiatives in support of Deloittes Real Estate Industry practice. 33 Sign up for Deloitte Insights updates at www.',
#      'filename': 'Deloitte 2023 Commercial Real Estate Outlook.pdf',
#      'page': 34,
#      'Cluster': 88}]},
#   'ideal': {'answer': 'Deloitte National Real Estate leader',
#    'sentences': ["Jeff Smith is Deloitte's National Real Estate leader with nearly 30 years of audit and accounting experience."]}},
#  {'category': 'DIFFERENT_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'In what capacity does Jeff Smith serve?',
#    'sources': [{'key': 'real_estate_index:Deloitte 2023 Commercial Real Estate Outlook.pdf-!33',
#      'text': ' com Tim Coy is a research leader and subject matter specialist on commercial real estate at the Deloitte Center for Financial Services. In his career, he has experience advising clients from across the industryREITs, investment managers, developers, brokerson topics such as real estate market fundamentals, data trends, and portfolio strategy. 32 Contact us Industry leadership Our insights can help you take advantage of change. If youre looking for fresh ideas to address your challenges, we should talk. Jeff Smith National Real Estate leader Partner Deloitte Touche LLP 1 617 437 2804 jefsmithdeloitte. com Jeff Smith is Deloittes National Real Estate leader with nearly 30 years of audit and accounting experience. Throughout his career, Smith has worked with public and private owners, developers, sponsors, managers, and lenders in nearly all sectors of the real estate and hospitality industries. Kathy Feucht Global Real Estate leader Partner Deloitte Touche LLP 1 414 977 2662 kfeuchtdeloitte. com Kathy Feucht is Deloittes Global Real Estate sector leader and an audit partner with more than 20 years of experience. She serves as lead client service partner for both public and private clients in the Chicago and Milwaukee marketplaces, with a focus in the real estate and hospitality sectors. Deloitte Center for Financial Services Jim Eckenrode Managing director The Deloitte Center for Financial Services Deloitte Services LP 1 617 585 4877 jeckenrodedeloitte. com Jim Eckenrode is managing director at the Deloitte Center for Financial Services, responsible for developing and executing Deloittes research agenda, while providing insights to leading financial institutions on business and technology strategy. Tim Coy Manager The Deloitte Center for Financial Services Deloitte Services LP 1 332 323 4896 ticoydeloitte. com Tim Coy is a research leader on commercial real estate at the Deloitte Center for Financial Services. He is responsible for the development of market-leading insights and thought leadership initiatives in support of Deloittes Real Estate Industry practice. 33 Sign up for Deloitte Insights updates at www.',
#      'filename': 'Deloitte 2023 Commercial Real Estate Outlook.pdf',
#      'page': 34,
#      'Cluster': 88}]},
#   'ideal': {'answer': 'Deloitte National Real Estate leader',
#    'sentences': ["Jeff Smith is Deloitte's National Real Estate leader with nearly 30 years of audit and accounting experience."]}}]

# %%
with jsonlines.open(f"generator_dataset_{datetime.datetime.now().strftime('%Y%m%d')}.jsonl", "w") as writer:
    writer.write_all(generator_rows)

# %% [markdown]
# ## Create the e2e dataset

# %%
import json
import blobfile as bf
dataset = json.load(bf.BlobFile("all_dataset_final.json", "rb"))
eval_rows = []
for datapoint in dataset:
      row = {
         "category": datapoint["category"],
         "input": {
               "question": datapoint["question"],
         },
         "ideal": {
               "answer": datapoint["answer"],
         }
      }
      eval_rows.append(row)
eval_rows
# Out:
# [{'category': 'SAME_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Did the number of new units authorized in multifamily buildings and the number of single-family housing starts trend in the same direction in 2022?'},
#   'ideal': {'answer': 'No'}},
#  {'category': 'DIFFERENT_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Did the growth trajectory of new apartment complexes align with the initiation of single-dwelling constructions in 2022?'},
#   'ideal': {'answer': 'No'}},
#  {'category': 'SAME_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Is the current demand for larger living spaces caused by the existing tax laws for individual homebuyer?'},
#   'ideal': {'answer': 'No'}},
#  {'category': 'DIFFERENT_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Are the existing regulations related to individual property taxation driving the present trend towards bigger homes?'},
#   'ideal': {'answer': 'No'}},
#  {'category': 'SAME_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Was the constrained construction of new supply a consequence of labor shortages and cautious construction pacing from homebuilders?'},
#   'ideal': {'answer': 'Yes'}},
#  {'category': 'DIFFERENT_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': "Are the limitations in new housing production attributed to workforce scarcity and builders' prudent construction speed?"},
#   'ideal': {'answer': 'Yes'}},
#  {'category': 'SAME_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Has the affordability of housing dropped in recent years, affecting both young and mid-career households?'},
#   'ideal': {'answer': 'Yes'}},
#  {'category': 'DIFFERENT_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Has there been a recent decline in housing affordability, impacting households in their early and middle stages of their careers?'},
#   'ideal': {'answer': 'Yes'}},
#  {'category': 'SAME_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Are high prices and high interest mortgages contributing to difficulties for people wanting to become homeowners?'},
#   'ideal': {'answer': 'Yes'}},
#  {'category': 'DIFFERENT_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Do steep costs and hefty interest rates on housing loans pose challenges for aspiring property owners?'},
#   'ideal': {'answer': 'Yes'}},
#  {'category': 'SAME_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Is the market for value-add investments growing, particularly among younger and mid-career households?'},
#   'ideal': {'answer': 'Yes'}},
#  {'category': 'DIFFERENT_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Is there an upswing in the market for investments that increase property value, especially among the younger and middle-aged demographic?'},
#   'ideal': {'answer': 'Yes'}},
#  {'category': 'SAME_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Have the costs of both construction and renovation risen due to issues such as supply chain disruptions?'},
#   'ideal': {'answer': 'Yes'}},
#  {'category': 'DIFFERENT_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Has there been an escalation in the expenses related to building and refurbishing houses, due to problems like supply chain interruptions?'},
#   'ideal': {'answer': 'Yes'}},
#  {'category': 'SAME_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Have difficulties in the construction industry, like a shortage of skilled workers and materials, hampered building efforts?'},
#   'ideal': {'answer': 'Yes'}},
#  {'category': 'DIFFERENT_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Have complications in the building industry, such as a lack of trained manpower and building resources, obstructed construction activities?'},
#   'ideal': {'answer': 'Yes'}},
#  {'category': 'SAME_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Are concerns over supply chain issues contributing to elevated costs in the housing construction industry?'},
#   'ideal': {'answer': 'Yes'}},
#  {'category': 'DIFFERENT_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Are apprehensions related to supply chain difficulties adding to the surging expenses in the residential building sector?'},
#   'ideal': {'answer': 'Yes'}},
#  {'category': 'SAME_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Has the United States property market begun a period of normalization after an extraordinary growth phase, beginning in 2010 and ending in 2022 when the Fed started hiking interest rates?'},
#   'ideal': {'answer': 'Yes'}},
#  {'category': 'DIFFERENT_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': "Did the US real estate market transition into a phase of stabilization post a remarkable expansion cycle, from 2010 through 2022, commencing with the Federal Reserve's decision to increase interest rates?"},
#   'ideal': {'answer': 'Yes'}},
#  {'category': 'SAME_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Given the factors that have influenced the real estate market after the COVID lockdown, did the market eventually experience a normalization or a return to the mean, according to industry experts?'},
#   'ideal': {'answer': 'Yes'}},
#  {'category': 'DIFFERENT_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'In light of the influences shaping the property market post-COVID lockdown, did industry professionals perceive a reversion or recalibration back to its usual state?'},
#   'ideal': {'answer': 'Yes'}},
#  {'category': 'SAME_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Is the increase in capitalization rates and the decrease in returns associated with rising interest rates and cost of capital, as observed in the U.S. property market? '},
#   'ideal': {'answer': 'Yes'}},
#  {'category': 'DIFFERENT_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Can we link the escalating capitalization rates and dwindling returns to heightened interest rates and the escalating cost of capital, as discerned in the American real estate market?'},
#   'ideal': {'answer': 'Yes'}},
#  {'category': 'SAME_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Despite the successful run of the U.S. commercial property markets after the COVID-19 lockdown, are cap rates and yields now rising in many markets, not just limited to the UK, without fully reflecting higher interest rates yet?'},
#   'ideal': {'answer': 'Yes'}},
#  {'category': 'DIFFERENT_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': "Regardless of the U.S. commercial property markets' favorable performance post COVID-19 lockdown, are the capitalization rates and yields escalating across various markets, including but not limited to the UK, without full consideration of higher interest rates?"},
#   'ideal': {'answer': 'Yes'}},
#  {'category': 'SAME_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Given the observations from the finance executive in the national homebuilder company and the survey results on rising interest rates, are both sources in agreement that the markets are normalizing?'},
#   'ideal': {'answer': 'Yes'}},
#  {'category': 'DIFFERENT_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'In light of the statements by the finance executive at the national homebuilder company and the data from surveys on increased interest rates, do both sources concur that there is a reversion to the norm occurring within the markets?'},
#   'ideal': {'answer': 'Yes'}},
#  {'category': 'SAME_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': "Is it true that the economic growth in China in 2023 is expected to be lower than the historical averages, but the country's recovery is predicted to be on track during the 2023-2025 period, albeit at a slower pace?"},
#   'ideal': {'answer': 'Yes'}},
#  {'category': 'DIFFERENT_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': "Can it be confirmed that China's anticipated economic expansion in 2023 will be less than its historical norm, but the nation's rebound is forecasted to progress steadily between 2023 and 2025, albeit at a more measured rate?"},
#   'ideal': {'answer': 'Yes'}},
#  {'category': 'SAME_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': "Is it accurate to say that while the Monetary Authority of Singapore manages monetary policies through the foreign exchange markets, Singapore's economic strength and geopolitical stability are likely to fare slightly better financial conditions than South Korea and Australia?"},
#   'ideal': {'answer': 'Yes'}},
#  {'category': 'DIFFERENT_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': "Is it fair to claim that despite the Monetary Authority of Singapore directing monetary policies through foreign exchange markets, Singapore's economic resilience and geopolitical equilibrium are predicted to withstand slightly superior financial conditions compared to South Korea and Australia?"},
#   'ideal': {'answer': 'Yes'}},
#  {'category': 'SAME_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Is it correct to say that while Japan is facing externally driven challenges, it is expected to maintain stable monetary policies with the Bank of Japan keeping interest rates near zero, thereby ensuring the spread between property yields and the risk-free rate remains intact?'},
#   'ideal': {'answer': 'Yes'}},
#  {'category': 'DIFFERENT_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Would it be right to state that, despite external pressures, Japan is anticipated to uphold steady monetary policies with the Bank of Japan maintaining interest rates close to zero, ensuring the differential between property yields and the risk-free rate remains constant?'},
#   'ideal': {'answer': 'Yes'}},
#  {'category': 'SAME_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Is the Bank of Japan committed to keeping interest rates near zero which can make Japan an attractive diversifier for institutional investors?'},
#   'ideal': {'answer': 'Yes'}},
#  {'category': 'DIFFERENT_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Is the Bank of Japan devoted to sustaining interest rates close to zero, potentially making Japan an appealing choice for institutional investors? '},
#   'ideal': {'answer': 'Yes'}},
#  {'category': 'SAME_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': "Does the Bank of Japan's commitment to keeping interest rates near zero lead to a strong yen?"},
#   'ideal': {'answer': 'No'}},
#  {'category': 'DIFFERENT_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Does the commitment of the Bank of Japan to maintain near-zero interest rates result in a fortified yen?'},
#   'ideal': {'answer': 'No'}},
#  {'category': 'SAME_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': "Do Asia Pacific real estate markets, being dominated by domestic and intra-regional capital, signify that higher interest rates are a major concern for Japan's real estate yield spread?"},
#   'ideal': {'answer': 'No'}},
#  {'category': 'DIFFERENT_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': "With Asia Pacific property markets primarily influenced by domestic and intra-regional capital, does this suggest that escalating interest rates are a significant worry for Japan's property yield spread?"},
#   'ideal': {'answer': 'No'}},
#  {'category': 'SAME_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Given the stable risk-free rate and real estate yields in Japan and domestic capital dominance in the Asia Pacific region, is Australia seen as a safe haven in the region?'},
#   'ideal': {'answer': 'Yes'}},
#  {'category': 'DIFFERENT_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'In view of the constant risk-free rate and property yields in Japan and the prevalence of domestic capital in the Asia Pacific, is Australia considered a safe harbor in the region?'},
#   'ideal': {'answer': 'Yes'}},
#  {'category': 'SAME_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Are interest rates expected to continue rising indefinitely, impacting real estate values?'},
#   'ideal': {'answer': 'No'}},
#  {'category': 'DIFFERENT_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Are interest rates projected to persistently climb, detrimentally affecting property values?'},
#   'ideal': {'answer': 'No'}},
#  {'category': 'SAME_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Can we conclude that the denominator effect is expected to force all institutional investors to sell their real estate assets?'},
#   'ideal': {'answer': 'No'}},
#  {'category': 'DIFFERENT_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Is it reasonable to expect the denominator effect to compel all institutional investors to offload their real estate holdings? '},
#   'ideal': {'answer': 'No'}},
#  {'category': 'SAME_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Can we infer that higher debt costs are the only determinant of real estate valuations?'},
#   'ideal': {'answer': 'No'}},
#  {'category': 'DIFFERENT_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Can we deduce that escalating debt expenses are the sole factor influencing property evaluations?'},
#   'ideal': {'answer': 'No'}},
#  {'category': 'SAME_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Will the increase in interest rates cease to impact real estate values as soon as inflation begins to decrease?'},
#   'ideal': {'answer': 'Yes'}},
#  {'category': 'DIFFERENT_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Will the escalation in interest rates stop influencing property values as soon as deflation initiates?'},
#   'ideal': {'answer': 'Yes'}},
#  {'category': 'SAME_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Does the current economic robustness in the US, Canada, and Singapore likely support a pivot in interest rates, assuming inflation settles closer to the target levels of central banks?'},
#   'ideal': {'answer': 'Yes'}},
#  {'category': 'DIFFERENT_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Is the current economic resilience in the US, Canada, and Singapore likely to foster a shift in interest rates, assuming inflation steadies closer to the benchmark levels set by central banks?'},
#   'ideal': {'answer': 'Yes'}},
#  {'category': 'SAME_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Can we infer that all-cash buyers gained more prominence in the market during the end of 2022 due to the higher borrowing costs and prime yields being below the cost of debt capital?'},
#   'ideal': {'answer': 'Yes'}},
#  {'category': 'DIFFERENT_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Can we deduce that purchasers paying in cash came to the fore in the market towards the end of 2022 due to the escalating borrowing expenses and prime yields being beneath the cost of debt capital?'},
#   'ideal': {'answer': 'Yes'}},
#  {'category': 'SAME_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Can we say that the concern about how long the Fed will keep raising rates is justified considering that these rising rates could negatively impact real estate values?'},
#   'ideal': {'answer': 'Yes'}},
#  {'category': 'DIFFERENT_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Is the apprehension about the duration the Fed will continue escalating rates valid, given that these rising rates could adversely affect property values? '},
#   'ideal': {'answer': 'Yes'}},
#  {'category': 'SAME_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Is it correct to say that both Europe and the US are expected to face challenges in different sectors (energy and office investments respectively) in 2023?'},
#   'ideal': {'answer': 'Yes'}},
#  {'category': 'DIFFERENT_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Is it right to suggest that both Europe and the US are anticipated to confront obstacles in distinct sectors (energy and office investments respectively) in 2023?'},
#   'ideal': {'answer': 'Yes'}},
#  {'category': 'SAME_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Is it correct to conclude that the potential dominance of distressed sales in the US in 2023 is directly related to the ongoing constraints from the virus?'},
#   'ideal': {'answer': 'No'}},
#  {'category': 'DIFFERENT_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Is it accurate to infer that the prospective prevalence of distressed sales in the US in 2023 is directly attributable to the ongoing limitations imposed by the virus?'},
#   'ideal': {'answer': 'No'}},
#  {'category': 'SAME_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'How much has prime rents fallen by the end of 2021?'},
#   'ideal': {'answer': 'EUR 275 per m2'}},
#  {'category': 'DIFFERENT_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'What was the decline in prime rents by the conclusion of 2021?'},
#   'ideal': {'answer': 'EUR 275 per m2'}},
#  {'category': 'SAME_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'How much is the City of Frankfurt to invest in city centre projects?'},
#   'ideal': {'answer': 'EUR 30m'}},
#  {'category': 'DIFFERENT_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'What is the committed investment by Frankfurt City for city centre developments?'},
#   'ideal': {'answer': 'EUR 30m'}},
#  {'category': 'SAME_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'What has been remodelled into the Weltstadthaus?'},
#   'ideal': {'answer': 'The Galeria store at the entrance to the Zeil'}},
#  {'category': 'DIFFERENT_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'What structure has been transformed into the Weltstadthaus?'},
#   'ideal': {'answer': 'The Galeria store at the entrance to the Zeil'}},
#  {'category': 'SAME_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'When will the former sports arena building be replaced?'},
#   'ideal': {'answer': '2024'}},
#  {'category': 'DIFFERENT_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'By what year is the replacement of the old sports arena planned?'},
#   'ideal': {'answer': '2024'}},
#  {'category': 'SAME_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'What was the quarter-on-quarter yield increase for French and Spanish cities?'},
#   'ideal': {'answer': 'Between 15 and 25bps'}},
#  {'category': 'DIFFERENT_WORDING_ONE_PARAGRAPH',
#   'input': {'question': "What's the quarterly yield rise for cities in France and Spain?"},
#   'ideal': {'answer': 'Between 15 and 25bps'}},
#  {'category': 'SAME_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'What is the estimated value loss during the outlook period?'},
#   'ideal': {'answer': 'Around 10 to 15'}},
#  {'category': 'DIFFERENT_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'What is the projected value depreciation during the forecast period?'},
#   'ideal': {'answer': 'Around 10 to 15'}},
#  {'category': 'SAME_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'What is the change in office transaction volumes in Europe compared to the same period in 2021?'},
#   'ideal': {'answer': 'Fell by over 20%'}},
#  {'category': 'DIFFERENT_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'How did the volume of office transactions in Europe shift in comparison with the same timeframe in 2021?'},
#   'ideal': {'answer': 'Fell by over 20%'}},
#  {'category': 'SAME_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'What is the average capital value decline of prime logistics properties in Q4 2022 compared to Q4 2021?'},
#   'ideal': {'answer': '7-8.'}},
#  {'category': 'DIFFERENT_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'What is the rate of depreciation in the capital value of prime logistics properties in the last quarter of 2022 compared to the same period in 2021?'},
#   'ideal': {'answer': '7-8.'}},
#  {'category': 'SAME_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'What is the vacancy rate in Düsseldorf and Frankfurt?'},
#   'ideal': {'answer': '8 per cent'}},
#  {'category': 'DIFFERENT_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'What percentage of unoccupied space is there in Düsseldorf and Frankfurt?'},
#   'ideal': {'answer': '8 per cent'}},
#  {'category': 'SAME_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'What is the policy rate of the Bank of Canada?'},
#   'ideal': {'answer': '3.75'}},
#  {'category': 'DIFFERENT_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'Please identify the standard interest rate established by the Canadian central bank?'},
#   'ideal': {'answer': '3.75'}},
#  {'category': 'SAME_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'What is the vacancy rate in Cologne?'},
#   'ideal': {'answer': '2.8 per cent'}},
#  {'category': 'DIFFERENT_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'What is the percentage of empty spaces in Cologne?'},
#   'ideal': {'answer': '2.8 per cent'}},
#  {'category': 'SAME_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'What was take-up in Q2 2022?'},
#   'ideal': {'answer': 'over 1 million m2'}},
#  {'category': 'DIFFERENT_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'What was the volume of absorption in the second quarter of 2022?'},
#   'ideal': {'answer': 'over 1 million m2'}},
#  {'category': 'SAME_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'How many of the 10 highest-rated markets last year repeated this year?'},
#   'ideal': {'answer': 'Nine'}},
#  {'category': 'DIFFERENT_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'How many of the top 10 markets from the previous year retained their position this year?'},
#   'ideal': {'answer': 'Nine'}},
#  {'category': 'SAME_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'How many markets moved up or down in rankings by at least 10 places?'},
#   'ideal': {'answer': 'About a quarter'}},
#  {'category': 'DIFFERENT_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'How many markets experienced a rise or fall of at least 10 spots in the rankings?'},
#   'ideal': {'answer': 'About a quarter'}},
#  {'category': 'SAME_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'How many of the 20-highest rated markets in last years survey fell in the rankings this year?'},
#   'ideal': {'answer': 'Eleven'}},
#  {'category': 'DIFFERENT_WORDING_ONE_PARAGRAPH',
#   'input': {'question': "How many of the top 20 markets from the previous year's survey saw a decrease in their rankings this year?"},
#   'ideal': {'answer': 'Eleven'}},
#  {'category': 'SAME_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'How many of the 20-lowest rated markets in last years survey rose in the rankings this year?'},
#   'ideal': {'answer': 'Thirteen'}},
#  {'category': 'DIFFERENT_WORDING_ONE_PARAGRAPH',
#   'input': {'question': "How many of the 20 lowest-ranked markets from the previous year's survey experienced an increase in rankings this year?"},
#   'ideal': {'answer': 'Thirteen'}},
#  {'category': 'SAME_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'How many Sun Belt markets were among the top 20 markets for overall prospects in 2011?'},
#   'ideal': {'answer': 'Ten.'}},
#  {'category': 'DIFFERENT_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'How many Sun Belt markets were in the top 20 overall prospects in 2011?'},
#   'ideal': {'answer': 'Ten.'}},
#  {'category': 'SAME_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'What effect did property values have in midyear 2022?'},
#   'ideal': {'answer': 'Property values dropped 10 to 20 percent'}},
#  {'category': 'DIFFERENT_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'How did property values behave in the middle of 2022?'},
#   'ideal': {'answer': 'Property values dropped 10 to 20 percent'}},
#  {'category': 'SAME_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'What is the average size of a metro area in the Supernova category?'},
#   'ideal': {'answer': '1 million to 2 million people'}},
#  {'category': 'DIFFERENT_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'What is the typical population of a metropolitan area classified under the Supernova category?'},
#   'ideal': {'answer': '1 million to 2 million people'}},
#  {'category': 'SAME_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'What is the rate of the 18-Hour Cities in terms of economic output among the 12 subgroups?'},
#   'ideal': {'answer': 'Third highest.'}},
#  {'category': 'DIFFERENT_WORDING_ONE_PARAGRAPH',
#   'input': {'question': "What's the economic output ranking of the 18-Hour Cities among the 12 subgroups?"},
#   'ideal': {'answer': 'Third highest.'}},
#  {'category': 'SAME_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'What is the trend of tourist numbers?'},
#   'ideal': {'answer': 'Almost back to 2019 levels.'}},
#  {'category': 'DIFFERENT_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'How are tourist numbers moving?'},
#   'ideal': {'answer': 'Almost back to 2019 levels.'}},
#  {'category': 'SAME_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'What is the average monthly disposable income per household in Euro?'},
#   'ideal': {'answer': '3,726 Euro'}},
#  {'category': 'DIFFERENT_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'What is the typical sum of money each household can expend monthly in the Eurozone?'},
#   'ideal': {'answer': '3,726 Euro'}},
#  {'category': 'SAME_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'How has consumer sentiment been impacted by the war in Ukraine, inflation and the gas crisis?'},
#   'ideal': {'answer': 'Consumer sentiment has fallen to a historic low'}},
#  {'category': 'DIFFERENT_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'How did the Ukraine war, inflation and gas crisis affect consumer mood?'},
#   'ideal': {'answer': 'Consumer sentiment has fallen to a historic low'}},
#  {'category': 'SAME_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'When did new home prices peak?'},
#   'ideal': {'answer': 'April 2022'}},
#  {'category': 'DIFFERENT_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'In which month did new home prices reach their highest point?'},
#   'ideal': {'answer': 'April 2022'}},
#  {'category': 'SAME_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'What is the phone number of DZ HYP AG?'},
#   'ideal': {'answer': '49 40 3334-0.'}},
#  {'category': 'DIFFERENT_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'What is the contact number for DZ HYP AG?'},
#   'ideal': {'answer': '49 40 3334-0.'}},
#  {'category': 'SAME_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'How much does the U.S. apartment property sector contribute annually to the U.S. economy according to the NMHC?'},
#   'ideal': {'answer': '$3.4 trillion'}},
#  {'category': 'DIFFERENT_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'What annual contribution does the U.S. apartment property sector make to the U.S. economy as per the NMHC?'},
#   'ideal': {'answer': '$3.4 trillion'}},
#  {'category': 'SAME_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'How much higher was the number of new units authorized in multifamily buildings over the past 12 months as of June 2022 compared to the same period in 2018-2019, as per a Bloomberg report?'},
#   'ideal': {'answer': '37 percent'}},
#  {'category': 'DIFFERENT_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'By what percentage was the authorization of new units in multifamily buildings higher over the last 12 months up to June 2022, in comparison with the same period in 2018-2019, according to a Bloomberg report?'},
#   'ideal': {'answer': '37 percent'}},
#  {'category': 'SAME_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'What percentage increase in apartments under construction was observed as of August, compared to a year ago?'},
#   'ideal': {'answer': '25 percent'}},
#  {'category': 'DIFFERENT_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'What was the year-on-year growth rate in apartments under construction as of August?'},
#   'ideal': {'answer': '25 percent'}},
#  {'category': 'SAME_WORDING_ONE_PARAGRAPH',
#   'input': {'question': "What percentage increase did renters making at least $75,000 see over the decade ending just before the pandemic, according to Harvard's Joint Center for Housing Studies (JCHS)?"},
#   'ideal': {'answer': '48 percent'}},
#  {'category': 'DIFFERENT_WORDING_ONE_PARAGRAPH',
#   'input': {'question': "By what percentage did the number of renters earning at least $75,000 increase over the decade ending just before the pandemic, as per the Harvard's Joint Center for Housing Studies (JCHS)?"},
#   'ideal': {'answer': '48 percent'}},
#  {'category': 'SAME_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'Who is Jeff Smith?'},
#   'ideal': {'answer': 'Deloitte National Real Estate leader'}},
#  {'category': 'DIFFERENT_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'In what capacity does Jeff Smith serve?'},
#   'ideal': {'answer': 'Deloitte National Real Estate leader'}},
#  {'category': 'NOT_SOURCE_BASED',
#   'input': {'question': 'What are apples?'},
#   'ideal': {'answer': "I don't know. Not provided in the sources"}},
#  {'category': 'NOT_SOURCE_BASED',
#   'input': {'question': 'How do solar panels work?'},
#   'ideal': {'answer': "I don't know. Not provided in the sources"}},
#  {'category': 'NOT_SOURCE_BASED',
#   'input': {'question': 'What is the role of mitochondria in a cell?'},
#   'ideal': {'answer': "I don't know. Not provided in the sources"}},
#  {'category': 'NOT_SOURCE_BASED',
#   'input': {'question': 'Who was the first person to climb Mount Everest?'},
#   'ideal': {'answer': "I don't know. Not provided in the sources"}},
#  {'category': 'NOT_SOURCE_BASED',
#   'input': {'question': 'How does the internet work?'},
#   'ideal': {'answer': "I don't know. Not provided in the sources"}},
#  {'category': 'NOT_SOURCE_BASED',
#   'input': {'question': 'What is the capital of Australia?'},
#   'ideal': {'answer': "I don't know. Not provided in the sources"}},
#  {'category': 'NOT_SOURCE_BASED',
#   'input': {'question': 'Why do leaves change color in the fall?'},
#   'ideal': {'answer': "I don't know. Not provided in the sources"}},
#  {'category': 'NOT_SOURCE_BASED',
#   'input': {'question': 'How is chocolate made?'},
#   'ideal': {'answer': "I don't know. Not provided in the sources"}},
#  {'category': 'NOT_SOURCE_BASED',
#   'input': {'question': 'Who invented the light bulb?'},
#   'ideal': {'answer': "I don't know. Not provided in the sources"}},
#  {'category': 'NOT_SOURCE_BASED',
#   'input': {'question': 'What is the theory of relativity?'},
#   'ideal': {'answer': "I don't know. Not provided in the sources"}},
#  {'category': 'NOT_SOURCE_BASED',
#   'input': {'question': 'What is the process of photosynthesis?'},
#   'ideal': {'answer': "I don't know. Not provided in the sources"}},
#  {'category': 'NOT_SOURCE_BASED',
#   'input': {'question': 'Why is the sky blue?'},
#   'ideal': {'answer': "I don't know. Not provided in the sources"}},
#  {'category': 'NOT_SOURCE_BASED',
#   'input': {'question': 'What is the meaning of life?'},
#   'ideal': {'answer': "I don't know. Not provided in the sources"}},
#  {'category': 'NOT_SOURCE_BASED',
#   'input': {'question': 'What causes earthquakes?'},
#   'ideal': {'answer': "I don't know. Not provided in the sources"}},
#  {'category': 'NOT_SOURCE_BASED',
#   'input': {'question': 'What is quantum mechanics?'},
#   'ideal': {'answer': "I don't know. Not provided in the sources"}},
#  {'category': 'NOT_SOURCE_BASED',
#   'input': {'question': "Who wrote 'Pride and Prejudice'?"},
#   'ideal': {'answer': "I don't know. Not provided in the sources"}},
#  {'category': 'NOT_SOURCE_BASED',
#   'input': {'question': 'What is blockchain technology?'},
#   'ideal': {'answer': "I don't know. Not provided in the sources"}},
#  {'category': 'NOT_SOURCE_BASED',
#   'input': {'question': 'How do vaccines work?'},
#   'ideal': {'answer': "I don't know. Not provided in the sources"}},
#  {'category': 'NOT_SOURCE_BASED',
#   'input': {'question': 'What is the purpose of the United Nations?'},
#   'ideal': {'answer': "I don't know. Not provided in the sources"}},
#  {'category': 'NOT_SOURCE_BASED',
#   'input': {'question': 'What is the function of the brain?'},
#   'ideal': {'answer': "I don't know. Not provided in the sources"}},
#  {'category': 'NOT_SOURCE_BASED',
#   'input': {'question': 'Who was Leonardo da Vinci?'},
#   'ideal': {'answer': "I don't know. Not provided in the sources"}},
#  {'category': 'NOT_SOURCE_BASED',
#   'input': {'question': 'How does a microwave oven work?'},
#   'ideal': {'answer': "I don't know. Not provided in the sources"}},
#  {'category': 'NOT_SOURCE_BASED',
#   'input': {'question': 'What is climate change?'},
#   'ideal': {'answer': "I don't know. Not provided in the sources"}},
#  {'category': 'NOT_SOURCE_BASED',
#   'input': {'question': 'What is the role of DNA in a cell?'},
#   'ideal': {'answer': "I don't know. Not provided in the sources"}},
#  {'category': 'NOT_SOURCE_BASED',
#   'input': {'question': 'What is the purpose of a constitution?'},
#   'ideal': {'answer': "I don't know. Not provided in the sources"}},
#  {'category': 'NOT_SOURCE_BASED',
#   'input': {'question': 'Who was William Shakespeare?'},
#   'ideal': {'answer': "I don't know. Not provided in the sources"}},
#  {'category': 'NOT_SOURCE_BASED',
#   'input': {'question': 'What is the difference between a virus and a bacteria?'},
#   'ideal': {'answer': "I don't know. Not provided in the sources"}},
#  {'category': 'NOT_SOURCE_BASED',
#   'input': {'question': 'What is the structure of a atom?'},
#   'ideal': {'answer': "I don't know. Not provided in the sources"}},
#  {'category': 'NOT_SOURCE_BASED',
#   'input': {'question': 'What is the function of the heart?'},
#   'ideal': {'answer': "I don't know. Not provided in the sources"}},
#  {'category': 'NOT_SOURCE_BASED',
#   'input': {'question': 'Who was Nikola Tesla?'},
#   'ideal': {'answer': "I don't know. Not provided in the sources"}}]

# %%
with jsonlines.open(f"eval_dataset_{datetime.datetime.now().strftime('%Y%m%d')}.jsonl", "w") as writer:
    writer.write_all(eval_rows)

# %%
# only save questions of Category NOT_SOURCE_BASED
not_sources_based_rows = [row for row in eval_rows if row["category"] == "NOT_SOURCE_BASED"]
with jsonlines.open(f"eval_NOT_SOURCE_BASED_{datetime.datetime.now().strftime('%Y%m%d')}.jsonl", "w") as writer:
    writer.write_all(not_sources_based_rows)

# %%
dataset = json.load(bf.BlobFile("all_dataset_final.json", "rb"))
# print every question answer pair except for the NOT_SOURCE_BASED category
for i, datapoint in enumerate(dataset):
    if datapoint["category"] == "NOT_SOURCE_BASED":
        continue
    # print(f"{i+1}: Question: {datapoint['question']} Answer: {datapoint['answer']}")

# %% [markdown]
# # EDITS FOR RETRIEVER CHANGES

# %%
import json
import blobfile as bf
import pandas as pd

smaller_chunk_csv = 'redis-test/real_estate_index.csv'
chunk_df = pd.read_csv(smaller_chunk_csv)
chunk_df.rename(columns={"text_chunk": "text"}, inplace=True)
dataset = json.load(bf.BlobFile("all_dataset_final.json", "rb"))
# print every question answer pair except for the NOT_SOURCE_BASED category
for i, datapoint in enumerate(dataset):
    if datapoint["category"] == "NOT_SOURCE_BASED":
        continue
    if len(datapoint["sentences"]) > 0:
        datapoint["t_150c_paragraph"] = []
        for sentence in datapoint["sentences"]:
            row = chunk_df.loc[(chunk_df['text'].str.contains(sentence))]
            row = row.to_dict(orient='records')
            if len(row) > 0:
                datapoint["t_150c_paragraph"].append(row[0])



with open("all_dataset_t_150c.json", "w") as f:
    json.dump(dataset, f)
# Out:
# /var/folders/fl/tm4fc_cn093f_bh634c4z63r0000gq/T/ipykernel_86603/119995659.py:16: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   row = chunk_df.loc[(chunk_df['text'].str.contains(sentence))]

# %%
dataset = json.load(bf.BlobFile("all_dataset_t_150c.json", "rb"))

retriever_rows = []
for datapoint in dataset:
    if datapoint["category"] == "NOT_SOURCE_BASED":
        continue
    row = {
        "category": datapoint["category"],
        "input": {
            "question": datapoint["question"],
        },
        "ideal": {
            "paragraph": datapoint["sentences"] if "sentences" and len(datapoint["sentences"]) > 0 else [paragraph["text"] for paragraph in datapoint["t_150c_paragraph"]],
            "filename": list(set(paragraph["filename"] for paragraph in datapoint["t_150c_paragraph"])),
            "ids": list(set(paragraph["id"] for paragraph in datapoint["t_150c_paragraph"])),
        }
    }
    retriever_rows.append(row)
retriever_rows
# Out:
# [{'category': 'SAME_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Did the number of new units authorized in multifamily buildings and the number of single-family housing starts trend in the same direction in 2022?'},
#   'ideal': {'paragraph': ['As of August, 862,000 apartments were under construction, up 25 percent from a year ago.',
#     'And now both permits and housing starts have been trending down again in 2022.'],
#    'filename': ['Emerging-Trends_USCanada-2023.pdf'],
#    'ids': ['index_150t_chunks:Emerging-Trends_USCanada-2023.pdf-!146',
#     'index_150t_chunks:Emerging-Trends_USCanada-2023.pdf-!57']}},
#  {'category': 'DIFFERENT_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Did the growth trajectory of new apartment complexes align with the initiation of single-dwelling constructions in 2022?'},
#   'ideal': {'paragraph': ['As of August, 862,000 apartments were under construction, up 25 percent from a year ago.',
#     'And now both permits and housing starts have been trending down again in 2022.'],
#    'filename': ['Emerging-Trends_USCanada-2023.pdf'],
#    'ids': ['index_150t_chunks:Emerging-Trends_USCanada-2023.pdf-!146',
#     'index_150t_chunks:Emerging-Trends_USCanada-2023.pdf-!57']}},
#  {'category': 'SAME_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Is the current demand for larger living spaces caused by the existing tax laws for individual homebuyer?'},
#   'ideal': {'paragraph': ['Two, demand gathered speed and sweep as people sought larger living spaces to balance remote work and household life, and more outdoor living options.',
#     'One reason: existing tax laws are stacked against the individual homebuyer.'],
#    'filename': ['Emerging-Trends_USCanada-2023.pdf'],
#    'ids': ['index_150t_chunks:Emerging-Trends_USCanada-2023.pdf-!145',
#     'index_150t_chunks:Emerging-Trends_USCanada-2023.pdf-!56']}},
#  {'category': 'DIFFERENT_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Are the existing regulations related to individual property taxation driving the present trend towards bigger homes?'},
#   'ideal': {'paragraph': ['Two, demand gathered speed and sweep as people sought larger living spaces to balance remote work and household life, and more outdoor living options.',
#     'One reason: existing tax laws are stacked against the individual homebuyer.'],
#    'filename': ['Emerging-Trends_USCanada-2023.pdf'],
#    'ids': ['index_150t_chunks:Emerging-Trends_USCanada-2023.pdf-!145',
#     'index_150t_chunks:Emerging-Trends_USCanada-2023.pdf-!56']}},
#  {'category': 'SAME_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Was the constrained construction of new supply a consequence of labor shortages and cautious construction pacing from homebuilders?'},
#   'ideal': {'paragraph': ['Three, constrained construction of new supply, and a price run-up on the single-family for-sale front, spilled over into expanded apartment demand.',
#     'Another supply constraint is homebuilders cautious construc- tion pacing, a vestige of the last recession.',
#     'And then labor shortages are compounding the problems.'],
#    'filename': ['Emerging-Trends_USCanada-2023.pdf'],
#    'ids': ['index_150t_chunks:Emerging-Trends_USCanada-2023.pdf-!145',
#     'index_150t_chunks:Emerging-Trends_USCanada-2023.pdf-!56',
#     'index_150t_chunks:Emerging-Trends_USCanada-2023.pdf-!57']}},
#  {'category': 'DIFFERENT_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': "Are the limitations in new housing production attributed to workforce scarcity and builders' prudent construction speed?"},
#   'ideal': {'paragraph': ['Three, constrained construction of new supply, and a price run-up on the single-family for-sale front, spilled over into expanded apartment demand.',
#     'Another supply constraint is homebuilders cautious construc- tion pacing, a vestige of the last recession.',
#     'And then labor shortages are compounding the problems.'],
#    'filename': ['Emerging-Trends_USCanada-2023.pdf'],
#    'ids': ['index_150t_chunks:Emerging-Trends_USCanada-2023.pdf-!145',
#     'index_150t_chunks:Emerging-Trends_USCanada-2023.pdf-!56',
#     'index_150t_chunks:Emerging-Trends_USCanada-2023.pdf-!57']}},
#  {'category': 'SAME_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Has the affordability of housing dropped in recent years, affecting both young and mid-career households?'},
#   'ideal': {'paragraph': ['Housing affordability has fallen to its lowest level in over 30 years. Prices and rents have soared relative to incomes. Spiraling mortgage rates have pushed the homeownership bar further out of reach for a growing share of households.',
#     'B and C value-add investments suit a growing market of younger and mid-career households stuck in the limbo of scarce supply, high prices, and high interest mortgages that will delay their becoming homeowners.'],
#    'filename': ['Emerging-Trends_USCanada-2023.pdf'],
#    'ids': ['index_150t_chunks:Emerging-Trends_USCanada-2023.pdf-!151',
#     'index_150t_chunks:Emerging-Trends_USCanada-2023.pdf-!52']}},
#  {'category': 'DIFFERENT_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Has there been a recent decline in housing affordability, impacting households in their early and middle stages of their careers?'},
#   'ideal': {'paragraph': ['Housing affordability has fallen to its lowest level in over 30 years. Prices and rents have soared relative to incomes. Spiraling mortgage rates have pushed the homeownership bar further out of reach for a growing share of households.',
#     'B and C value-add investments suit a growing market of younger and mid-career households stuck in the limbo of scarce supply, high prices, and high interest mortgages that will delay their becoming homeowners.'],
#    'filename': ['Emerging-Trends_USCanada-2023.pdf'],
#    'ids': ['index_150t_chunks:Emerging-Trends_USCanada-2023.pdf-!151',
#     'index_150t_chunks:Emerging-Trends_USCanada-2023.pdf-!52']}},
#  {'category': 'SAME_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Are high prices and high interest mortgages contributing to difficulties for people wanting to become homeowners?'},
#   'ideal': {'paragraph': ['Housing affordability has fallen to its lowest level in over 30 years. Prices and rents have soared relative to incomes. Spiraling mortgage rates have pushed the homeownership bar further out of reach for a growing share of households.',
#     'B and C value-add investments suit a growing market of younger and mid-career households stuck in the limbo of scarce supply, high prices, and high interest mortgages that will delay their becoming homeowners.'],
#    'filename': ['Emerging-Trends_USCanada-2023.pdf'],
#    'ids': ['index_150t_chunks:Emerging-Trends_USCanada-2023.pdf-!151',
#     'index_150t_chunks:Emerging-Trends_USCanada-2023.pdf-!52']}},
#  {'category': 'DIFFERENT_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Do steep costs and hefty interest rates on housing loans pose challenges for aspiring property owners?'},
#   'ideal': {'paragraph': ['Housing affordability has fallen to its lowest level in over 30 years. Prices and rents have soared relative to incomes. Spiraling mortgage rates have pushed the homeownership bar further out of reach for a growing share of households.',
#     'B and C value-add investments suit a growing market of younger and mid-career households stuck in the limbo of scarce supply, high prices, and high interest mortgages that will delay their becoming homeowners.'],
#    'filename': ['Emerging-Trends_USCanada-2023.pdf'],
#    'ids': ['index_150t_chunks:Emerging-Trends_USCanada-2023.pdf-!151',
#     'index_150t_chunks:Emerging-Trends_USCanada-2023.pdf-!52']}},
#  {'category': 'SAME_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Is the market for value-add investments growing, particularly among younger and mid-career households?'},
#   'ideal': {'paragraph': ['Housing affordability has fallen to its lowest level in over 30 years. Prices and rents have soared relative to incomes. Spiraling mortgage rates have pushed the homeownership bar further out of reach for a growing share of households.',
#     'B and C value-add investments suit a growing market of younger and mid-career households stuck in the limbo of scarce supply, high prices, and high interest mortgages that will delay their becoming homeowners.'],
#    'filename': ['Emerging-Trends_USCanada-2023.pdf'],
#    'ids': ['index_150t_chunks:Emerging-Trends_USCanada-2023.pdf-!151',
#     'index_150t_chunks:Emerging-Trends_USCanada-2023.pdf-!52']}},
#  {'category': 'DIFFERENT_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Is there an upswing in the market for investments that increase property value, especially among the younger and middle-aged demographic?'},
#   'ideal': {'paragraph': ['Housing affordability has fallen to its lowest level in over 30 years. Prices and rents have soared relative to incomes. Spiraling mortgage rates have pushed the homeownership bar further out of reach for a growing share of households.',
#     'B and C value-add investments suit a growing market of younger and mid-career households stuck in the limbo of scarce supply, high prices, and high interest mortgages that will delay their becoming homeowners.'],
#    'filename': ['Emerging-Trends_USCanada-2023.pdf'],
#    'ids': ['index_150t_chunks:Emerging-Trends_USCanada-2023.pdf-!151',
#     'index_150t_chunks:Emerging-Trends_USCanada-2023.pdf-!52']}},
#  {'category': 'SAME_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Have the costs of both construction and renovation risen due to issues such as supply chain disruptions?'},
#   'ideal': {'paragraph': ['Building in towns and cities was hampered by the fact that the construction industry was working more or less at capacity, by a shortage of skilled workers and of materials, along with the emergence of protests here and there. The cost of reno- vation has risen on a similar scale.',
#     "Construction costs shot up due to supply chain disruptions and are still worrisome. As one housing industry adviser notes, There's a stress index about global supply chains, and those stress indices are all indicating that they're moderating, but they're still at very high levels."],
#    'filename': [],
#    'ids': []}},
#  {'category': 'DIFFERENT_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Has there been an escalation in the expenses related to building and refurbishing houses, due to problems like supply chain interruptions?'},
#   'ideal': {'paragraph': ['Building in towns and cities was hampered by the fact that the construction industry was working more or less at capacity, by a shortage of skilled workers and of materials, along with the emergence of protests here and there. The cost of reno- vation has risen on a similar scale.',
#     "Construction costs shot up due to supply chain disruptions and are still worrisome. As one housing industry adviser notes, There's a stress index about global supply chains, and those stress indices are all indicating that they're moderating, but they're still at very high levels."],
#    'filename': [],
#    'ids': []}},
#  {'category': 'SAME_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Have difficulties in the construction industry, like a shortage of skilled workers and materials, hampered building efforts?'},
#   'ideal': {'paragraph': ['Building in towns and cities was hampered by the fact that the construction industry was working more or less at capacity, by a shortage of skilled workers and of materials, along with the emergence of protests here and there. The cost of reno- vation has risen on a similar scale.',
#     "Construction costs shot up due to supply chain disruptions and are still worrisome. As one housing industry adviser notes, There's a stress index about global supply chains, and those stress indices are all indicating that they're moderating, but they're still at very high levels."],
#    'filename': [],
#    'ids': []}},
#  {'category': 'DIFFERENT_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Have complications in the building industry, such as a lack of trained manpower and building resources, obstructed construction activities?'},
#   'ideal': {'paragraph': ['Building in towns and cities was hampered by the fact that the construction industry was working more or less at capacity, by a shortage of skilled workers and of materials, along with the emergence of protests here and there. The cost of reno- vation has risen on a similar scale.',
#     "Construction costs shot up due to supply chain disruptions and are still worrisome. As one housing industry adviser notes, There's a stress index about global supply chains, and those stress indices are all indicating that they're moderating, but they're still at very high levels."],
#    'filename': [],
#    'ids': []}},
#  {'category': 'SAME_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Are concerns over supply chain issues contributing to elevated costs in the housing construction industry?'},
#   'ideal': {'paragraph': ['Building in towns and cities was hampered by the fact that the construction industry was working more or less at capacity, by a shortage of skilled workers and of materials, along with the emergence of protests here and there. The cost of reno- vation has risen on a similar scale.',
#     "Construction costs shot up due to supply chain disruptions and are still worrisome. As one housing industry adviser notes, There's a stress index about global supply chains, and those stress indices are all indicating that they're moderating, but they're still at very high levels."],
#    'filename': [],
#    'ids': []}},
#  {'category': 'DIFFERENT_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Are apprehensions related to supply chain difficulties adding to the surging expenses in the residential building sector?'},
#   'ideal': {'paragraph': ['Building in towns and cities was hampered by the fact that the construction industry was working more or less at capacity, by a shortage of skilled workers and of materials, along with the emergence of protests here and there. The cost of reno- vation has risen on a similar scale.',
#     "Construction costs shot up due to supply chain disruptions and are still worrisome. As one housing industry adviser notes, There's a stress index about global supply chains, and those stress indices are all indicating that they're moderating, but they're still at very high levels."],
#    'filename': [],
#    'ids': []}},
#  {'category': 'SAME_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Has the United States property market begun a period of normalization after an extraordinary growth phase, beginning in 2010 and ending in 2022 when the Fed started hiking interest rates?'},
#   'ideal': {'paragraph': ['And now, more than two years on, property investors and managers are learning anew that whopping growth and profits eventually fall back to earth—a reversion to the mean, to use finance jargon, or simply normalizing, as numerous industry experts we interviewed put it.',
#     'Indeed, home sales—both new and existing—had an extraordinary 12-year run since bottoming out in the summer of 2010 until the Fed started hiking interest rates in the spring of 2022.'],
#    'filename': [],
#    'ids': []}},
#  {'category': 'DIFFERENT_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': "Did the US real estate market transition into a phase of stabilization post a remarkable expansion cycle, from 2010 through 2022, commencing with the Federal Reserve's decision to increase interest rates?"},
#   'ideal': {'paragraph': ['And now, more than two years on, property investors and managers are learning anew that whopping growth and profits eventually fall back to earth—a reversion to the mean, to use finance jargon, or simply normalizing, as numerous industry experts we interviewed put it.',
#     'Indeed, home sales—both new and existing—had an extraordinary 12-year run since bottoming out in the summer of 2010 until the Fed started hiking interest rates in the spring of 2022.'],
#    'filename': [],
#    'ids': []}},
#  {'category': 'SAME_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Given the factors that have influenced the real estate market after the COVID lockdown, did the market eventually experience a normalization or a return to the mean, according to industry experts?'},
#   'ideal': {'paragraph': ['And now, more than two years on, property investors and managers are learning anew that whopping growth and profits eventually fall back to earth—a reversion to the mean, to use finance jargon, or simply normalizing, as numerous industry experts we interviewed put it.',
#     'Indeed, home Economicnancial issues Interest rates and cost of capital Availability of qualied labor Job and income growth Ination Capital availability Global economic growth Tariffstrade conicts State and local taxes Federal taxes Currency exchange rates Socialpolitical issues Housing costs and availability 4.21 3.51 Geopolitical conicts Political extremism Immigration policy Epidemicspandemics Climate change Statelocal government budgets Income inequality Federal budget decit Higher education costs Diversity and inclusion Threat of terrorism Real estatedevelopment issues Construction labor costs Construction material costs Construction labor availability Land costs Operating costs State and local regulations Tenant leasing and retention costs NIMBYism Infrastructuretransportation Property taxes Environmentalsustainability requirements Risks from extreme weather Health and wellness features Municipal service cuts Health- and safety-related policies Source: Emerging Trends in Real Estate 2023 survey.'],
#    'filename': ['Emerging-Trends_USCanada-2023.pdf'],
#    'ids': ['index_150t_chunks:Emerging-Trends_USCanada-2023.pdf-!22']}},
#  {'category': 'DIFFERENT_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'In light of the influences shaping the property market post-COVID lockdown, did industry professionals perceive a reversion or recalibration back to its usual state?'},
#   'ideal': {'paragraph': ['And now, more than two years on, property investors and managers are learning anew that whopping growth and profits eventually fall back to earth—a reversion to the mean, to use finance jargon, or simply normalizing, as numerous industry experts we interviewed put it.',
#     'Indeed, home Economicnancial issues Interest rates and cost of capital Availability of qualied labor Job and income growth Ination Capital availability Global economic growth Tariffstrade conicts State and local taxes Federal taxes Currency exchange rates Socialpolitical issues Housing costs and availability 4.21 3.51 Geopolitical conicts Political extremism Immigration policy Epidemicspandemics Climate change Statelocal government budgets Income inequality Federal budget decit Higher education costs Diversity and inclusion Threat of terrorism Real estatedevelopment issues Construction labor costs Construction material costs Construction labor availability Land costs Operating costs State and local regulations Tenant leasing and retention costs NIMBYism Infrastructuretransportation Property taxes Environmentalsustainability requirements Risks from extreme weather Health and wellness features Municipal service cuts Health- and safety-related policies Source: Emerging Trends in Real Estate 2023 survey.'],
#    'filename': ['Emerging-Trends_USCanada-2023.pdf'],
#    'ids': ['index_150t_chunks:Emerging-Trends_USCanada-2023.pdf-!22']}},
#  {'category': 'SAME_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Is the increase in capitalization rates and the decrease in returns associated with rising interest rates and cost of capital, as observed in the U.S. property market? '},
#   'ideal': {'paragraph': ['These market reversions will take several forms: prices of most assets are declining as cap rates rise and transaction volumes fall from record levels, while rent gains for others are merely moderating as demand returns to more sustainable levels.',
#     'More than half believe that capitalization rates are heading up next year and returns are coming down, primarily due to rising interest rates and cost of capital, which was the top economic concern voiced in our survey.'],
#    'filename': ['Emerging-Trends_USCanada-2023.pdf'],
#    'ids': ['index_150t_chunks:Emerging-Trends_USCanada-2023.pdf-!21',
#     'index_150t_chunks:Emerging-Trends_USCanada-2023.pdf-!28']}},
#  {'category': 'DIFFERENT_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Can we link the escalating capitalization rates and dwindling returns to heightened interest rates and the escalating cost of capital, as discerned in the American real estate market?'},
#   'ideal': {'paragraph': ['These market reversions will take several forms: prices of most assets are declining as cap rates rise and transaction volumes fall from record levels, while rent gains for others are merely moderating as demand returns to more sustainable levels.',
#     'More than half believe that capitalization rates are heading up next year and returns are coming down, primarily due to rising interest rates and cost of capital, which was the top economic concern voiced in our survey.'],
#    'filename': ['Emerging-Trends_USCanada-2023.pdf'],
#    'ids': ['index_150t_chunks:Emerging-Trends_USCanada-2023.pdf-!21',
#     'index_150t_chunks:Emerging-Trends_USCanada-2023.pdf-!28']}},
#  {'category': 'SAME_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Despite the successful run of the U.S. commercial property markets after the COVID-19 lockdown, are cap rates and yields now rising in many markets, not just limited to the UK, without fully reflecting higher interest rates yet?'},
#   'ideal': {'paragraph': ['Defying just about every prediction voiced during the terrifying and uncertain days of the COVID lockdown that began in March 2020, U. S. commercial property markets actually embarked on a remarkable run.',
#     'We have already started to see cap rates and yields rise in many markets, with the most rapid adjustment taking place in the UK. However, we do not think that prices fully reflect higher interest rates yet.'],
#    'filename': ['global-real-estate-markets-2023.pdf',
#     'Emerging-Trends_USCanada-2023.pdf'],
#    'ids': ['index_150t_chunks:global-real-estate-markets-2023.pdf-!3',
#     'index_150t_chunks:Emerging-Trends_USCanada-2023.pdf-!20']}},
#  {'category': 'DIFFERENT_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': "Regardless of the U.S. commercial property markets' favorable performance post COVID-19 lockdown, are the capitalization rates and yields escalating across various markets, including but not limited to the UK, without full consideration of higher interest rates?"},
#   'ideal': {'paragraph': ['Defying just about every prediction voiced during the terrifying and uncertain days of the COVID lockdown that began in March 2020, U. S. commercial property markets actually embarked on a remarkable run.',
#     'We have already started to see cap rates and yields rise in many markets, with the most rapid adjustment taking place in the UK. However, we do not think that prices fully reflect higher interest rates yet.'],
#    'filename': ['global-real-estate-markets-2023.pdf',
#     'Emerging-Trends_USCanada-2023.pdf'],
#    'ids': ['index_150t_chunks:global-real-estate-markets-2023.pdf-!3',
#     'index_150t_chunks:Emerging-Trends_USCanada-2023.pdf-!20']}},
#  {'category': 'SAME_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Given the observations from the finance executive in the national homebuilder company and the survey results on rising interest rates, are both sources in agreement that the markets are normalizing?'},
#   'ideal': {'paragraph': ['Housing Set to Cool A finance executive with one national homebuilder told us, Were still selling. Its just not at the pace that it was selling before the last two years, which was a pace that you dont typi- cally see. So, the markets are more normalizing.',
#     'More than half believe that capitalization rates are heading up next year and returns are coming down, primarily due to rising interest rates and cost of capital, which was the top economic concern voiced in our survey. After more than a decade of lower for longer, the Fed is finally normalizing interest rates closer to historical levels.'],
#    'filename': ['Emerging-Trends_USCanada-2023.pdf'],
#    'ids': ['index_150t_chunks:Emerging-Trends_USCanada-2023.pdf-!22',
#     'index_150t_chunks:Emerging-Trends_USCanada-2023.pdf-!28']}},
#  {'category': 'DIFFERENT_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'In light of the statements by the finance executive at the national homebuilder company and the data from surveys on increased interest rates, do both sources concur that there is a reversion to the norm occurring within the markets?'},
#   'ideal': {'paragraph': ['Housing Set to Cool A finance executive with one national homebuilder told us, Were still selling. Its just not at the pace that it was selling before the last two years, which was a pace that you dont typi- cally see. So, the markets are more normalizing.',
#     'More than half believe that capitalization rates are heading up next year and returns are coming down, primarily due to rising interest rates and cost of capital, which was the top economic concern voiced in our survey. After more than a decade of lower for longer, the Fed is finally normalizing interest rates closer to historical levels.'],
#    'filename': ['Emerging-Trends_USCanada-2023.pdf'],
#    'ids': ['index_150t_chunks:Emerging-Trends_USCanada-2023.pdf-!22',
#     'index_150t_chunks:Emerging-Trends_USCanada-2023.pdf-!28']}},
#  {'category': 'SAME_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': "Is it true that the economic growth in China in 2023 is expected to be lower than the historical averages, but the country's recovery is predicted to be on track during the 2023-2025 period, albeit at a slower pace?"},
#   'ideal': {'paragraph': ['Economic growth in China in 2023 should be below historical averages,',
#     'During the outlook period, China is expected to recover and follow its growth path but at a slower pace.'],
#    'filename': ['bouwinvest_international-market-outlook_2023-2025-1.pdf',
#     'isa-outlook-2023.pdf'],
#    'ids': ['index_150t_chunks:isa-outlook-2023.pdf-!69',
#     'index_150t_chunks:bouwinvest_international-market-outlook_2023-2025-1.pdf-!26']}},
#  {'category': 'DIFFERENT_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': "Can it be confirmed that China's anticipated economic expansion in 2023 will be less than its historical norm, but the nation's rebound is forecasted to progress steadily between 2023 and 2025, albeit at a more measured rate?"},
#   'ideal': {'paragraph': ['Economic growth in China in 2023 should be below historical averages,',
#     'During the outlook period, China is expected to recover and follow its growth path but at a slower pace.'],
#    'filename': ['bouwinvest_international-market-outlook_2023-2025-1.pdf',
#     'isa-outlook-2023.pdf'],
#    'ids': ['index_150t_chunks:isa-outlook-2023.pdf-!69',
#     'index_150t_chunks:bouwinvest_international-market-outlook_2023-2025-1.pdf-!26']}},
#  {'category': 'SAME_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': "Is it accurate to say that while the Monetary Authority of Singapore manages monetary policies through the foreign exchange markets, Singapore's economic strength and geopolitical stability are likely to fare slightly better financial conditions than South Korea and Australia?"},
#   'ideal': {'paragraph': ['The Monetary Authority of Singapore manages monetary policies through the foreign exchange markets... Financial conditions in Singapore are expected to fare slightly better than those of South Korea and Australia, as Singapore benefits from strong investor appetite due to its relative economic strength and geopolitical stability.',
#     "Singapore's relative attractiveness to Hong Kong is expected to increase... Singapores relative attractiveness to Hong Kong is expec- ted to increase."],
#    'filename': [],
#    'ids': []}},
#  {'category': 'DIFFERENT_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': "Is it fair to claim that despite the Monetary Authority of Singapore directing monetary policies through foreign exchange markets, Singapore's economic resilience and geopolitical equilibrium are predicted to withstand slightly superior financial conditions compared to South Korea and Australia?"},
#   'ideal': {'paragraph': ['The Monetary Authority of Singapore manages monetary policies through the foreign exchange markets... Financial conditions in Singapore are expected to fare slightly better than those of South Korea and Australia, as Singapore benefits from strong investor appetite due to its relative economic strength and geopolitical stability.',
#     "Singapore's relative attractiveness to Hong Kong is expected to increase... Singapores relative attractiveness to Hong Kong is expec- ted to increase."],
#    'filename': [],
#    'ids': []}},
#  {'category': 'SAME_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Is it correct to say that while Japan is facing externally driven challenges, it is expected to maintain stable monetary policies with the Bank of Japan keeping interest rates near zero, thereby ensuring the spread between property yields and the risk-free rate remains intact?'},
#   'ideal': {'paragraph': ['In Japan, yield curve control comes at the cost of a weak yen. If the Bank of Japan (BoJ) remains committed to keeping interest rates near zero, currency intervention, such as yen-buying to prevent further depreciation, could be on the table again... most of the challenges Japan is facing are externally driven, while domestic-driven fundamentals remain relatively healthy.',
#     'Higher interest rates are a concern for all Asia-Pacific markets, with the exception of China and Japan. Japan is keeping a lid on interest rate growth and its benchmark 10-year government bond rate remains close to zero. The spread between property yields and the risk-free rate is therefore intact.'],
#    'filename': [],
#    'ids': []}},
#  {'category': 'DIFFERENT_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Would it be right to state that, despite external pressures, Japan is anticipated to uphold steady monetary policies with the Bank of Japan maintaining interest rates close to zero, ensuring the differential between property yields and the risk-free rate remains constant?'},
#   'ideal': {'paragraph': ['In Japan, yield curve control comes at the cost of a weak yen. If the Bank of Japan (BoJ) remains committed to keeping interest rates near zero, currency intervention, such as yen-buying to prevent further depreciation, could be on the table again... most of the challenges Japan is facing are externally driven, while domestic-driven fundamentals remain relatively healthy.',
#     'Higher interest rates are a concern for all Asia-Pacific markets, with the exception of China and Japan. Japan is keeping a lid on interest rate growth and its benchmark 10-year government bond rate remains close to zero. The spread between property yields and the risk-free rate is therefore intact.'],
#    'filename': [],
#    'ids': []}},
#  {'category': 'SAME_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Is the Bank of Japan committed to keeping interest rates near zero which can make Japan an attractive diversifier for institutional investors?'},
#   'ideal': {'paragraph': ['In Japan, yield curve control comes at the cost of a weak yen. If the Bank of Japan (BoJ) remains committed to keeping interest rates near zero, currency intervention, such as yen-buying to prevent further depreciation, could be on the table again.',
#     'Japan remains an attractive diversifier for institutional investors regional and global real estate portfolios, due to the relative resiliency of its occupier and capital market fundamentals, its stable geopolitical environment and divergent monetary policies.'],
#    'filename': ['isa-outlook-2023.pdf'],
#    'ids': ['index_150t_chunks:isa-outlook-2023.pdf-!91']}},
#  {'category': 'DIFFERENT_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Is the Bank of Japan devoted to sustaining interest rates close to zero, potentially making Japan an appealing choice for institutional investors? '},
#   'ideal': {'paragraph': ['In Japan, yield curve control comes at the cost of a weak yen. If the Bank of Japan (BoJ) remains committed to keeping interest rates near zero, currency intervention, such as yen-buying to prevent further depreciation, could be on the table again.',
#     'Japan remains an attractive diversifier for institutional investors regional and global real estate portfolios, due to the relative resiliency of its occupier and capital market fundamentals, its stable geopolitical environment and divergent monetary policies.'],
#    'filename': ['isa-outlook-2023.pdf'],
#    'ids': ['index_150t_chunks:isa-outlook-2023.pdf-!91']}},
#  {'category': 'SAME_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': "Does the Bank of Japan's commitment to keeping interest rates near zero lead to a strong yen?"},
#   'ideal': {'paragraph': ['In Japan, yield curve control comes at the cost of a weak yen. If the Bank of Japan (BoJ) remains committed to keeping interest rates near zero, currency intervention, such as yen-buying to prevent further depreciation, could be on the table again.',
#     'Japan remains an attractive diversifier for institutional investors regional and global real estate portfolios, due to the relative resiliency of its occupier and capital market fundamentals, its stable geopolitical environment and divergent monetary policies.'],
#    'filename': ['isa-outlook-2023.pdf'],
#    'ids': ['index_150t_chunks:isa-outlook-2023.pdf-!91']}},
#  {'category': 'DIFFERENT_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Does the commitment of the Bank of Japan to maintain near-zero interest rates result in a fortified yen?'},
#   'ideal': {'paragraph': ['In Japan, yield curve control comes at the cost of a weak yen. If the Bank of Japan (BoJ) remains committed to keeping interest rates near zero, currency intervention, such as yen-buying to prevent further depreciation, could be on the table again.',
#     'Japan remains an attractive diversifier for institutional investors regional and global real estate portfolios, due to the relative resiliency of its occupier and capital market fundamentals, its stable geopolitical environment and divergent monetary policies.'],
#    'filename': ['isa-outlook-2023.pdf'],
#    'ids': ['index_150t_chunks:isa-outlook-2023.pdf-!91']}},
#  {'category': 'SAME_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': "Do Asia Pacific real estate markets, being dominated by domestic and intra-regional capital, signify that higher interest rates are a major concern for Japan's real estate yield spread?"},
#   'ideal': {'paragraph': ['In theory, weak currencies offer attractive discounts for cross-regional investors, but Asia Pacific real estate capital markets are traditionally dominated by domestic and intra-regional capital. In this cycle, most of these capital sources should remain well- capitalized with little financial pressure to sell.',
#     'Australia is cementing its status as a safe haven in the region. Singapores relative attractiveness to Hong Kong is expected to increase. Higher interest rates are less of a concern in Japan where the spread between the risk-free rate and real estate yields remains stable.'],
#    'filename': ['isa-outlook-2023.pdf'],
#    'ids': ['index_150t_chunks:isa-outlook-2023.pdf-!77']}},
#  {'category': 'DIFFERENT_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': "With Asia Pacific property markets primarily influenced by domestic and intra-regional capital, does this suggest that escalating interest rates are a significant worry for Japan's property yield spread?"},
#   'ideal': {'paragraph': ['In theory, weak currencies offer attractive discounts for cross-regional investors, but Asia Pacific real estate capital markets are traditionally dominated by domestic and intra-regional capital. In this cycle, most of these capital sources should remain well- capitalized with little financial pressure to sell.',
#     'Australia is cementing its status as a safe haven in the region. Singapores relative attractiveness to Hong Kong is expected to increase. Higher interest rates are less of a concern in Japan where the spread between the risk-free rate and real estate yields remains stable.'],
#    'filename': ['isa-outlook-2023.pdf'],
#    'ids': ['index_150t_chunks:isa-outlook-2023.pdf-!77']}},
#  {'category': 'SAME_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Given the stable risk-free rate and real estate yields in Japan and domestic capital dominance in the Asia Pacific region, is Australia seen as a safe haven in the region?'},
#   'ideal': {'paragraph': ['In theory, weak currencies offer attractive discounts for cross-regional investors, but Asia Pacific real estate capital markets are traditionally dominated by domestic and intra-regional capital. In this cycle, most of these capital sources should remain well- capitalized with little financial pressure to sell.',
#     'Australia is cementing its status as a safe haven in the region. Singapores relative attractiveness to Hong Kong is expected to increase. Higher interest rates are less of a concern in Japan where the spread between the risk-free rate and real estate yields remains stable.'],
#    'filename': ['isa-outlook-2023.pdf'],
#    'ids': ['index_150t_chunks:isa-outlook-2023.pdf-!77']}},
#  {'category': 'DIFFERENT_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'In view of the constant risk-free rate and property yields in Japan and the prevalence of domestic capital in the Asia Pacific, is Australia considered a safe harbor in the region?'},
#   'ideal': {'paragraph': ['In theory, weak currencies offer attractive discounts for cross-regional investors, but Asia Pacific real estate capital markets are traditionally dominated by domestic and intra-regional capital. In this cycle, most of these capital sources should remain well- capitalized with little financial pressure to sell.',
#     'Australia is cementing its status as a safe haven in the region. Singapores relative attractiveness to Hong Kong is expected to increase. Higher interest rates are less of a concern in Japan where the spread between the risk-free rate and real estate yields remains stable.'],
#    'filename': ['isa-outlook-2023.pdf'],
#    'ids': ['index_150t_chunks:isa-outlook-2023.pdf-!77']}},
#  {'category': 'SAME_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Are interest rates expected to continue rising indefinitely, impacting real estate values?'},
#   'ideal': {'paragraph': ['Inflation should eventually settle closer to central banks target levels, allowing the longed-for pivot in interest rates.',
#     'The relentless math of higher interest rates will continue to weigh heavily on real estate values, at least until interest rates stabilize as inflation begins to subside.'],
#    'filename': ['isa-outlook-2023.pdf'],
#    'ids': ['index_150t_chunks:isa-outlook-2023.pdf-!20',
#     'index_150t_chunks:isa-outlook-2023.pdf-!30']}},
#  {'category': 'DIFFERENT_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Are interest rates projected to persistently climb, detrimentally affecting property values?'},
#   'ideal': {'paragraph': ['Inflation should eventually settle closer to central banks target levels, allowing the longed-for pivot in interest rates.',
#     'The relentless math of higher interest rates will continue to weigh heavily on real estate values, at least until interest rates stabilize as inflation begins to subside.'],
#    'filename': ['isa-outlook-2023.pdf'],
#    'ids': ['index_150t_chunks:isa-outlook-2023.pdf-!20',
#     'index_150t_chunks:isa-outlook-2023.pdf-!30']}},
#  {'category': 'SAME_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Can we conclude that the denominator effect is expected to force all institutional investors to sell their real estate assets?'},
#   'ideal': {'paragraph': ['And while interest rates are increasing, equity and bond prices have been falling, triggering the denominator effect for some institutional investors with asset allocations that must remain in balance.',
#     'Denominator effects and higher borrowing costs will keep a meaningful fraction of core and higher return buyers on the sidelines, especially at the start of 2023.'],
#    'filename': ['isa-outlook-2023.pdf', 'Emerging-Trends_USCanada-2023.pdf'],
#    'ids': ['index_150t_chunks:Emerging-Trends_USCanada-2023.pdf-!45',
#     'index_150t_chunks:isa-outlook-2023.pdf-!138']}},
#  {'category': 'DIFFERENT_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Is it reasonable to expect the denominator effect to compel all institutional investors to offload their real estate holdings? '},
#   'ideal': {'paragraph': ['And while interest rates are increasing, equity and bond prices have been falling, triggering the denominator effect for some institutional investors with asset allocations that must remain in balance.',
#     'Denominator effects and higher borrowing costs will keep a meaningful fraction of core and higher return buyers on the sidelines, especially at the start of 2023.'],
#    'filename': ['isa-outlook-2023.pdf', 'Emerging-Trends_USCanada-2023.pdf'],
#    'ids': ['index_150t_chunks:Emerging-Trends_USCanada-2023.pdf-!45',
#     'index_150t_chunks:isa-outlook-2023.pdf-!138']}},
#  {'category': 'SAME_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Can we infer that higher debt costs are the only determinant of real estate valuations?'},
#   'ideal': {'paragraph': ['Ultimately, however, valuations are the result of the interaction between higher debt costs and the path of real estate fundamentals, the prospects for which vary widely across sectors and geographies.',
#     'With the normalisation of monetary policy that has now begun, this situation should dissolve and the rise in real estate yields should be flatter than that of the risk-free interest rate.'],
#    'filename': ['outlook-real-estatet-market-germany-dec-2022.pdf',
#     'isa-outlook-2023.pdf'],
#    'ids': ['index_150t_chunks:isa-outlook-2023.pdf-!32',
#     'index_150t_chunks:outlook-real-estatet-market-germany-dec-2022.pdf-!21']}},
#  {'category': 'DIFFERENT_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Can we deduce that escalating debt expenses are the sole factor influencing property evaluations?'},
#   'ideal': {'paragraph': ['Ultimately, however, valuations are the result of the interaction between higher debt costs and the path of real estate fundamentals, the prospects for which vary widely across sectors and geographies.',
#     'With the normalisation of monetary policy that has now begun, this situation should dissolve and the rise in real estate yields should be flatter than that of the risk-free interest rate.'],
#    'filename': ['outlook-real-estatet-market-germany-dec-2022.pdf',
#     'isa-outlook-2023.pdf'],
#    'ids': ['index_150t_chunks:isa-outlook-2023.pdf-!32',
#     'index_150t_chunks:outlook-real-estatet-market-germany-dec-2022.pdf-!21']}},
#  {'category': 'SAME_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Will the increase in interest rates cease to impact real estate values as soon as inflation begins to decrease?'},
#   'ideal': {'paragraph': ['Says the regional leader of one global firm, Cap rates have gapped out as interest rates went up. And suddenly, things didnt pencil, and that generated broken deals. The cost of financing for real estate and everything else went up dramatically.',
#     'The relentless math of higher interest rates will continue to weigh heavily on real estate values, at least until interest rates stabilize as inflation begins to subside.'],
#    'filename': ['isa-outlook-2023.pdf', 'Emerging-Trends_USCanada-2023.pdf'],
#    'ids': ['index_150t_chunks:Emerging-Trends_USCanada-2023.pdf-!44',
#     'index_150t_chunks:isa-outlook-2023.pdf-!30']}},
#  {'category': 'DIFFERENT_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Will the escalation in interest rates stop influencing property values as soon as deflation initiates?'},
#   'ideal': {'paragraph': ['Says the regional leader of one global firm, Cap rates have gapped out as interest rates went up. And suddenly, things didnt pencil, and that generated broken deals. The cost of financing for real estate and everything else went up dramatically.',
#     'The relentless math of higher interest rates will continue to weigh heavily on real estate values, at least until interest rates stabilize as inflation begins to subside.'],
#    'filename': ['isa-outlook-2023.pdf', 'Emerging-Trends_USCanada-2023.pdf'],
#    'ids': ['index_150t_chunks:Emerging-Trends_USCanada-2023.pdf-!44',
#     'index_150t_chunks:isa-outlook-2023.pdf-!30']}},
#  {'category': 'SAME_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Does the current economic robustness in the US, Canada, and Singapore likely support a pivot in interest rates, assuming inflation settles closer to the target levels of central banks?'},
#   'ideal': {'paragraph': ['Inflation should eventually settle closer to central banks target levels, allowing the longed-for pivot in interest rates.',
#     'The dominant driver of inflation in the US, Canada and Singapore is that their economies are robust and operating close to full capacity.'],
#    'filename': ['isa-outlook-2023.pdf'],
#    'ids': ['index_150t_chunks:isa-outlook-2023.pdf-!20',
#     'index_150t_chunks:isa-outlook-2023.pdf-!33']}},
#  {'category': 'DIFFERENT_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Is the current economic resilience in the US, Canada, and Singapore likely to foster a shift in interest rates, assuming inflation steadies closer to the benchmark levels set by central banks?'},
#   'ideal': {'paragraph': ['Inflation should eventually settle closer to central banks target levels, allowing the longed-for pivot in interest rates.',
#     'The dominant driver of inflation in the US, Canada and Singapore is that their economies are robust and operating close to full capacity.'],
#    'filename': ['isa-outlook-2023.pdf'],
#    'ids': ['index_150t_chunks:isa-outlook-2023.pdf-!20',
#     'index_150t_chunks:isa-outlook-2023.pdf-!33']}},
#  {'category': 'SAME_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Can we infer that all-cash buyers gained more prominence in the market during the end of 2022 due to the higher borrowing costs and prime yields being below the cost of debt capital?'},
#   'ideal': {'paragraph': ['At the end of the third quarter of 2022, prime yields in all major market segments were below the cost of debt capital.',
#     "This is one of those cash is king situations where borrowing costs are higher, and if you're an all-cash buyer, those probably represent a disproportionate share of the people in the market today."],
#    'filename': ['outlook-real-estatet-market-germany-dec-2022.pdf'],
#    'ids': ['index_150t_chunks:outlook-real-estatet-market-germany-dec-2022.pdf-!22']}},
#  {'category': 'DIFFERENT_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Can we deduce that purchasers paying in cash came to the fore in the market towards the end of 2022 due to the escalating borrowing expenses and prime yields being beneath the cost of debt capital?'},
#   'ideal': {'paragraph': ['At the end of the third quarter of 2022, prime yields in all major market segments were below the cost of debt capital.',
#     "This is one of those cash is king situations where borrowing costs are higher, and if you're an all-cash buyer, those probably represent a disproportionate share of the people in the market today."],
#    'filename': ['outlook-real-estatet-market-germany-dec-2022.pdf'],
#    'ids': ['index_150t_chunks:outlook-real-estatet-market-germany-dec-2022.pdf-!22']}},
#  {'category': 'SAME_WORDING_MULTIPLE_PARAGRAPHS',
# ...
#    'filename': ['Emerging-Trends_USCanada-2023.pdf'],
#    'ids': ['index_150t_chunks:Emerging-Trends_USCanada-2023.pdf-!259']}},
#  {'category': 'DIFFERENT_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'How many of the top 10 markets from the previous year retained their position this year?'},
#   'ideal': {'paragraph': ['Many of the changes were relatively minor, and nine of the 10 highest-rated markets last year repeated this year .'],
#    'filename': ['Emerging-Trends_USCanada-2023.pdf'],
#    'ids': ['index_150t_chunks:Emerging-Trends_USCanada-2023.pdf-!259']}},
#  {'category': 'SAME_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'How many markets moved up or down in rankings by at least 10 places?'},
#   'ideal': {'paragraph': ['But there were some material changes over the year as about a quarter of markets moved up or down in rankings by at least 10 places.'],
#    'filename': ['Emerging-Trends_USCanada-2023.pdf'],
#    'ids': ['index_150t_chunks:Emerging-Trends_USCanada-2023.pdf-!259']}},
#  {'category': 'DIFFERENT_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'How many markets experienced a rise or fall of at least 10 spots in the rankings?'},
#   'ideal': {'paragraph': ['But there were some material changes over the year as about a quarter of markets moved up or down in rankings by at least 10 places.'],
#    'filename': ['Emerging-Trends_USCanada-2023.pdf'],
#    'ids': ['index_150t_chunks:Emerging-Trends_USCanada-2023.pdf-!259']}},
#  {'category': 'SAME_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'How many of the 20-highest rated markets in last years survey fell in the rankings this year?'},
#   'ideal': {'paragraph': ['More than half (11) of the 20-highest rated markets in last years survey fell in the rankings this year, although almost all by less than 10 places. '],
#    'filename': [],
#    'ids': []}},
#  {'category': 'DIFFERENT_WORDING_ONE_PARAGRAPH',
#   'input': {'question': "How many of the top 20 markets from the previous year's survey saw a decrease in their rankings this year?"},
#   'ideal': {'paragraph': ['More than half (11) of the 20-highest rated markets in last years survey fell in the rankings this year, although almost all by less than 10 places. '],
#    'filename': [],
#    'ids': []}},
#  {'category': 'SAME_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'How many of the 20-lowest rated markets in last years survey rose in the rankings this year?'},
#   'ideal': {'paragraph': ['Thirteen of the 20-lowest rated markets in last years survey rose in the rankings this year.'],
#    'filename': ['Emerging-Trends_USCanada-2023.pdf'],
#    'ids': ['index_150t_chunks:Emerging-Trends_USCanada-2023.pdf-!260']}},
#  {'category': 'DIFFERENT_WORDING_ONE_PARAGRAPH',
#   'input': {'question': "How many of the 20 lowest-ranked markets from the previous year's survey experienced an increase in rankings this year?"},
#   'ideal': {'paragraph': ['Thirteen of the 20-lowest rated markets in last years survey rose in the rankings this year.'],
#    'filename': ['Emerging-Trends_USCanada-2023.pdf'],
#    'ids': ['index_150t_chunks:Emerging-Trends_USCanada-2023.pdf-!260']}},
#  {'category': 'SAME_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'How many Sun Belt markets were among the top 20 markets for overall prospects in 2011?'},
#   'ideal': {'paragraph': ['The number of Sun Belt markets among the top 20 markets for overall prospects has increased from 10 in 2011 to 14 in each of the past two years.'],
#    'filename': ['Emerging-Trends_USCanada-2023.pdf'],
#    'ids': ['index_150t_chunks:Emerging-Trends_USCanada-2023.pdf-!260']}},
#  {'category': 'DIFFERENT_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'How many Sun Belt markets were in the top 20 overall prospects in 2011?'},
#   'ideal': {'paragraph': ['The number of Sun Belt markets among the top 20 markets for overall prospects has increased from 10 in 2011 to 14 in each of the past two years.'],
#    'filename': ['Emerging-Trends_USCanada-2023.pdf'],
#    'ids': ['index_150t_chunks:Emerging-Trends_USCanada-2023.pdf-!260']}},
#  {'category': 'SAME_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'What effect did property values have in midyear 2022?'},
#   'ideal': {'paragraph': ['Property values dropped 10 to 20 percent as of midyear 2022'],
#    'filename': ['Emerging-Trends_USCanada-2023.pdf'],
#    'ids': ['index_150t_chunks:Emerging-Trends_USCanada-2023.pdf-!222']}},
#  {'category': 'DIFFERENT_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'How did property values behave in the middle of 2022?'},
#   'ideal': {'paragraph': ['Property values dropped 10 to 20 percent as of midyear 2022'],
#    'filename': ['Emerging-Trends_USCanada-2023.pdf'],
#    'ids': ['index_150t_chunks:Emerging-Trends_USCanada-2023.pdf-!222']}},
#  {'category': 'SAME_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'What is the average size of a metro area in the Supernova category?'},
#   'ideal': {'paragraph': ['Like the astronomic source for its name, the five metro areas in the Supernova category markets have exploded into prominence over the past decade or so. All are smaller markets with 1 million to 2 million residents, but their defining attribute is their tremendous and sustained population and job growth, which are well above national averages.'],
#    'filename': ['Emerging-Trends_USCanada-2023.pdf'],
#    'ids': ['index_150t_chunks:Emerging-Trends_USCanada-2023.pdf-!274']}},
#  {'category': 'DIFFERENT_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'What is the typical population of a metropolitan area classified under the Supernova category?'},
#   'ideal': {'paragraph': ['Like the astronomic source for its name, the five metro areas in the Supernova category markets have exploded into prominence over the past decade or so. All are smaller markets with 1 million to 2 million residents, but their defining attribute is their tremendous and sustained population and job growth, which are well above national averages.'],
#    'filename': ['Emerging-Trends_USCanada-2023.pdf'],
#    'ids': ['index_150t_chunks:Emerging-Trends_USCanada-2023.pdf-!274']}},
#  {'category': 'SAME_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'What is the rate of the 18-Hour Cities in terms of economic output among the 12 subgroups?'},
#   'ideal': {'paragraph': ['As a group, the 18-Hour Cities rate third highest among the 12 subgroups, though the average market ranking fell this year as four of the markets declined while three rose. '],
#    'filename': ['Emerging-Trends_USCanada-2023.pdf'],
#    'ids': ['index_150t_chunks:Emerging-Trends_USCanada-2023.pdf-!274']}},
#  {'category': 'DIFFERENT_WORDING_ONE_PARAGRAPH',
#   'input': {'question': "What's the economic output ranking of the 18-Hour Cities among the 12 subgroups?"},
#   'ideal': {'paragraph': ['As a group, the 18-Hour Cities rate third highest among the 12 subgroups, though the average market ranking fell this year as four of the markets declined while three rose. '],
#    'filename': ['Emerging-Trends_USCanada-2023.pdf'],
#    'ids': ['index_150t_chunks:Emerging-Trends_USCanada-2023.pdf-!274']}},
#  {'category': 'SAME_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'What is the trend of tourist numbers?'},
#   'ideal': {'paragraph': ['Tourist numbers almost back to 2019 levels'],
#    'filename': ['2022-09-21_Immobilienmarkt_Deutschland_2022_2023_EN.pdf'],
#    'ids': ['index_150t_chunks:2022-09-21_Immobilienmarkt_Deutschland_2022_2023_EN.pdf-!63']}},
#  {'category': 'DIFFERENT_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'How are tourist numbers moving?'},
#   'ideal': {'paragraph': ['Tourist numbers almost back to 2019 levels'],
#    'filename': ['2022-09-21_Immobilienmarkt_Deutschland_2022_2023_EN.pdf'],
#    'ids': ['index_150t_chunks:2022-09-21_Immobilienmarkt_Deutschland_2022_2023_EN.pdf-!63']}},
#  {'category': 'SAME_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'What is the average monthly disposable income per household in Euro?'},
#   'ideal': {'paragraph': ['Average monthly disposable income per household: EUR 3,726 Euro'],
#    'filename': ['2022-09-21_Immobilienmarkt_Deutschland_2022_2023_EN.pdf'],
#    'ids': ['index_150t_chunks:2022-09-21_Immobilienmarkt_Deutschland_2022_2023_EN.pdf-!46']}},
#  {'category': 'DIFFERENT_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'What is the typical sum of money each household can expend monthly in the Eurozone?'},
#   'ideal': {'paragraph': ['Average monthly disposable income per household: EUR 3,726 Euro'],
#    'filename': ['2022-09-21_Immobilienmarkt_Deutschland_2022_2023_EN.pdf'],
#    'ids': ['index_150t_chunks:2022-09-21_Immobilienmarkt_Deutschland_2022_2023_EN.pdf-!46']}},
#  {'category': 'SAME_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'How has consumer sentiment been impacted by the war in Ukraine, inflation and the gas crisis?'},
#   'ideal': {'paragraph': ['The war in Ukraine, inflation and the gas crisis are key concerns for people. This is reflected in consumer sentiment which has fallen to a historic low.'],
#    'filename': ['2022-09-21_Immobilienmarkt_Deutschland_2022_2023_EN.pdf'],
#    'ids': ['index_150t_chunks:2022-09-21_Immobilienmarkt_Deutschland_2022_2023_EN.pdf-!46']}},
#  {'category': 'DIFFERENT_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'How did the Ukraine war, inflation and gas crisis affect consumer mood?'},
#   'ideal': {'paragraph': ['The war in Ukraine, inflation and the gas crisis are key concerns for people. This is reflected in consumer sentiment which has fallen to a historic low.'],
#    'filename': ['2022-09-21_Immobilienmarkt_Deutschland_2022_2023_EN.pdf'],
#    'ids': ['index_150t_chunks:2022-09-21_Immobilienmarkt_Deutschland_2022_2023_EN.pdf-!46']}},
#  {'category': 'SAME_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'When did new home prices peak?'},
#   'ideal': {'paragraph': ['New home prices peaked in April 2022, while prices of existing homes likely peaked in June after appreciation started to slow with the rise in mortgage rates.'],
#    'filename': ['Emerging-Trends_USCanada-2023.pdf'],
#    'ids': ['index_150t_chunks:Emerging-Trends_USCanada-2023.pdf-!24']}},
#  {'category': 'DIFFERENT_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'In which month did new home prices reach their highest point?'},
#   'ideal': {'paragraph': ['New home prices peaked in April 2022, while prices of existing homes likely peaked in June after appreciation started to slow with the rise in mortgage rates.'],
#    'filename': ['Emerging-Trends_USCanada-2023.pdf'],
#    'ids': ['index_150t_chunks:Emerging-Trends_USCanada-2023.pdf-!24']}},
#  {'category': 'SAME_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'What is the phone number of DZ HYP AG?'},
#   'ideal': {'paragraph': ['DZ HYP AG Rosenstrasse 2 20095 Hamburg Germany Phone 49 40 3334-0 dzhyp.'],
#    'filename': ['2022-09-21_Immobilienmarkt_Deutschland_2022_2023_EN.pdf'],
#    'ids': ['index_150t_chunks:2022-09-21_Immobilienmarkt_Deutschland_2022_2023_EN.pdf-!190']}},
#  {'category': 'DIFFERENT_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'What is the contact number for DZ HYP AG?'},
#   'ideal': {'paragraph': ['DZ HYP AG Rosenstrasse 2 20095 Hamburg Germany Phone 49 40 3334-0 dzhyp.'],
#    'filename': ['2022-09-21_Immobilienmarkt_Deutschland_2022_2023_EN.pdf'],
#    'ids': ['index_150t_chunks:2022-09-21_Immobilienmarkt_Deutschland_2022_2023_EN.pdf-!190']}},
#  {'category': 'SAME_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'How much does the U.S. apartment property sector contribute annually to the U.S. economy according to the NMHC?'},
#   'ideal': {'paragraph': ['The U. S. apartment property sectorproviding shelter to 37 mil- lion residents in 21.3 million structures of five or more household units, and contributing $3.4 trillion annually to the U. S. economy, according to the NMHC'],
#    'filename': [],
#    'ids': []}},
#  {'category': 'DIFFERENT_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'What annual contribution does the U.S. apartment property sector make to the U.S. economy as per the NMHC?'},
#   'ideal': {'paragraph': ['The U. S. apartment property sectorproviding shelter to 37 mil- lion residents in 21.3 million structures of five or more household units, and contributing $3.4 trillion annually to the U. S. economy, according to the NMHC'],
#    'filename': [],
#    'ids': []}},
#  {'category': 'SAME_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'How much higher was the number of new units authorized in multifamily buildings over the past 12 months as of June 2022 compared to the same period in 2018-2019, as per a Bloomberg report?'},
#   'ideal': {'paragraph': ['According to a recent Bloomberg report, After dipping in 2020, the number of new units authorized in multifamily build- ings took off, running 37 percent higher over the past 12 months as of June 2022 than in the same period in 20182019. '],
#    'filename': ['Emerging-Trends_USCanada-2023.pdf'],
#    'ids': ['index_150t_chunks:Emerging-Trends_USCanada-2023.pdf-!146']}},
#  {'category': 'DIFFERENT_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'By what percentage was the authorization of new units in multifamily buildings higher over the last 12 months up to June 2022, in comparison with the same period in 2018-2019, according to a Bloomberg report?'},
#   'ideal': {'paragraph': ['According to a recent Bloomberg report, After dipping in 2020, the number of new units authorized in multifamily build- ings took off, running 37 percent higher over the past 12 months as of June 2022 than in the same period in 20182019. '],
#    'filename': ['Emerging-Trends_USCanada-2023.pdf'],
#    'ids': ['index_150t_chunks:Emerging-Trends_USCanada-2023.pdf-!146']}},
#  {'category': 'SAME_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'What percentage increase in apartments under construction was observed as of August, compared to a year ago?'},
#   'ideal': {'paragraph': ['As of August, 862,000 apartments were under construction, up 25 percent from a year ago.'],
#    'filename': ['Emerging-Trends_USCanada-2023.pdf'],
#    'ids': ['index_150t_chunks:Emerging-Trends_USCanada-2023.pdf-!146']}},
#  {'category': 'DIFFERENT_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'What was the year-on-year growth rate in apartments under construction as of August?'},
#   'ideal': {'paragraph': ['As of August, 862,000 apartments were under construction, up 25 percent from a year ago.'],
#    'filename': ['Emerging-Trends_USCanada-2023.pdf'],
#    'ids': ['index_150t_chunks:Emerging-Trends_USCanada-2023.pdf-!146']}},
#  {'category': 'SAME_WORDING_ONE_PARAGRAPH',
#   'input': {'question': "What percentage increase did renters making at least $75,000 see over the decade ending just before the pandemic, according to Harvard's Joint Center for Housing Studies (JCHS)?"},
#   'ideal': {'paragraph': ['According to Harvards Joint Center for Housing Studies (JCHS), the number of renters making at least $75,000 jumped by 48 percent over the decade ending just before the pandemic, to 11.3 million.'],
#    'filename': [],
#    'ids': []}},
#  {'category': 'DIFFERENT_WORDING_ONE_PARAGRAPH',
#   'input': {'question': "By what percentage did the number of renters earning at least $75,000 increase over the decade ending just before the pandemic, as per the Harvard's Joint Center for Housing Studies (JCHS)?"},
#   'ideal': {'paragraph': ['According to Harvards Joint Center for Housing Studies (JCHS), the number of renters making at least $75,000 jumped by 48 percent over the decade ending just before the pandemic, to 11.3 million.'],
#    'filename': [],
#    'ids': []}},
#  {'category': 'SAME_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'Who is Jeff Smith?'},
#   'ideal': {'paragraph': ["Jeff Smith is Deloitte's National Real Estate leader with nearly 30 years of audit and accounting experience."],
#    'filename': [],
#    'ids': []}},
#  {'category': 'DIFFERENT_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'In what capacity does Jeff Smith serve?'},
#   'ideal': {'paragraph': ["Jeff Smith is Deloitte's National Real Estate leader with nearly 30 years of audit and accounting experience."],
#    'filename': [],
#    'ids': []}}]

# %%
import jsonlines
import datetime
with jsonlines.open(f"retriever_dataset_t_150c_{datetime.datetime.now().strftime('%Y%m%d')}.jsonl", "w") as writer:
    writer.write_all(retriever_rows)

# %%
import json
import blobfile as bf
import pandas as pd
from transformers import AutoTokenizer
from fuzzywuzzy import fuzz

tokenizer = AutoTokenizer.from_pretrained('intfloat/e5-large-v2')

chunk_csv = 'redis-test/index_e5_embeddings.csv'
chunk_df = pd.read_csv(chunk_csv)
chunk_df.rename(columns={"text_chunk": "text"}, inplace=True)
# clean the text column to remove the [CLS] and [SEP] tokens by using a lambda function
chunk_df['text'] = chunk_df['text'].apply(lambda x: x.replace(' [SEP] [CLS] ', ' '))



dataset = json.load(bf.BlobFile("all_dataset_final.json", "rb"))
# print every question answer pair except for the NOT_SOURCE_BASED category
for i, datapoint in enumerate(dataset):
    if datapoint["category"] == "NOT_SOURCE_BASED":
        continue
    if len(datapoint["sentences"]) > 0:
        datapoint["e5_paragraph"] = []
        datapoint["e5_sentences"] = []
        for sentence in datapoint["sentences"]:
            sentence = tokenizer.encode(sentence, add_special_tokens=True)
            sentence = tokenizer.decode(sentence)
            sentence = sentence.replace("[CLS]", "").replace("[SEP]", "").strip()
            datapoint["e5_sentences"].append(sentence)
            row = chunk_df.loc[(chunk_df['text'].str.contains(sentence))]
            row = row.to_dict(orient='records')
            if len(row) > 0:
                datapoint["e5_paragraph"].append(row[0])

with open("all_dataset_e5.json", "w") as f:
    json.dump(dataset, f)
# Out:
# Could not find sentence: housing affordability has fallen to its lowest level in over 30 years. prices and rents have soared relative to incomes. spiraling mortgage rates have pushed the homeownership bar further out of reach for a growing share of households.
# Most similar paragraph: index_e5_embeddings:Emerging-Trends_USCanada-2023.pdf-!26
# Could not find sentence: b and c value - add investments suit a growing market of younger and mid - career households stuck in the limbo of scarce supply, high prices, and high interest mortgages that will delay their becoming homeowners.
# Most similar paragraph: index_e5_embeddings:global-real-estate-markets-2023.pdf-!12
# Could not find sentence: housing affordability has fallen to its lowest level in over 30 years. prices and rents have soared relative to incomes. spiraling mortgage rates have pushed the homeownership bar further out of reach for a growing share of households.
# Most similar paragraph: index_e5_embeddings:Emerging-Trends_USCanada-2023.pdf-!26
# Could not find sentence: b and c value - add investments suit a growing market of younger and mid - career households stuck in the limbo of scarce supply, high prices, and high interest mortgages that will delay their becoming homeowners.
# Most similar paragraph: index_e5_embeddings:global-real-estate-markets-2023.pdf-!12
# Could not find sentence: housing affordability has fallen to its lowest level in over 30 years. prices and rents have soared relative to incomes. spiraling mortgage rates have pushed the homeownership bar further out of reach for a growing share of households.
# Most similar paragraph: index_e5_embeddings:Emerging-Trends_USCanada-2023.pdf-!26
# Could not find sentence: b and c value - add investments suit a growing market of younger and mid - career households stuck in the limbo of scarce supply, high prices, and high interest mortgages that will delay their becoming homeowners.
# Most similar paragraph: index_e5_embeddings:global-real-estate-markets-2023.pdf-!12
# Could not find sentence: housing affordability has fallen to its lowest level in over 30 years. prices and rents have soared relative to incomes. spiraling mortgage rates have pushed the homeownership bar further out of reach for a growing share of households.
# Most similar paragraph: index_e5_embeddings:Emerging-Trends_USCanada-2023.pdf-!26
# Could not find sentence: b and c value - add investments suit a growing market of younger and mid - career households stuck in the limbo of scarce supply, high prices, and high interest mortgages that will delay their becoming homeowners.
# Most similar paragraph: index_e5_embeddings:global-real-estate-markets-2023.pdf-!12
# Could not find sentence: housing affordability has fallen to its lowest level in over 30 years. prices and rents have soared relative to incomes. spiraling mortgage rates have pushed the homeownership bar further out of reach for a growing share of households.
# Most similar paragraph: index_e5_embeddings:Emerging-Trends_USCanada-2023.pdf-!26
# Could not find sentence: b and c value - add investments suit a growing market of younger and mid - career households stuck in the limbo of scarce supply, high prices, and high interest mortgages that will delay their becoming homeowners.
# Most similar paragraph: index_e5_embeddings:global-real-estate-markets-2023.pdf-!12
# Could not find sentence: housing affordability has fallen to its lowest level in over 30 years. prices and rents have soared relative to incomes. spiraling mortgage rates have pushed the homeownership bar further out of reach for a growing share of households.
# Most similar paragraph: index_e5_embeddings:Emerging-Trends_USCanada-2023.pdf-!26
# Could not find sentence: b and c value - add investments suit a growing market of younger and mid - career households stuck in the limbo of scarce supply, high prices, and high interest mortgages that will delay their becoming homeowners.
# Most similar paragraph: index_e5_embeddings:global-real-estate-markets-2023.pdf-!12
# Could not find sentence: building in towns and cities was hampered by the fact that the construction industry was working more or less at capacity, by a shortage of skilled workers and of materials, along with the emergence of protests here and there. the cost of reno - vation has risen on a similar scale.
# Most similar paragraph: index_e5_embeddings:bouwinvest_international-market-outlook_2023-2025-1.pdf-!20
# Could not find sentence: construction costs shot up due to supply chain disruptions and are still worrisome. as one housing industry adviser notes, there's a stress index about global supply chains, and those stress indices are all indicating that they're moderating, but they're still at very high levels.
# Most similar paragraph: index_e5_embeddings:2023_Housing_market_outlook__Price_dip_and_interes.pdf-!48
# Could not find sentence: building in towns and cities was hampered by the fact that the construction industry was working more or less at capacity, by a shortage of skilled workers and of materials, along with the emergence of protests here and there. the cost of reno - vation has risen on a similar scale.
# Most similar paragraph: index_e5_embeddings:bouwinvest_international-market-outlook_2023-2025-1.pdf-!20
# Could not find sentence: construction costs shot up due to supply chain disruptions and are still worrisome. as one housing industry adviser notes, there's a stress index about global supply chains, and those stress indices are all indicating that they're moderating, but they're still at very high levels.
# Most similar paragraph: index_e5_embeddings:2023_Housing_market_outlook__Price_dip_and_interes.pdf-!48
# Could not find sentence: building in towns and cities was hampered by the fact that the construction industry was working more or less at capacity, by a shortage of skilled workers and of materials, along with the emergence of protests here and there. the cost of reno - vation has risen on a similar scale.
# Most similar paragraph: index_e5_embeddings:bouwinvest_international-market-outlook_2023-2025-1.pdf-!20
# Could not find sentence: construction costs shot up due to supply chain disruptions and are still worrisome. as one housing industry adviser notes, there's a stress index about global supply chains, and those stress indices are all indicating that they're moderating, but they're still at very high levels.
# Most similar paragraph: index_e5_embeddings:2023_Housing_market_outlook__Price_dip_and_interes.pdf-!48
# Could not find sentence: building in towns and cities was hampered by the fact that the construction industry was working more or less at capacity, by a shortage of skilled workers and of materials, along with the emergence of protests here and there. the cost of reno - vation has risen on a similar scale.
# Most similar paragraph: index_e5_embeddings:bouwinvest_international-market-outlook_2023-2025-1.pdf-!20
# Could not find sentence: construction costs shot up due to supply chain disruptions and are still worrisome. as one housing industry adviser notes, there's a stress index about global supply chains, and those stress indices are all indicating that they're moderating, but they're still at very high levels.
# Most similar paragraph: index_e5_embeddings:2023_Housing_market_outlook__Price_dip_and_interes.pdf-!48
# Could not find sentence: building in towns and cities was hampered by the fact that the construction industry was working more or less at capacity, by a shortage of skilled workers and of materials, along with the emergence of protests here and there. the cost of reno - vation has risen on a similar scale.
# Most similar paragraph: index_e5_embeddings:bouwinvest_international-market-outlook_2023-2025-1.pdf-!20
# Could not find sentence: construction costs shot up due to supply chain disruptions and are still worrisome. as one housing industry adviser notes, there's a stress index about global supply chains, and those stress indices are all indicating that they're moderating, but they're still at very high levels.
# Most similar paragraph: index_e5_embeddings:2023_Housing_market_outlook__Price_dip_and_interes.pdf-!48
# Could not find sentence: building in towns and cities was hampered by the fact that the construction industry was working more or less at capacity, by a shortage of skilled workers and of materials, along with the emergence of protests here and there. the cost of reno - vation has risen on a similar scale.
# Most similar paragraph: index_e5_embeddings:bouwinvest_international-market-outlook_2023-2025-1.pdf-!20
# Could not find sentence: construction costs shot up due to supply chain disruptions and are still worrisome. as one housing industry adviser notes, there's a stress index about global supply chains, and those stress indices are all indicating that they're moderating, but they're still at very high levels.
# Most similar paragraph: index_e5_embeddings:2023_Housing_market_outlook__Price_dip_and_interes.pdf-!48
# Could not find sentence: and now, more than two years on, property investors and managers are learning anew that whopping growth and profits eventually fall back to earth — a reversion to the mean, to use finance jargon, or simply normalizing, as numerous industry experts we interviewed put it.
# Most similar paragraph: index_e5_embeddings:isa-outlook-2023.pdf-!69
# Could not find sentence: indeed, home sales — both new and existing — had an extraordinary 12 - year run since bottoming out in the summer of 2010 until the fed started hiking interest rates in the spring of 2022.
# Most similar paragraph: index_e5_embeddings:2023_Housing_market_outlook__Price_dip_and_interes.pdf-!48
# Could not find sentence: and now, more than two years on, property investors and managers are learning anew that whopping growth and profits eventually fall back to earth — a reversion to the mean, to use finance jargon, or simply normalizing, as numerous industry experts we interviewed put it.
# Most similar paragraph: index_e5_embeddings:isa-outlook-2023.pdf-!69
# Could not find sentence: indeed, home sales — both new and existing — had an extraordinary 12 - year run since bottoming out in the summer of 2010 until the fed started hiking interest rates in the spring of 2022.
# Most similar paragraph: index_e5_embeddings:2023_Housing_market_outlook__Price_dip_and_interes.pdf-!48
# Could not find sentence: and now, more than two years on, property investors and managers are learning anew that whopping growth and profits eventually fall back to earth — a reversion to the mean, to use finance jargon, or simply normalizing, as numerous industry experts we interviewed put it.
# Most similar paragraph: index_e5_embeddings:isa-outlook-2023.pdf-!69
# Could not find sentence: indeed, home economicnancial issues interest rates and cost of capital availability of qualied labor job and income growth ination capital availability global economic growth tariffstrade conicts state and local taxes federal taxes currency exchange rates socialpolitical issues housing costs and availability 4. 21 3. 51 geopolitical conicts political extremism immigration policy epidemicspandemics climate change statelocal government budgets income inequality federal budget decit higher education costs diversity and inclusion threat of terrorism real estatedevelopment issues construction labor costs construction material costs construction labor availability land costs operating costs state and local regulations tenant leasing and retention costs nimbyism infrastructuretransportation property taxes environmentalsustainability requirements risks from extreme weather health and wellness features municipal service cuts health - and safety - related policies source : emerging trends in real estate 2023 survey.
# Most similar paragraph: index_e5_embeddings:Emerging-Trends_USCanada-2023.pdf-!10
# Could not find sentence: and now, more than two years on, property investors and managers are learning anew that whopping growth and profits eventually fall back to earth — a reversion to the mean, to use finance jargon, or simply normalizing, as numerous industry experts we interviewed put it.
# Most similar paragraph: index_e5_embeddings:isa-outlook-2023.pdf-!69
# Could not find sentence: indeed, home economicnancial issues interest rates and cost of capital availability of qualied labor job and income growth ination capital availability global economic growth tariffstrade conicts state and local taxes federal taxes currency exchange rates socialpolitical issues housing costs and availability 4. 21 3. 51 geopolitical conicts political extremism immigration policy epidemicspandemics climate change statelocal government budgets income inequality federal budget decit higher education costs diversity and inclusion threat of terrorism real estatedevelopment issues construction labor costs construction material costs construction labor availability land costs operating costs state and local regulations tenant leasing and retention costs nimbyism infrastructuretransportation property taxes environmentalsustainability requirements risks from extreme weather health and wellness features municipal service cuts health - and safety - related policies source : emerging trends in real estate 2023 survey.
# Most similar paragraph: index_e5_embeddings:Emerging-Trends_USCanada-2023.pdf-!10
# Could not find sentence: these market reversions will take several forms : prices of most assets are declining as cap rates rise and transaction volumes fall from record levels, while rent gains for others are merely moderating as demand returns to more sustainable levels.
# Most similar paragraph: index_e5_embeddings:isa-outlook-2023.pdf-!69
# Could not find sentence: these market reversions will take several forms : prices of most assets are declining as cap rates rise and transaction volumes fall from record levels, while rent gains for others are merely moderating as demand returns to more sustainable levels.
# Most similar paragraph: index_e5_embeddings:isa-outlook-2023.pdf-!69
# Could not find sentence: we have already started to see cap rates and yields rise in many markets, with the most rapid adjustment taking place in the uk. however, we do not think that prices fully reflect higher interest rates yet.
# Most similar paragraph: index_e5_embeddings:global-real-estate-markets-2023.pdf-!12
# Could not find sentence: we have already started to see cap rates and yields rise in many markets, with the most rapid adjustment taking place in the uk. however, we do not think that prices fully reflect higher interest rates yet.
# Most similar paragraph: index_e5_embeddings:global-real-estate-markets-2023.pdf-!12
# Could not find sentence: the monetary authority of singapore manages monetary policies through the foreign exchange markets... financial conditions in singapore are expected to fare slightly better than those of south korea and australia, as singapore benefits from strong investor appetite due to its relative economic strength and geopolitical stability.
# Most similar paragraph: index_e5_embeddings:2023_Housing_market_outlook__Price_dip_and_interes.pdf-!48
# Could not find sentence: singapore's relative attractiveness to hong kong is expected to increase... singapores relative attractiveness to hong kong is expec - ted to increase.
# Most similar paragraph: index_e5_embeddings:global-real-estate-markets-2023.pdf-!12
# Could not find sentence: the monetary authority of singapore manages monetary policies through the foreign exchange markets... financial conditions in singapore are expected to fare slightly better than those of south korea and australia, as singapore benefits from strong investor appetite due to its relative economic strength and geopolitical stability.
# Most similar paragraph: index_e5_embeddings:2023_Housing_market_outlook__Price_dip_and_interes.pdf-!48
# Could not find sentence: singapore's relative attractiveness to hong kong is expected to increase... singapores relative attractiveness to hong kong is expec - ted to increase.
# Most similar paragraph: index_e5_embeddings:global-real-estate-markets-2023.pdf-!12
# Could not find sentence: in japan, yield curve control comes at the cost of a weak yen. if the bank of japan ( boj ) remains committed to keeping interest rates near zero, currency intervention, such as yen - buying to prevent further depreciation, could be on the table again... most of the challenges japan is facing are externally driven, while domestic - driven fundamentals remain relatively healthy.
# /var/folders/fl/tm4fc_cn093f_bh634c4z63r0000gq/T/ipykernel_86603/272627843.py:30: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   row = chunk_df.loc[(chunk_df['text'].str.contains(sentence))]
# Most similar paragraph: index_e5_embeddings:2023_Housing_market_outlook__Price_dip_and_interes.pdf-!48
# Could not find sentence: in japan, yield curve control comes at the cost of a weak yen. if the bank of japan ( boj ) remains committed to keeping interest rates near zero, currency intervention, such as yen - buying to prevent further depreciation, could be on the table again... most of the challenges japan is facing are externally driven, while domestic - driven fundamentals remain relatively healthy.
# Most similar paragraph: index_e5_embeddings:2023_Housing_market_outlook__Price_dip_and_interes.pdf-!48
# Could not find sentence: in japan, yield curve control comes at the cost of a weak yen. if the bank of japan ( boj ) remains committed to keeping interest rates near zero, currency intervention, such as yen - buying to prevent further depreciation, could be on the table again.
# Most similar paragraph: index_e5_embeddings:2023_Housing_market_outlook__Price_dip_and_interes.pdf-!48
# Could not find sentence: japan remains an attractive diversifier for institutional investors regional and global real estate portfolios, due to the relative resiliency of its occupier and capital market fundamentals, its stable geopolitical environment and divergent monetary policies.
# Most similar paragraph: index_e5_embeddings:2023_Housing_market_outlook__Price_dip_and_interes.pdf-!48
# Could not find sentence: in japan, yield curve control comes at the cost of a weak yen. if the bank of japan ( boj ) remains committed to keeping interest rates near zero, currency intervention, such as yen - buying to prevent further depreciation, could be on the table again.
# Most similar paragraph: index_e5_embeddings:2023_Housing_market_outlook__Price_dip_and_interes.pdf-!48
# Could not find sentence: japan remains an attractive diversifier for institutional investors regional and global real estate portfolios, due to the relative resiliency of its occupier and capital market fundamentals, its stable geopolitical environment and divergent monetary policies.
# Most similar paragraph: index_e5_embeddings:2023_Housing_market_outlook__Price_dip_and_interes.pdf-!48
# Could not find sentence: in japan, yield curve control comes at the cost of a weak yen. if the bank of japan ( boj ) remains committed to keeping interest rates near zero, currency intervention, such as yen - buying to prevent further depreciation, could be on the table again.
# Most similar paragraph: index_e5_embeddings:2023_Housing_market_outlook__Price_dip_and_interes.pdf-!48
# Could not find sentence: japan remains an attractive diversifier for institutional investors regional and global real estate portfolios, due to the relative resiliency of its occupier and capital market fundamentals, its stable geopolitical environment and divergent monetary policies.
# Most similar paragraph: index_e5_embeddings:2023_Housing_market_outlook__Price_dip_and_interes.pdf-!48
# Could not find sentence: in japan, yield curve control comes at the cost of a weak yen. if the bank of japan ( boj ) remains committed to keeping interest rates near zero, currency intervention, such as yen - buying to prevent further depreciation, could be on the table again.
# Most similar paragraph: index_e5_embeddings:2023_Housing_market_outlook__Price_dip_and_interes.pdf-!48
# Could not find sentence: japan remains an attractive diversifier for institutional investors regional and global real estate portfolios, due to the relative resiliency of its occupier and capital market fundamentals, its stable geopolitical environment and divergent monetary policies.
# Most similar paragraph: index_e5_embeddings:2023_Housing_market_outlook__Price_dip_and_interes.pdf-!48
# Could not find sentence: australia is cementing its status as a safe haven in the region. singapores relative attractiveness to hong kong is expected to increase. higher interest rates are less of a concern in japan where the spread between the risk - free rate and real estate yields remains stable.
# Most similar paragraph: index_e5_embeddings:2023_Housing_market_outlook__Price_dip_and_interes.pdf-!48
# Could not find sentence: australia is cementing its status as a safe haven in the region. singapores relative attractiveness to hong kong is expected to increase. higher interest rates are less of a concern in japan where the spread between the risk - free rate and real estate yields remains stable.
# Most similar paragraph: index_e5_embeddings:2023_Housing_market_outlook__Price_dip_and_interes.pdf-!48
# Could not find sentence: australia is cementing its status as a safe haven in the region. singapores relative attractiveness to hong kong is expected to increase. higher interest rates are less of a concern in japan where the spread between the risk - free rate and real estate yields remains stable.
# Most similar paragraph: index_e5_embeddings:2023_Housing_market_outlook__Price_dip_and_interes.pdf-!48
# Could not find sentence: australia is cementing its status as a safe haven in the region. singapores relative attractiveness to hong kong is expected to increase. higher interest rates are less of a concern in japan where the spread between the risk - free rate and real estate yields remains stable.
# Most similar paragraph: index_e5_embeddings:2023_Housing_market_outlook__Price_dip_and_interes.pdf-!48
# Could not find sentence: the relentless math of higher interest rates will continue to weigh heavily on real estate values, at least until interest rates stabilize as inflation begins to subside.
# Most similar paragraph: index_e5_embeddings:global-real-estate-markets-2023.pdf-!12
# Could not find sentence: the relentless math of higher interest rates will continue to weigh heavily on real estate values, at least until interest rates stabilize as inflation begins to subside.
# Most similar paragraph: index_e5_embeddings:global-real-estate-markets-2023.pdf-!12
# Could not find sentence: denominator effects and higher borrowing costs will keep a meaningful fraction of core and higher return buyers on the sidelines, especially at the start of 2023.
# Most similar paragraph: index_e5_embeddings:global-real-estate-markets-2023.pdf-!12
# Could not find sentence: denominator effects and higher borrowing costs will keep a meaningful fraction of core and higher return buyers on the sidelines, especially at the start of 2023.
# Most similar paragraph: index_e5_embeddings:global-real-estate-markets-2023.pdf-!12
# Could not find sentence: with the normalisation of monetary policy that has now begun, this situation should dissolve and the rise in real estate yields should be flatter than that of the risk - free interest rate.
# Most similar paragraph: index_e5_embeddings:2023_Housing_market_outlook__Price_dip_and_interes.pdf-!48
# Could not find sentence: with the normalisation of monetary policy that has now begun, this situation should dissolve and the rise in real estate yields should be flatter than that of the risk - free interest rate.
# Most similar paragraph: index_e5_embeddings:2023_Housing_market_outlook__Price_dip_and_interes.pdf-!48
# Could not find sentence: the relentless math of higher interest rates will continue to weigh heavily on real estate values, at least until interest rates stabilize as inflation begins to subside.
# Most similar paragraph: index_e5_embeddings:global-real-estate-markets-2023.pdf-!12
# Could not find sentence: the relentless math of higher interest rates will continue to weigh heavily on real estate values, at least until interest rates stabilize as inflation begins to subside.
# Most similar paragraph: index_e5_embeddings:global-real-estate-markets-2023.pdf-!12
# Could not find sentence: this is one of those cash is king situations where borrowing costs are higher, and if you're an all - cash buyer, those probably represent a disproportionate share of the people in the market today.
# Most similar paragraph: index_e5_embeddings:2023_Housing_market_outlook__Price_dip_and_interes.pdf-!48
# Could not find sentence: this is one of those cash is king situations where borrowing costs are higher, and if you're an all - cash buyer, those probably represent a disproportionate share of the people in the market today.
# Most similar paragraph: index_e5_embeddings:2023_Housing_market_outlook__Price_dip_and_interes.pdf-!48
# Could not find sentence: the relentless math of higher interest rates will continue to weigh heavily on real estate values, at least until interest rates stabilize as inflation begins to subside.
# Most similar paragraph: index_e5_embeddings:global-real-estate-markets-2023.pdf-!12
# Could not find sentence: the relentless math of higher interest rates will continue to weigh heavily on real estate values, at least until interest rates stabilize as inflation begins to subside.
# Most similar paragraph: index_e5_embeddings:global-real-estate-markets-2023.pdf-!12
# Could not find sentence: europe faces especially severe challenges stemming from an energy price shock, with ripple effects of unknown global scope.
# Most similar paragraph: index_e5_embeddings:Emerging-Trends_USCanada-2023.pdf-!203
# Could not find sentence: office investments in the us will face significant challenges in 2023 as lenders and core buyers view the sector as particularly risky.
# Most similar paragraph: index_e5_embeddings:global-real-estate-markets-2023.pdf-!12
# Could not find sentence: europe faces especially severe challenges stemming from an energy price shock, with ripple effects of unknown global scope.
# Most similar paragraph: index_e5_embeddings:Emerging-Trends_USCanada-2023.pdf-!203
# Could not find sentence: office investments in the us will face significant challenges in 2023 as lenders and core buyers view the sector as particularly risky.
# Most similar paragraph: index_e5_embeddings:global-real-estate-markets-2023.pdf-!12
# Could not find sentence: this would amount to a value loss of around 10 to 15 before stabilization and recovery takes place.
# Most similar paragraph: index_e5_embeddings:global-real-estate-markets-2023.pdf-!12
# Could not find sentence: this would amount to a value loss of around 10 to 15 before stabilization and recovery takes place.
# Most similar paragraph: index_e5_embeddings:global-real-estate-markets-2023.pdf-!12
# Could not find sentence: the volume of new supply coming to market is meanwhile decreasing due to both rising construction costs and a capital values of prime logistics properties are forecast to decline by an average 7 - 8 in q4 2022 compared with q4 2021 levels.
# Most similar paragraph: index_e5_embeddings:2023_Housing_market_outlook__Price_dip_and_interes.pdf-!48
# Could not find sentence: the volume of new supply coming to market is meanwhile decreasing due to both rising construction costs and a capital values of prime logistics properties are forecast to decline by an average 7 - 8 in q4 2022 compared with q4 2021 levels.
# Most similar paragraph: index_e5_embeddings:2023_Housing_market_outlook__Price_dip_and_interes.pdf-!48
# Could not find sentence: most recently, though, they have been beat - en by cologne with a figure of 2. 8 per cent.
# Most similar paragraph: index_e5_embeddings:Emerging-Trends_USCanada-2023.pdf-!203
# Could not find sentence: most recently, though, they have been beat - en by cologne with a figure of 2. 8 per cent.
# Most similar paragraph: index_e5_embeddings:Emerging-Trends_USCanada-2023.pdf-!203
# Could not find sentence: many of the changes were relatively minor, and nine of the 10 highest - rated markets last year repeated this year.
# Most similar paragraph: index_e5_embeddings:global-real-estate-markets-2023.pdf-!12
# Could not find sentence: many of the changes were relatively minor, and nine of the 10 highest - rated markets last year repeated this year.
# Most similar paragraph: index_e5_embeddings:global-real-estate-markets-2023.pdf-!12
# Could not find sentence: more than half ( 11 ) of the 20 - highest rated markets in last years survey fell in the rankings this year, although almost all by less than 10 places.
# Most similar paragraph: index_e5_embeddings:global-real-estate-markets-2023.pdf-!12
# Could not find sentence: more than half ( 11 ) of the 20 - highest rated markets in last years survey fell in the rankings this year, although almost all by less than 10 places.
# Most similar paragraph: index_e5_embeddings:global-real-estate-markets-2023.pdf-!12
# Could not find sentence: like the astronomic source for its name, the five metro areas in the supernova category markets have exploded into prominence over the past decade or so. all are smaller markets with 1 million to 2 million residents, but their defining attribute is their tremendous and sustained population and job growth, which are well above national averages.
# Most similar paragraph: index_e5_embeddings:2023_Housing_market_outlook__Price_dip_and_interes.pdf-!48
# Could not find sentence: like the astronomic source for its name, the five metro areas in the supernova category markets have exploded into prominence over the past decade or so. all are smaller markets with 1 million to 2 million residents, but their defining attribute is their tremendous and sustained population and job growth, which are well above national averages.
# Most similar paragraph: index_e5_embeddings:2023_Housing_market_outlook__Price_dip_and_interes.pdf-!48
# Could not find sentence: average monthly disposable income per household : eur 3, 726 euro
# Most similar paragraph: index_e5_embeddings:Emerging-Trends_USCanada-2023.pdf-!203
# Could not find sentence: average monthly disposable income per household : eur 3, 726 euro
# Most similar paragraph: index_e5_embeddings:Emerging-Trends_USCanada-2023.pdf-!203
# Could not find sentence: new home prices peaked in april 2022, while prices of existing homes likely peaked in june after appreciation started to slow with the rise in mortgage rates.
# Most similar paragraph: index_e5_embeddings:Emerging-Trends_USCanada-2023.pdf-!203
# Could not find sentence: new home prices peaked in april 2022, while prices of existing homes likely peaked in june after appreciation started to slow with the rise in mortgage rates.
# Most similar paragraph: index_e5_embeddings:Emerging-Trends_USCanada-2023.pdf-!203
# Could not find sentence: the u. s. apartment property sectorproviding shelter to 37 mil - lion residents in 21. 3 million structures of five or more household units, and contributing $ 3. 4 trillion annually to the u. s. economy, according to the nmhc
# Most similar paragraph: index_e5_embeddings:2023_Housing_market_outlook__Price_dip_and_interes.pdf-!48
# Could not find sentence: the u. s. apartment property sectorproviding shelter to 37 mil - lion residents in 21. 3 million structures of five or more household units, and contributing $ 3. 4 trillion annually to the u. s. economy, according to the nmhc
# Most similar paragraph: index_e5_embeddings:2023_Housing_market_outlook__Price_dip_and_interes.pdf-!48
# Could not find sentence: according to harvards joint center for housing studies ( jchs ), the number of renters making at least $ 75, 000 jumped by 48 percent over the decade ending just before the pandemic, to 11. 3 million.
# Most similar paragraph: index_e5_embeddings:2023_Housing_market_outlook__Price_dip_and_interes.pdf-!48
# Could not find sentence: according to harvards joint center for housing studies ( jchs ), the number of renters making at least $ 75, 000 jumped by 48 percent over the decade ending just before the pandemic, to 11. 3 million.
# Most similar paragraph: index_e5_embeddings:2023_Housing_market_outlook__Price_dip_and_interes.pdf-!48
# Number of datapoints with e5_paragraphs: 76

# %%
dataset = json.load(bf.BlobFile("all_dataset_e5_manuel_edit.json", "rb"))

retriever_rows = []
for datapoint in dataset:
    if datapoint["category"] == "NOT_SOURCE_BASED":
        continue
    row = {
        "category": datapoint["category"],
        "input": {
            "question": datapoint["question"],
        },
        "ideal": {
            "paragraph": datapoint["e5_sentences"] if "e5_sentences" and len(datapoint["e5_sentences"]) > 0 else datapoint["sentences"],
            "ids": list(set(paragraph["id"] for paragraph in datapoint["e5_paragraph"])),
        }
    }
    retriever_rows.append(row)
retriever_rows
# Out:
# [{'category': 'SAME_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Did the number of new units authorized in multifamily buildings and the number of single-family housing starts trend in the same direction in 2022?'},
#   'ideal': {'paragraph': ['as of august, 862, 000 apartments were under construction, up 25 percent from a year ago.',
#     'and now both permits and housing starts have been trending down again in 2022.'],
#    'ids': ['index_e5_embeddings:Emerging-Trends_USCanada-2023.pdf-!29',
#     'index_e5_embeddings:Emerging-Trends_USCanada-2023.pdf-!77']}},
#  {'category': 'DIFFERENT_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Did the growth trajectory of new apartment complexes align with the initiation of single-dwelling constructions in 2022?'},
#   'ideal': {'paragraph': ['as of august, 862, 000 apartments were under construction, up 25 percent from a year ago.',
#     'and now both permits and housing starts have been trending down again in 2022.'],
#    'ids': ['index_e5_embeddings:Emerging-Trends_USCanada-2023.pdf-!29',
#     'index_e5_embeddings:Emerging-Trends_USCanada-2023.pdf-!77']}},
#  {'category': 'SAME_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Is the current demand for larger living spaces caused by the existing tax laws for individual homebuyer?'},
#   'ideal': {'paragraph': ['two, demand gathered speed and sweep as people sought larger living spaces to balance remote work and household life, and more outdoor living options.',
#     'one reason : existing tax laws are stacked against the individual homebuyer.'],
#    'ids': ['index_e5_embeddings:Emerging-Trends_USCanada-2023.pdf-!76',
#     'index_e5_embeddings:Emerging-Trends_USCanada-2023.pdf-!28']}},
#  {'category': 'DIFFERENT_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Are the existing regulations related to individual property taxation driving the present trend towards bigger homes?'},
#   'ideal': {'paragraph': ['two, demand gathered speed and sweep as people sought larger living spaces to balance remote work and household life, and more outdoor living options.',
#     'one reason : existing tax laws are stacked against the individual homebuyer.'],
#    'ids': ['index_e5_embeddings:Emerging-Trends_USCanada-2023.pdf-!76',
#     'index_e5_embeddings:Emerging-Trends_USCanada-2023.pdf-!28']}},
#  {'category': 'SAME_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Was the constrained construction of new supply a consequence of labor shortages and cautious construction pacing from homebuilders?'},
#   'ideal': {'paragraph': ['three, constrained construction of new supply, and a price run - up on the single - family for - sale front, spilled over into expanded apartment demand.',
#     'another supply constraint is homebuilders cautious construc - tion pacing, a vestige of the last recession.',
#     'and then labor shortages are compounding the problems.'],
#    'ids': ['index_e5_embeddings:Emerging-Trends_USCanada-2023.pdf-!29',
#     'index_e5_embeddings:Emerging-Trends_USCanada-2023.pdf-!76',
#     'index_e5_embeddings:Emerging-Trends_USCanada-2023.pdf-!28']}},
#  {'category': 'DIFFERENT_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': "Are the limitations in new housing production attributed to workforce scarcity and builders' prudent construction speed?"},
#   'ideal': {'paragraph': ['three, constrained construction of new supply, and a price run - up on the single - family for - sale front, spilled over into expanded apartment demand.',
#     'another supply constraint is homebuilders cautious construc - tion pacing, a vestige of the last recession.',
#     'and then labor shortages are compounding the problems.'],
#    'ids': ['index_e5_embeddings:Emerging-Trends_USCanada-2023.pdf-!29',
#     'index_e5_embeddings:Emerging-Trends_USCanada-2023.pdf-!76',
#     'index_e5_embeddings:Emerging-Trends_USCanada-2023.pdf-!28']}},
#  {'category': 'SAME_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Has the affordability of housing dropped in recent years, affecting both young and mid-career households?'},
#   'ideal': {'paragraph': ['housing affordability has fallen to its lowest level in over 30 years. prices and rents have soared relative to incomes. spiraling mortgage rates have pushed the homeownership bar further out of reach for a growing share of households.',
#     'b and c value - add investments suit a growing market of younger and mid - career households stuck in the limbo of scarce supply, high prices, and high interest mortgages that will delay their becoming homeowners.'],
#    'ids': ['index_e5_embeddings:Emerging-Trends_USCanada-2023.pdf-!26',
#     'index_e5_embeddings:Emerging-Trends_USCanada-2023.pdf-!80']}},
#  {'category': 'DIFFERENT_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Has there been a recent decline in housing affordability, impacting households in their early and middle stages of their careers?'},
#   'ideal': {'paragraph': ['housing affordability has fallen to its lowest level in over 30 years. prices and rents have soared relative to incomes. spiraling mortgage rates have pushed the homeownership bar further out of reach for a growing share of households.',
#     'b and c value - add investments suit a growing market of younger and mid - career households stuck in the limbo of scarce supply, high prices, and high interest mortgages that will delay their becoming homeowners.'],
#    'ids': ['index_e5_embeddings:Emerging-Trends_USCanada-2023.pdf-!26',
#     'index_e5_embeddings:Emerging-Trends_USCanada-2023.pdf-!80']}},
#  {'category': 'SAME_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Are high prices and high interest mortgages contributing to difficulties for people wanting to become homeowners?'},
#   'ideal': {'paragraph': ['housing affordability has fallen to its lowest level in over 30 years. prices and rents have soared relative to incomes. spiraling mortgage rates have pushed the homeownership bar further out of reach for a growing share of households.',
#     'b and c value - add investments suit a growing market of younger and mid - career households stuck in the limbo of scarce supply, high prices, and high interest mortgages that will delay their becoming homeowners.'],
#    'ids': ['index_e5_embeddings:Emerging-Trends_USCanada-2023.pdf-!26',
#     'index_e5_embeddings:Emerging-Trends_USCanada-2023.pdf-!80']}},
#  {'category': 'DIFFERENT_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Do steep costs and hefty interest rates on housing loans pose challenges for aspiring property owners?'},
#   'ideal': {'paragraph': ['housing affordability has fallen to its lowest level in over 30 years. prices and rents have soared relative to incomes. spiraling mortgage rates have pushed the homeownership bar further out of reach for a growing share of households.',
#     'b and c value - add investments suit a growing market of younger and mid - career households stuck in the limbo of scarce supply, high prices, and high interest mortgages that will delay their becoming homeowners.'],
#    'ids': ['index_e5_embeddings:Emerging-Trends_USCanada-2023.pdf-!26',
#     'index_e5_embeddings:Emerging-Trends_USCanada-2023.pdf-!80']}},
#  {'category': 'SAME_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Is the market for value-add investments growing, particularly among younger and mid-career households?'},
#   'ideal': {'paragraph': ['housing affordability has fallen to its lowest level in over 30 years. prices and rents have soared relative to incomes. spiraling mortgage rates have pushed the homeownership bar further out of reach for a growing share of households.',
#     'b and c value - add investments suit a growing market of younger and mid - career households stuck in the limbo of scarce supply, high prices, and high interest mortgages that will delay their becoming homeowners.'],
#    'ids': ['index_e5_embeddings:Emerging-Trends_USCanada-2023.pdf-!26',
#     'index_e5_embeddings:Emerging-Trends_USCanada-2023.pdf-!80']}},
#  {'category': 'DIFFERENT_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Is there an upswing in the market for investments that increase property value, especially among the younger and middle-aged demographic?'},
#   'ideal': {'paragraph': ['housing affordability has fallen to its lowest level in over 30 years. prices and rents have soared relative to incomes. spiraling mortgage rates have pushed the homeownership bar further out of reach for a growing share of households.',
#     'b and c value - add investments suit a growing market of younger and mid - career households stuck in the limbo of scarce supply, high prices, and high interest mortgages that will delay their becoming homeowners.'],
#    'ids': ['index_e5_embeddings:Emerging-Trends_USCanada-2023.pdf-!26',
#     'index_e5_embeddings:Emerging-Trends_USCanada-2023.pdf-!80']}},
#  {'category': 'SAME_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Have the costs of both construction and renovation risen due to issues such as supply chain disruptions?'},
#   'ideal': {'paragraph': ['building in towns and cities was hampered by the fact that the construction industry was working more or less at capacity, by a shortage of skilled workers and of materials, along with the emergence of protests here and there. the cost of reno - vation has risen on a similar scale.',
#     "construction costs shot up due to supply chain disruptions and are still worrisome. as one housing industry adviser notes, there's a stress index about global supply chains, and those stress indices are all indicating that they're moderating, but they're still at very high levels."],
#    'ids': ['index_e5_embeddings:Emerging-Trends_USCanada-2023.pdf-!29',
#     'index_e5_embeddings:2022-09-21_Immobilienmarkt_Deutschland_2022_2023_EN.pdf-!63']}},
#  {'category': 'DIFFERENT_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Has there been an escalation in the expenses related to building and refurbishing houses, due to problems like supply chain interruptions?'},
#   'ideal': {'paragraph': ['building in towns and cities was hampered by the fact that the construction industry was working more or less at capacity, by a shortage of skilled workers and of materials, along with the emergence of protests here and there. the cost of reno - vation has risen on a similar scale.',
#     "construction costs shot up due to supply chain disruptions and are still worrisome. as one housing industry adviser notes, there's a stress index about global supply chains, and those stress indices are all indicating that they're moderating, but they're still at very high levels."],
#    'ids': ['index_e5_embeddings:Emerging-Trends_USCanada-2023.pdf-!29',
#     'index_e5_embeddings:2022-09-21_Immobilienmarkt_Deutschland_2022_2023_EN.pdf-!63']}},
#  {'category': 'SAME_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Have difficulties in the construction industry, like a shortage of skilled workers and materials, hampered building efforts?'},
#   'ideal': {'paragraph': ['building in towns and cities was hampered by the fact that the construction industry was working more or less at capacity, by a shortage of skilled workers and of materials, along with the emergence of protests here and there. the cost of reno - vation has risen on a similar scale.',
#     "construction costs shot up due to supply chain disruptions and are still worrisome. as one housing industry adviser notes, there's a stress index about global supply chains, and those stress indices are all indicating that they're moderating, but they're still at very high levels."],
#    'ids': ['index_e5_embeddings:Emerging-Trends_USCanada-2023.pdf-!29',
#     'index_e5_embeddings:2022-09-21_Immobilienmarkt_Deutschland_2022_2023_EN.pdf-!63']}},
#  {'category': 'DIFFERENT_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Have complications in the building industry, such as a lack of trained manpower and building resources, obstructed construction activities?'},
#   'ideal': {'paragraph': ['building in towns and cities was hampered by the fact that the construction industry was working more or less at capacity, by a shortage of skilled workers and of materials, along with the emergence of protests here and there. the cost of reno - vation has risen on a similar scale.',
#     "construction costs shot up due to supply chain disruptions and are still worrisome. as one housing industry adviser notes, there's a stress index about global supply chains, and those stress indices are all indicating that they're moderating, but they're still at very high levels."],
#    'ids': ['index_e5_embeddings:Emerging-Trends_USCanada-2023.pdf-!29',
#     'index_e5_embeddings:2022-09-21_Immobilienmarkt_Deutschland_2022_2023_EN.pdf-!63']}},
#  {'category': 'SAME_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Are concerns over supply chain issues contributing to elevated costs in the housing construction industry?'},
#   'ideal': {'paragraph': ['building in towns and cities was hampered by the fact that the construction industry was working more or less at capacity, by a shortage of skilled workers and of materials, along with the emergence of protests here and there. the cost of reno - vation has risen on a similar scale.',
#     "construction costs shot up due to supply chain disruptions and are still worrisome. as one housing industry adviser notes, there's a stress index about global supply chains, and those stress indices are all indicating that they're moderating, but they're still at very high levels."],
#    'ids': ['index_e5_embeddings:Emerging-Trends_USCanada-2023.pdf-!29',
#     'index_e5_embeddings:2022-09-21_Immobilienmarkt_Deutschland_2022_2023_EN.pdf-!63']}},
#  {'category': 'DIFFERENT_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Are apprehensions related to supply chain difficulties adding to the surging expenses in the residential building sector?'},
#   'ideal': {'paragraph': ['building in towns and cities was hampered by the fact that the construction industry was working more or less at capacity, by a shortage of skilled workers and of materials, along with the emergence of protests here and there. the cost of reno - vation has risen on a similar scale.',
#     "construction costs shot up due to supply chain disruptions and are still worrisome. as one housing industry adviser notes, there's a stress index about global supply chains, and those stress indices are all indicating that they're moderating, but they're still at very high levels."],
#    'ids': ['index_e5_embeddings:Emerging-Trends_USCanada-2023.pdf-!29',
#     'index_e5_embeddings:2022-09-21_Immobilienmarkt_Deutschland_2022_2023_EN.pdf-!63']}},
#  {'category': 'SAME_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Has the United States property market begun a period of normalization after an extraordinary growth phase, beginning in 2010 and ending in 2022 when the Fed started hiking interest rates?'},
#   'ideal': {'paragraph': ['and now, more than two years on, property investors and managers are learning anew that whopping growth and profits eventually fall back to earth — a reversion to the mean, to use finance jargon, or simply normalizing, as numerous industry experts we interviewed put it.',
#     'indeed, home sales — both new and existing — had an extraordinary 12 - year run since bottoming out in the summer of 2010 until the fed started hiking interest rates in the spring of 2022.'],
#    'ids': ['index_e5_embeddings:Emerging-Trends_USCanada-2023.pdf-!10',
#     'index_e5_embeddings:Emerging-Trends_USCanada-2023.pdf-!9']}},
#  {'category': 'DIFFERENT_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': "Did the US real estate market transition into a phase of stabilization post a remarkable expansion cycle, from 2010 through 2022, commencing with the Federal Reserve's decision to increase interest rates?"},
#   'ideal': {'paragraph': ['and now, more than two years on, property investors and managers are learning anew that whopping growth and profits eventually fall back to earth — a reversion to the mean, to use finance jargon, or simply normalizing, as numerous industry experts we interviewed put it.',
#     'indeed, home sales — both new and existing — had an extraordinary 12 - year run since bottoming out in the summer of 2010 until the fed started hiking interest rates in the spring of 2022.'],
#    'ids': ['index_e5_embeddings:Emerging-Trends_USCanada-2023.pdf-!10',
#     'index_e5_embeddings:Emerging-Trends_USCanada-2023.pdf-!9']}},
#  {'category': 'SAME_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Given the factors that have influenced the real estate market after the COVID lockdown, did the market eventually experience a normalization or a return to the mean, according to industry experts?'},
#   'ideal': {'paragraph': ['and now, more than two years on, property investors and managers are learning anew that whopping growth and profits eventually fall back to earth — a reversion to the mean, to use finance jargon, or simply normalizing, as numerous industry experts we interviewed put it.',
#     'indeed, home economicnancial issues interest rates and cost of capital availability of qualied labor job and income growth ination capital availability global economic growth tariffstrade conicts state and local taxes federal taxes currency exchange rates socialpolitical issues housing costs and availability 4. 21 3. 51 geopolitical conicts political extremism immigration policy epidemicspandemics climate change statelocal government budgets income inequality federal budget decit higher education costs diversity and inclusion threat of terrorism real estatedevelopment issues construction labor costs construction material costs construction labor availability land costs operating costs state and local regulations tenant leasing and retention costs nimbyism infrastructuretransportation property taxes environmentalsustainability requirements risks from extreme weather health and wellness features municipal service cuts health - and safety - related policies source : emerging trends in real estate 2023 survey.'],
#    'ids': ['index_e5_embeddings:Emerging-Trends_USCanada-2023.pdf-!13',
#     'index_e5_embeddings:Emerging-Trends_USCanada-2023.pdf-!9']}},
#  {'category': 'DIFFERENT_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'In light of the influences shaping the property market post-COVID lockdown, did industry professionals perceive a reversion or recalibration back to its usual state?'},
#   'ideal': {'paragraph': ['and now, more than two years on, property investors and managers are learning anew that whopping growth and profits eventually fall back to earth — a reversion to the mean, to use finance jargon, or simply normalizing, as numerous industry experts we interviewed put it.',
#     'indeed, home economicnancial issues interest rates and cost of capital availability of qualied labor job and income growth ination capital availability global economic growth tariffstrade conicts state and local taxes federal taxes currency exchange rates socialpolitical issues housing costs and availability 4. 21 3. 51 geopolitical conicts political extremism immigration policy epidemicspandemics climate change statelocal government budgets income inequality federal budget decit higher education costs diversity and inclusion threat of terrorism real estatedevelopment issues construction labor costs construction material costs construction labor availability land costs operating costs state and local regulations tenant leasing and retention costs nimbyism infrastructuretransportation property taxes environmentalsustainability requirements risks from extreme weather health and wellness features municipal service cuts health - and safety - related policies source : emerging trends in real estate 2023 survey.'],
#    'ids': ['index_e5_embeddings:Emerging-Trends_USCanada-2023.pdf-!13',
#     'index_e5_embeddings:Emerging-Trends_USCanada-2023.pdf-!9']}},
#  {'category': 'SAME_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Is the increase in capitalization rates and the decrease in returns associated with rising interest rates and cost of capital, as observed in the U.S. property market? '},
#   'ideal': {'paragraph': ['these market reversions will take several forms : prices of most assets are declining as cap rates rise and transaction volumes fall from record levels, while rent gains for others are merely moderating as demand returns to more sustainable levels.',
#     'more than half believe that capitalization rates are heading up next year and returns are coming down, primarily due to rising interest rates and cost of capital, which was the top economic concern voiced in our survey.'],
#    'ids': ['index_e5_embeddings:Emerging-Trends_USCanada-2023.pdf-!13',
#     'index_e5_embeddings:Emerging-Trends_USCanada-2023.pdf-!9']}},
#  {'category': 'DIFFERENT_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Can we link the escalating capitalization rates and dwindling returns to heightened interest rates and the escalating cost of capital, as discerned in the American real estate market?'},
#   'ideal': {'paragraph': ['these market reversions will take several forms : prices of most assets are declining as cap rates rise and transaction volumes fall from record levels, while rent gains for others are merely moderating as demand returns to more sustainable levels.',
#     'more than half believe that capitalization rates are heading up next year and returns are coming down, primarily due to rising interest rates and cost of capital, which was the top economic concern voiced in our survey.'],
#    'ids': ['index_e5_embeddings:Emerging-Trends_USCanada-2023.pdf-!13',
#     'index_e5_embeddings:Emerging-Trends_USCanada-2023.pdf-!9']}},
#  {'category': 'SAME_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Despite the successful run of the U.S. commercial property markets after the COVID-19 lockdown, are cap rates and yields now rising in many markets, not just limited to the UK, without fully reflecting higher interest rates yet?'},
#   'ideal': {'paragraph': ['defying just about every prediction voiced during the terrifying and uncertain days of the covid lockdown that began in march 2020, u. s. commercial property markets actually embarked on a remarkable run.',
#     'we have already started to see cap rates and yields rise in many markets, with the most rapid adjustment taking place in the uk. however, we do not think that prices fully reflect higher interest rates yet.'],
#    'ids': ['index_e5_embeddings:Emerging-Trends_USCanada-2023.pdf-!8',
#     'index_e5_embeddings:global-real-estate-markets-2023.pdf-!1']}},
#  {'category': 'DIFFERENT_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': "Regardless of the U.S. commercial property markets' favorable performance post COVID-19 lockdown, are the capitalization rates and yields escalating across various markets, including but not limited to the UK, without full consideration of higher interest rates?"},
#   'ideal': {'paragraph': ['defying just about every prediction voiced during the terrifying and uncertain days of the covid lockdown that began in march 2020, u. s. commercial property markets actually embarked on a remarkable run.',
#     'we have already started to see cap rates and yields rise in many markets, with the most rapid adjustment taking place in the uk. however, we do not think that prices fully reflect higher interest rates yet.'],
#    'ids': ['index_e5_embeddings:Emerging-Trends_USCanada-2023.pdf-!8',
#     'index_e5_embeddings:global-real-estate-markets-2023.pdf-!1']}},
#  {'category': 'SAME_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Given the observations from the finance executive in the national homebuilder company and the survey results on rising interest rates, are both sources in agreement that the markets are normalizing?'},
#   'ideal': {'paragraph': ['housing set to cool a finance executive with one national homebuilder told us, were still selling. its just not at the pace that it was selling before the last two years, which was a pace that you dont typi - cally see. so, the markets are more normalizing.',
#     'more than half believe that capitalization rates are heading up next year and returns are coming down, primarily due to rising interest rates and cost of capital, which was the top economic concern voiced in our survey. after more than a decade of lower for longer, the fed is finally normalizing interest rates closer to historical levels.'],
#    'ids': ['index_e5_embeddings:Emerging-Trends_USCanada-2023.pdf-!13',
#     'index_e5_embeddings:Emerging-Trends_USCanada-2023.pdf-!9']}},
#  {'category': 'DIFFERENT_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'In light of the statements by the finance executive at the national homebuilder company and the data from surveys on increased interest rates, do both sources concur that there is a reversion to the norm occurring within the markets?'},
#   'ideal': {'paragraph': ['housing set to cool a finance executive with one national homebuilder told us, were still selling. its just not at the pace that it was selling before the last two years, which was a pace that you dont typi - cally see. so, the markets are more normalizing.',
#     'more than half believe that capitalization rates are heading up next year and returns are coming down, primarily due to rising interest rates and cost of capital, which was the top economic concern voiced in our survey. after more than a decade of lower for longer, the fed is finally normalizing interest rates closer to historical levels.'],
#    'ids': ['index_e5_embeddings:Emerging-Trends_USCanada-2023.pdf-!13',
#     'index_e5_embeddings:Emerging-Trends_USCanada-2023.pdf-!9']}},
#  {'category': 'SAME_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': "Is it true that the economic growth in China in 2023 is expected to be lower than the historical averages, but the country's recovery is predicted to be on track during the 2023-2025 period, albeit at a slower pace?"},
#   'ideal': {'paragraph': ['economic growth in china in 2023 should be below historical averages,',
#     'during the outlook period, china is expected to recover and follow its growth path but at a slower pace.'],
#    'ids': ['index_e5_embeddings:bouwinvest_international-market-outlook_2023-2025-1.pdf-!12',
#     'index_e5_embeddings:isa-outlook-2023.pdf-!32']}},
#  {'category': 'DIFFERENT_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': "Can it be confirmed that China's anticipated economic expansion in 2023 will be less than its historical norm, but the nation's rebound is forecasted to progress steadily between 2023 and 2025, albeit at a more measured rate?"},
#   'ideal': {'paragraph': ['economic growth in china in 2023 should be below historical averages,',
#     'during the outlook period, china is expected to recover and follow its growth path but at a slower pace.'],
#    'ids': ['index_e5_embeddings:bouwinvest_international-market-outlook_2023-2025-1.pdf-!12',
#     'index_e5_embeddings:isa-outlook-2023.pdf-!32']}},
#  {'category': 'SAME_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': "Is it accurate to say that while the Monetary Authority of Singapore manages monetary policies through the foreign exchange markets, Singapore's economic strength and geopolitical stability are likely to fare slightly better financial conditions than South Korea and Australia?"},
#   'ideal': {'paragraph': ['the monetary authority of singapore manages monetary policies through the foreign exchange markets... financial conditions in singapore are expected to fare slightly better than those of south korea and australia, as singapore benefits from strong investor appetite due to its relative economic strength and geopolitical stability.',
#     "singapore's relative attractiveness to hong kong is expected to increase"],
#    'ids': ['index_e5_embeddings:isa-outlook-2023.pdf-!32',
#     'index_e5_embeddings:isa-outlook-2023.pdf-!36']}},
#  {'category': 'DIFFERENT_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': "Is it fair to claim that despite the Monetary Authority of Singapore directing monetary policies through foreign exchange markets, Singapore's economic resilience and geopolitical equilibrium are predicted to withstand slightly superior financial conditions compared to South Korea and Australia?"},
#   'ideal': {'paragraph': ['the monetary authority of singapore manages monetary policies through the foreign exchange markets... financial conditions in singapore are expected to fare slightly better than those of south korea and australia, as singapore benefits from strong investor appetite due to its relative economic strength and geopolitical stability.',
#     "singapore's relative attractiveness to hong kong is expected to increase... singapores relative attractiveness to hong kong is expec - ted to increase."],
#    'ids': ['index_e5_embeddings:isa-outlook-2023.pdf-!32',
#     'index_e5_embeddings:isa-outlook-2023.pdf-!36']}},
#  {'category': 'SAME_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Is it correct to say that while Japan is facing externally driven challenges, it is expected to maintain stable monetary policies with the Bank of Japan keeping interest rates near zero, thereby ensuring the spread between property yields and the risk-free rate remains intact?'},
#   'ideal': {'paragraph': ['in japan, yield curve control comes at the cost of a weak yen. if the bank of japan ( boj ) remains committed to keeping interest rates near zero, currency intervention, such as yen - buying to prevent further depreciation, could be on the table again... most of the challenges japan is facing are externally driven, while domestic - driven fundamentals remain relatively healthy.',
#     'higher interest rates are a concern for all asia - pacific markets, with the exception of china and japan. japan is keeping a lid on interest rate growth and its benchmark 10 - year government bond rate remains close to zero. the spread between property yields and the risk - free rate is therefore intact.'],
#    'ids': ['index_e5_embeddings:bouwinvest_international-market-outlook_2023-2025-1.pdf-!13']}},
#  {'category': 'DIFFERENT_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Would it be right to state that, despite external pressures, Japan is anticipated to uphold steady monetary policies with the Bank of Japan maintaining interest rates close to zero, ensuring the differential between property yields and the risk-free rate remains constant?'},
#   'ideal': {'paragraph': ['in japan, yield curve control comes at the cost of a weak yen. if the bank of japan ( boj ) remains committed to keeping interest rates near zero, currency intervention, such as yen - buying to prevent further depreciation, could be on the table again... most of the challenges japan is facing are externally driven, while domestic - driven fundamentals remain relatively healthy.',
#     'higher interest rates are a concern for all asia - pacific markets, with the exception of china and japan. japan is keeping a lid on interest rate growth and its benchmark 10 - year government bond rate remains close to zero. the spread between property yields and the risk - free rate is therefore intact.'],
#    'ids': ['index_e5_embeddings:bouwinvest_international-market-outlook_2023-2025-1.pdf-!13']}},
#  {'category': 'SAME_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Is the Bank of Japan committed to keeping interest rates near zero which can make Japan an attractive diversifier for institutional investors?'},
#   'ideal': {'paragraph': ['in japan, yield curve control comes at the cost of a weak yen. if the bank of japan ( boj ) remains committed to keeping interest rates near zero, currency intervention, such as yen - buying to prevent further depreciation, could be on the table again.',
#     'japan remains an attractive diversifier for institutional investors regional and global real estate portfolios, due to the relative resiliency of its occupier and capital market fundamentals, its stable geopolitical environment and divergent monetary policies.'],
#    'ids': ['index_e5_embeddings:isa-outlook-2023.pdf-!42',
#     'index_e5_embeddings:isa-outlook-2023.pdf-!32']}},
#  {'category': 'DIFFERENT_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Is the Bank of Japan devoted to sustaining interest rates close to zero, potentially making Japan an appealing choice for institutional investors? '},
#   'ideal': {'paragraph': ['in japan, yield curve control comes at the cost of a weak yen. if the bank of japan ( boj ) remains committed to keeping interest rates near zero, currency intervention, such as yen - buying to prevent further depreciation, could be on the table again.',
#     'japan remains an attractive diversifier for institutional investors regional and global real estate portfolios, due to the relative resiliency of its occupier and capital market fundamentals, its stable geopolitical environment and divergent monetary policies.'],
#    'ids': ['index_e5_embeddings:isa-outlook-2023.pdf-!42',
#     'index_e5_embeddings:isa-outlook-2023.pdf-!32']}},
#  {'category': 'SAME_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': "Does the Bank of Japan's commitment to keeping interest rates near zero lead to a strong yen?"},
#   'ideal': {'paragraph': ['in japan, yield curve control comes at the cost of a weak yen. if the bank of japan ( boj ) remains committed to keeping interest rates near zero, currency intervention, such as yen - buying to prevent further depreciation, could be on the table again.',
#     'japan remains an attractive diversifier for institutional investors regional and global real estate portfolios, due to the relative resiliency of its occupier and capital market fundamentals, its stable geopolitical environment and divergent monetary policies.'],
#    'ids': ['index_e5_embeddings:isa-outlook-2023.pdf-!42',
#     'index_e5_embeddings:isa-outlook-2023.pdf-!32']}},
#  {'category': 'DIFFERENT_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Does the commitment of the Bank of Japan to maintain near-zero interest rates result in a fortified yen?'},
#   'ideal': {'paragraph': ['in japan, yield curve control comes at the cost of a weak yen. if the bank of japan ( boj ) remains committed to keeping interest rates near zero, currency intervention, such as yen - buying to prevent further depreciation, could be on the table again.',
#     'japan remains an attractive diversifier for institutional investors regional and global real estate portfolios, due to the relative resiliency of its occupier and capital market fundamentals, its stable geopolitical environment and divergent monetary policies.'],
#    'ids': ['index_e5_embeddings:isa-outlook-2023.pdf-!42',
#     'index_e5_embeddings:isa-outlook-2023.pdf-!32']}},
#  {'category': 'SAME_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': "Do Asia Pacific real estate markets, being dominated by domestic and intra-regional capital, signify that higher interest rates are a major concern for Japan's real estate yield spread?"},
#   'ideal': {'paragraph': ['in theory, weak currencies offer attractive discounts for cross - regional investors, but asia pacific real estate capital markets are traditionally dominated by domestic and intra - regional capital. in this cycle, most of these capital sources should remain well - capitalized with little financial pressure to sell.',
#     'australia is cementing its status as a safe haven in the region. singapores relative attractiveness to hong kong is expected to increase. higher interest rates are less of a concern in japan where the spread between the risk - free rate and real estate yields remains stable.'],
#    'ids': ['index_e5_embeddings:isa-outlook-2023.pdf-!35']}},
#  {'category': 'DIFFERENT_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': "With Asia Pacific property markets primarily influenced by domestic and intra-regional capital, does this suggest that escalating interest rates are a significant worry for Japan's property yield spread?"},
#   'ideal': {'paragraph': ['in theory, weak currencies offer attractive discounts for cross - regional investors, but asia pacific real estate capital markets are traditionally dominated by domestic and intra - regional capital. in this cycle, most of these capital sources should remain well - capitalized with little financial pressure to sell.',
#     'australia is cementing its status as a safe haven in the region. singapores relative attractiveness to hong kong is expected to increase. higher interest rates are less of a concern in japan where the spread between the risk - free rate and real estate yields remains stable.'],
#    'ids': ['index_e5_embeddings:isa-outlook-2023.pdf-!35']}},
#  {'category': 'SAME_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Given the stable risk-free rate and real estate yields in Japan and domestic capital dominance in the Asia Pacific region, is Australia seen as a safe haven in the region?'},
#   'ideal': {'paragraph': ['in theory, weak currencies offer attractive discounts for cross - regional investors, but asia pacific real estate capital markets are traditionally dominated by domestic and intra - regional capital. in this cycle, most of these capital sources should remain well - capitalized with little financial pressure to sell.',
#     'australia is cementing its status as a safe haven in the region. singapores relative attractiveness to hong kong is expected to increase. higher interest rates are less of a concern in japan where the spread between the risk - free rate and real estate yields remains stable.'],
#    'ids': ['index_e5_embeddings:isa-outlook-2023.pdf-!35']}},
#  {'category': 'DIFFERENT_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'In view of the constant risk-free rate and property yields in Japan and the prevalence of domestic capital in the Asia Pacific, is Australia considered a safe harbor in the region?'},
#   'ideal': {'paragraph': ['in theory, weak currencies offer attractive discounts for cross - regional investors, but asia pacific real estate capital markets are traditionally dominated by domestic and intra - regional capital. in this cycle, most of these capital sources should remain well - capitalized with little financial pressure to sell.',
#     'australia is cementing its status as a safe haven in the region. singapores relative attractiveness to hong kong is expected to increase. higher interest rates are less of a concern in japan where the spread between the risk - free rate and real estate yields remains stable.'],
#    'ids': ['index_e5_embeddings:isa-outlook-2023.pdf-!35']}},
#  {'category': 'SAME_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Are interest rates expected to continue rising indefinitely, impacting real estate values?'},
#   'ideal': {'paragraph': ['inflation should eventually settle closer to central banks target levels, allowing the longed - for pivot in interest rates.',
#     'the relentless math of higher interest rates will continue to weigh heavily on real estate values, at least until interest rates stabilize as inflation begins to subside.'],
#    'ids': ['index_e5_embeddings:isa-outlook-2023.pdf-!9']}},
#  {'category': 'DIFFERENT_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Are interest rates projected to persistently climb, detrimentally affecting property values?'},
#   'ideal': {'paragraph': ['inflation should eventually settle closer to central banks target levels, allowing the longed - for pivot in interest rates.',
#     'the relentless math of higher interest rates will continue to weigh heavily on real estate values, at least until interest rates stabilize as inflation begins to subside.'],
#    'ids': ['index_e5_embeddings:isa-outlook-2023.pdf-!9']}},
#  {'category': 'SAME_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Can we conclude that the denominator effect is expected to force all institutional investors to sell their real estate assets?'},
#   'ideal': {'paragraph': ['and while interest rates are increasing, equity and bond prices have been falling, triggering the denominator effect for some institutional investors with asset allocations that must remain in balance.',
#     'denominator effects and higher borrowing costs will keep a meaningful fraction of core and higher return buyers on the sidelines, especially at the start of 2023.'],
#    'ids': ['index_e5_embeddings:Emerging-Trends_USCanada-2023.pdf-!22']}},
#  {'category': 'DIFFERENT_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Is it reasonable to expect the denominator effect to compel all institutional investors to offload their real estate holdings? '},
#   'ideal': {'paragraph': ['and while interest rates are increasing, equity and bond prices have been falling, triggering the denominator effect for some institutional investors with asset allocations that must remain in balance.',
#     'denominator effects and higher borrowing costs will keep a meaningful fraction of core and higher return buyers on the sidelines, especially at the start of 2023.'],
#    'ids': ['index_e5_embeddings:Emerging-Trends_USCanada-2023.pdf-!22']}},
#  {'category': 'SAME_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Can we infer that higher debt costs are the only determinant of real estate valuations?'},
#   'ideal': {'paragraph': ['ultimately, however, valuations are the result of the interaction between higher debt costs and the path of real estate fundamentals, the prospects for which vary widely across sectors and geographies.',
#     'with the normalisation of monetary policy that has now begun, this situation should dissolve and the rise in real estate yields should be flatter than that of the risk - free interest rate.'],
#    'ids': ['index_e5_embeddings:isa-outlook-2023.pdf-!15']}},
#  {'category': 'DIFFERENT_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Can we deduce that escalating debt expenses are the sole factor influencing property evaluations?'},
#   'ideal': {'paragraph': ['ultimately, however, valuations are the result of the interaction between higher debt costs and the path of real estate fundamentals, the prospects for which vary widely across sectors and geographies.',
#     'with the normalisation of monetary policy that has now begun, this situation should dissolve and the rise in real estate yields should be flatter than that of the risk - free interest rate.'],
#    'ids': ['index_e5_embeddings:isa-outlook-2023.pdf-!15']}},
#  {'category': 'SAME_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Will the increase in interest rates cease to impact real estate values as soon as inflation begins to decrease?'},
#   'ideal': {'paragraph': ['says the regional leader of one global firm, cap rates have gapped out as interest rates went up. and suddenly, things didnt pencil, and that generated broken deals. the cost of financing for real estate and everything else went up dramatically.',
#     'the relentless math of higher interest rates will continue to weigh heavily on real estate values, at least until interest rates stabilize as inflation begins to subside.'],
#    'ids': ['index_e5_embeddings:Emerging-Trends_USCanada-2023.pdf-!22']}},
#  {'category': 'DIFFERENT_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Will the escalation in interest rates stop influencing property values as soon as deflation initiates?'},
#   'ideal': {'paragraph': ['says the regional leader of one global firm, cap rates have gapped out as interest rates went up. and suddenly, things didnt pencil, and that generated broken deals. the cost of financing for real estate and everything else went up dramatically.',
#     'the relentless math of higher interest rates will continue to weigh heavily on real estate values, at least until interest rates stabilize as inflation begins to subside.'],
#    'ids': ['index_e5_embeddings:Emerging-Trends_USCanada-2023.pdf-!22']}},
#  {'category': 'SAME_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Does the current economic robustness in the US, Canada, and Singapore likely support a pivot in interest rates, assuming inflation settles closer to the target levels of central banks?'},
#   'ideal': {'paragraph': ['inflation should eventually settle closer to central banks target levels, allowing the longed - for pivot in interest rates.',
#     'the dominant driver of inflation in the us, canada and singapore is that their economies are robust and operating close to full capacity.'],
#    'ids': ['index_e5_embeddings:isa-outlook-2023.pdf-!9',
#     'index_e5_embeddings:isa-outlook-2023.pdf-!16']}},
#  {'category': 'DIFFERENT_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Is the current economic resilience in the US, Canada, and Singapore likely to foster a shift in interest rates, assuming inflation steadies closer to the benchmark levels set by central banks?'},
#   'ideal': {'paragraph': ['inflation should eventually settle closer to central banks target levels, allowing the longed - for pivot in interest rates.',
#     'the dominant driver of inflation in the us, canada and singapore is that their economies are robust and operating close to full capacity.'],
#    'ids': ['index_e5_embeddings:isa-outlook-2023.pdf-!9',
#     'index_e5_embeddings:isa-outlook-2023.pdf-!16']}},
#  {'category': 'SAME_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Can we infer that all-cash buyers gained more prominence in the market during the end of 2022 due to the higher borrowing costs and prime yields being below the cost of debt capital?'},
#   'ideal': {'paragraph': ['at the end of the third quarter of 2022, prime yields in all major market segments were below the cost of debt capital.',
#     "this is one of those cash is king situations where borrowing costs are higher, and if you're an all - cash buyer, those probably represent a disproportionate share of the people in the market today."],
#    'ids': ['index_e5_embeddings:outlook-real-estatet-market-germany-dec-2022.pdf-!11']}},
#  {'category': 'DIFFERENT_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Can we deduce that purchasers paying in cash came to the fore in the market towards the end of 2022 due to the escalating borrowing expenses and prime yields being beneath the cost of debt capital?'},
#   'ideal': {'paragraph': ['at the end of the third quarter of 2022, prime yields in all major market segments were below the cost of debt capital.',
#     "this is one of those cash is king situations where borrowing costs are higher, and if you're an all - cash buyer, those probably represent a disproportionate share of the people in the market today."],
#    'ids': ['index_e5_embeddings:outlook-real-estatet-market-germany-dec-2022.pdf-!11']}},
#  {'category': 'SAME_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Can we say that the concern about how long the Fed will keep raising rates is justified considering that these rising rates could negatively impact real estate values?'},
#   'ideal': {'paragraph': ['the fundamental issue for many investors is how long the fed will keep raising rates.',
#     'the relentless math of higher interest rates will continue to weigh heavily on real estate values, at least until interest rates stabilize as inflation begins to subside.'],
#    'ids': ['index_e5_embeddings:Emerging-Trends_USCanada-2023.pdf-!24']}},
#  {'category': 'DIFFERENT_WORDING_MULTIPLE_PARAGRAPHS',
#   'input': {'question': 'Is the apprehension about the duration the Fed will continue escalating rates valid, given that these rising rates could adversely affect property values? '},
#   'ideal': {'paragraph': ['the fundamental issue for many investors is how long the fed will keep raising rates.',
#     'the relentless math of higher interest rates will continue to weigh heavily on real estate values, at least until interest rates stabilize as inflation begins to subside.'],
#    'ids': ['index_e5_embeddings:Emerging-Trends_USCanada-2023.pdf-!24']}},
#  {'category': 'SAME_WORDING_MULTIPLE_PARAGRAPHS',
# ...
#   'ideal': {'paragraph': ['most recently, though, they have been beat - en by cologne with a figure of 2. 8 per cent.'],
#    'ids': ['index_e5_embeddings:2022-09-21_Immobilienmarkt_Deutschland_2022_2023_EN.pdf-!45']}},
#  {'category': 'SAME_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'What was take-up in Q2 2022?'},
#   'ideal': {'paragraph': ['take - up in q2 2022 rose to over 1 mil - lion m2 a figure only exceeded seven times in the 50 quarters since 2010.'],
#    'ids': ['index_e5_embeddings:2022-09-21_Immobilienmarkt_Deutschland_2022_2023_EN.pdf-!45']}},
#  {'category': 'DIFFERENT_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'What was the volume of absorption in the second quarter of 2022?'},
#   'ideal': {'paragraph': ['take - up in q2 2022 rose to over 1 mil - lion m2 a figure only exceeded seven times in the 50 quarters since 2010.'],
#    'ids': ['index_e5_embeddings:2022-09-21_Immobilienmarkt_Deutschland_2022_2023_EN.pdf-!45']}},
#  {'category': 'SAME_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'How many of the 10 highest-rated markets last year repeated this year?'},
#   'ideal': {'paragraph': ['many of the changes were relatively minor, and nine of the 10 highest - rated markets last year repeated this year.'],
#    'ids': ['index_e5_embeddings:Emerging-Trends_USCanada-2023.pdf-!136']}},
#  {'category': 'DIFFERENT_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'How many of the top 10 markets from the previous year retained their position this year?'},
#   'ideal': {'paragraph': ['many of the changes were relatively minor, and nine of the 10 highest - rated markets last year repeated this year.'],
#    'ids': ['index_e5_embeddings:Emerging-Trends_USCanada-2023.pdf-!136']}},
#  {'category': 'SAME_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'How many markets moved up or down in rankings by at least 10 places?'},
#   'ideal': {'paragraph': ['but there were some material changes over the year as about a quarter of markets moved up or down in rankings by at least 10 places.'],
#    'ids': ['index_e5_embeddings:Emerging-Trends_USCanada-2023.pdf-!136']}},
#  {'category': 'DIFFERENT_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'How many markets experienced a rise or fall of at least 10 spots in the rankings?'},
#   'ideal': {'paragraph': ['but there were some material changes over the year as about a quarter of markets moved up or down in rankings by at least 10 places.'],
#    'ids': ['index_e5_embeddings:Emerging-Trends_USCanada-2023.pdf-!136']}},
#  {'category': 'SAME_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'How many of the 20-highest rated markets in last years survey fell in the rankings this year?'},
#   'ideal': {'paragraph': ['more than half ( 11 ) of the 20 - highest rated markets in last years survey fell in the rankings this year, although almost all by less than 10 places.'],
#    'ids': ['index_e5_embeddings:Emerging-Trends_USCanada-2023.pdf-!136']}},
#  {'category': 'DIFFERENT_WORDING_ONE_PARAGRAPH',
#   'input': {'question': "How many of the top 20 markets from the previous year's survey saw a decrease in their rankings this year?"},
#   'ideal': {'paragraph': ['more than half ( 11 ) of the 20 - highest rated markets in last years survey fell in the rankings this year, although almost all by less than 10 places.'],
#    'ids': ['index_e5_embeddings:Emerging-Trends_USCanada-2023.pdf-!136']}},
#  {'category': 'SAME_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'How many of the 20-lowest rated markets in last years survey rose in the rankings this year?'},
#   'ideal': {'paragraph': ['thirteen of the 20 - lowest rated markets in last years survey rose in the rankings this year.'],
#    'ids': ['index_e5_embeddings:Emerging-Trends_USCanada-2023.pdf-!136']}},
#  {'category': 'DIFFERENT_WORDING_ONE_PARAGRAPH',
#   'input': {'question': "How many of the 20 lowest-ranked markets from the previous year's survey experienced an increase in rankings this year?"},
#   'ideal': {'paragraph': ['thirteen of the 20 - lowest rated markets in last years survey rose in the rankings this year.'],
#    'ids': ['index_e5_embeddings:Emerging-Trends_USCanada-2023.pdf-!136']}},
#  {'category': 'SAME_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'How many Sun Belt markets were among the top 20 markets for overall prospects in 2011?'},
#   'ideal': {'paragraph': ['the number of sun belt markets among the top 20 markets for overall prospects has increased from 10 in 2011 to 14 in each of the past two years.'],
#    'ids': ['index_e5_embeddings:Emerging-Trends_USCanada-2023.pdf-!136']}},
#  {'category': 'DIFFERENT_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'How many Sun Belt markets were in the top 20 overall prospects in 2011?'},
#   'ideal': {'paragraph': ['the number of sun belt markets among the top 20 markets for overall prospects has increased from 10 in 2011 to 14 in each of the past two years.'],
#    'ids': ['index_e5_embeddings:Emerging-Trends_USCanada-2023.pdf-!136']}},
#  {'category': 'SAME_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'What effect did property values have in midyear 2022?'},
#   'ideal': {'paragraph': ['property values dropped 10 to 20 percent as of midyear 2022'],
#    'ids': ['index_e5_embeddings:Emerging-Trends_USCanada-2023.pdf-!117']}},
#  {'category': 'DIFFERENT_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'How did property values behave in the middle of 2022?'},
#   'ideal': {'paragraph': ['property values dropped 10 to 20 percent as of midyear 2022'],
#    'ids': ['index_e5_embeddings:Emerging-Trends_USCanada-2023.pdf-!117']}},
#  {'category': 'SAME_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'What is the average size of a metro area in the Supernova category?'},
#   'ideal': {'paragraph': ['like the astronomic source for its name, the five metro areas in the supernova category markets have exploded into prominence over the past decade or so. all are smaller markets with 1 million to 2 million residents, but their defining attribute is their tremendous and sustained population and job growth, which are well above national averages.'],
#    'ids': ['index_e5_embeddings:Emerging-Trends_USCanada-2023.pdf-!142']}},
#  {'category': 'DIFFERENT_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'What is the typical population of a metropolitan area classified under the Supernova category?'},
#   'ideal': {'paragraph': ['like the astronomic source for its name, the five metro areas in the supernova category markets have exploded into prominence over the past decade or so. all are smaller markets with 1 million to 2 million residents, but their defining attribute is their tremendous and sustained population and job growth, which are well above national averages.'],
#    'ids': ['index_e5_embeddings:Emerging-Trends_USCanada-2023.pdf-!142']}},
#  {'category': 'SAME_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'What is the rate of the 18-Hour Cities in terms of economic output among the 12 subgroups?'},
#   'ideal': {'paragraph': ['as a group, the 18 - hour cities rate third highest among the 12 subgroups, though the average market ranking fell this year as four of the markets declined while three rose.'],
#    'ids': ['index_e5_embeddings:Emerging-Trends_USCanada-2023.pdf-!142']}},
#  {'category': 'DIFFERENT_WORDING_ONE_PARAGRAPH',
#   'input': {'question': "What's the economic output ranking of the 18-Hour Cities among the 12 subgroups?"},
#   'ideal': {'paragraph': ['as a group, the 18 - hour cities rate third highest among the 12 subgroups, though the average market ranking fell this year as four of the markets declined while three rose.'],
#    'ids': ['index_e5_embeddings:Emerging-Trends_USCanada-2023.pdf-!142']}},
#  {'category': 'SAME_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'What is the trend of tourist numbers?'},
#   'ideal': {'paragraph': ['tourist numbers almost back to 2019 levels'],
#    'ids': ['index_e5_embeddings:2022-09-21_Immobilienmarkt_Deutschland_2022_2023_EN.pdf-!28']}},
#  {'category': 'DIFFERENT_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'How are tourist numbers moving?'},
#   'ideal': {'paragraph': ['tourist numbers almost back to 2019 levels'],
#    'ids': ['index_e5_embeddings:2022-09-21_Immobilienmarkt_Deutschland_2022_2023_EN.pdf-!28']}},
#  {'category': 'SAME_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'What is the average monthly disposable income per household in Euro?'},
#   'ideal': {'paragraph': ['average monthly disposable income per household : eur 3, 726 euro'],
#    'ids': ['index_e5_embeddings:2022-09-21_Immobilienmarkt_Deutschland_2022_2023_EN.pdf-!21']}},
#  {'category': 'DIFFERENT_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'What is the typical sum of money each household can expend monthly in the Eurozone?'},
#   'ideal': {'paragraph': ['average monthly disposable income per household : eur 3, 726 euro'],
#    'ids': ['index_e5_embeddings:2022-09-21_Immobilienmarkt_Deutschland_2022_2023_EN.pdf-!21']}},
#  {'category': 'SAME_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'How has consumer sentiment been impacted by the war in Ukraine, inflation and the gas crisis?'},
#   'ideal': {'paragraph': ['the war in ukraine, inflation and the gas crisis are key concerns for people. this is reflected in consumer sentiment which has fallen to a historic low.'],
#    'ids': ['index_e5_embeddings:2022-09-21_Immobilienmarkt_Deutschland_2022_2023_EN.pdf-!21']}},
#  {'category': 'DIFFERENT_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'How did the Ukraine war, inflation and gas crisis affect consumer mood?'},
#   'ideal': {'paragraph': ['the war in ukraine, inflation and the gas crisis are key concerns for people. this is reflected in consumer sentiment which has fallen to a historic low.'],
#    'ids': ['index_e5_embeddings:2022-09-21_Immobilienmarkt_Deutschland_2022_2023_EN.pdf-!21']}},
#  {'category': 'SAME_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'When did new home prices peak?'},
#   'ideal': {'paragraph': ['new home prices peaked in april 2022, while prices of existing homes likely peaked in june after appreciation started to slow with the rise in mortgage rates.'],
#    'ids': ['index_e5_embeddings:Emerging-Trends_USCanada-2023.pdf-!10']}},
#  {'category': 'DIFFERENT_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'In which month did new home prices reach their highest point?'},
#   'ideal': {'paragraph': ['new home prices peaked in april 2022, while prices of existing homes likely peaked in june after appreciation started to slow with the rise in mortgage rates.'],
#    'ids': ['index_e5_embeddings:Emerging-Trends_USCanada-2023.pdf-!10']}},
#  {'category': 'SAME_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'What is the phone number of DZ HYP AG?'},
#   'ideal': {'paragraph': ['dz hyp ag rosenstrasse 2 20095 hamburg germany phone 49 40 3334 - 0 dzhyp.'],
#    'ids': ['index_e5_embeddings:2022-09-21_Immobilienmarkt_Deutschland_2022_2023_EN.pdf-!83']}},
#  {'category': 'DIFFERENT_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'What is the contact number for DZ HYP AG?'},
#   'ideal': {'paragraph': ['dz hyp ag rosenstrasse 2 20095 hamburg germany phone 49 40 3334 - 0 dzhyp.'],
#    'ids': ['index_e5_embeddings:2022-09-21_Immobilienmarkt_Deutschland_2022_2023_EN.pdf-!83']}},
#  {'category': 'SAME_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'How much does the U.S. apartment property sector contribute annually to the U.S. economy according to the NMHC?'},
#   'ideal': {'paragraph': ['the u. s. apartment property sectorproviding shelter to 37 mil - lion residents in 21. 3 million structures of five or more household units, and contributing $ 3. 4 trillion annually to the u. s. economy, according to the nmhc'],
#    'ids': ['index_e5_embeddings:Emerging-Trends_USCanada-2023.pdf-!76']}},
#  {'category': 'DIFFERENT_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'What annual contribution does the U.S. apartment property sector make to the U.S. economy as per the NMHC?'},
#   'ideal': {'paragraph': ['the u. s. apartment property sectorproviding shelter to 37 mil - lion residents in 21. 3 million structures of five or more household units, and contributing $ 3. 4 trillion annually to the u. s. economy, according to the nmhc'],
#    'ids': ['index_e5_embeddings:Emerging-Trends_USCanada-2023.pdf-!76']}},
#  {'category': 'SAME_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'How much higher was the number of new units authorized in multifamily buildings over the past 12 months as of June 2022 compared to the same period in 2018-2019, as per a Bloomberg report?'},
#   'ideal': {'paragraph': ['according to a recent bloomberg report, after dipping in 2020, the number of new units authorized in multifamily build - ings took off, running 37 percent higher over the past 12 months as of june 2022 than in the same period in 20182019.'],
#    'ids': ['index_e5_embeddings:Emerging-Trends_USCanada-2023.pdf-!77']}},
#  {'category': 'DIFFERENT_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'By what percentage was the authorization of new units in multifamily buildings higher over the last 12 months up to June 2022, in comparison with the same period in 2018-2019, according to a Bloomberg report?'},
#   'ideal': {'paragraph': ['according to a recent bloomberg report, after dipping in 2020, the number of new units authorized in multifamily build - ings took off, running 37 percent higher over the past 12 months as of june 2022 than in the same period in 20182019.'],
#    'ids': ['index_e5_embeddings:Emerging-Trends_USCanada-2023.pdf-!77']}},
#  {'category': 'SAME_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'What percentage increase in apartments under construction was observed as of August, compared to a year ago?'},
#   'ideal': {'paragraph': ['as of august, 862, 000 apartments were under construction, up 25 percent from a year ago.'],
#    'ids': ['index_e5_embeddings:Emerging-Trends_USCanada-2023.pdf-!77']}},
#  {'category': 'DIFFERENT_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'What was the year-on-year growth rate in apartments under construction as of August?'},
#   'ideal': {'paragraph': ['as of august, 862, 000 apartments were under construction, up 25 percent from a year ago.'],
#    'ids': ['index_e5_embeddings:Emerging-Trends_USCanada-2023.pdf-!77']}},
#  {'category': 'SAME_WORDING_ONE_PARAGRAPH',
#   'input': {'question': "What percentage increase did renters making at least $75,000 see over the decade ending just before the pandemic, according to Harvard's Joint Center for Housing Studies (JCHS)?"},
#   'ideal': {'paragraph': ['according to harvards joint center for housing studies ( jchs ), the number of renters making at least $ 75, 000 jumped by 48 percent over the decade ending just before the pandemic, to 11. 3 million.'],
#    'ids': ['index_e5_embeddings:Emerging-Trends_USCanada-2023.pdf-!78']}},
#  {'category': 'DIFFERENT_WORDING_ONE_PARAGRAPH',
#   'input': {'question': "By what percentage did the number of renters earning at least $75,000 increase over the decade ending just before the pandemic, as per the Harvard's Joint Center for Housing Studies (JCHS)?"},
#   'ideal': {'paragraph': ['according to harvards joint center for housing studies ( jchs ), the number of renters making at least $ 75, 000 jumped by 48 percent over the decade ending just before the pandemic, to 11. 3 million.'],
#    'ids': ['index_e5_embeddings:Emerging-Trends_USCanada-2023.pdf-!78']}},
#  {'category': 'SAME_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'Who is Jeff Smith?'},
#   'ideal': {'paragraph': ['jeff smith is deloittes national real estate leader with nearly 30 years of audit and accounting experience.'],
#    'ids': ['index_e5_embeddings:Deloitte 2023 Commercial Real Estate Outlook.pdf-!35']}},
#  {'category': 'DIFFERENT_WORDING_ONE_PARAGRAPH',
#   'input': {'question': 'In what capacity does Jeff Smith serve?'},
#   'ideal': {'paragraph': ['jeff smith is deloittes national real estate leader with nearly 30 years of audit and accounting experience.'],
#    'ids': ['index_e5_embeddings:Deloitte 2023 Commercial Real Estate Outlook.pdf-!35']}}]

# %%
import jsonlines
import datetime
with jsonlines.open(f"retriever_dataset_e5_{datetime.datetime.now().strftime('%Y%m%d')}.jsonl", "w") as writer:
    writer.write_all(retriever_rows)

# %%
import json
import blobfile as bf
import pandas as pd

chunk_df = pd.read_csv('redis-test/index_300t_chunks.csv')
chunk_df.rename(columns={"text_chunk": "text"}, inplace=True)
dataset = json.load(bf.BlobFile("all_dataset_final.json", "rb"))
# print every question answer pair except for the NOT_SOURCE_BASED category
for i, datapoint in enumerate(dataset):
    if datapoint["category"] == "NOT_SOURCE_BASED":
        continue
    if len(datapoint["sentences"]) > 0:
        datapoint["t_250c_paragraph"] = []
        for sentence in datapoint["sentences"]:
            row = chunk_df.loc[(chunk_df['text'].str.contains(sentence))]
            row = row.to_dict(orient='records')
            if len(row) > 0:
                datapoint["t_250c_paragraph"].append(row[0])



with open("all_dataset_t_200c.json", "w") as f:
    json.dump(dataset, f)
# Out:
# /var/folders/fl/tm4fc_cn093f_bh634c4z63r0000gq/T/ipykernel_28793/545668187.py:15: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   row = chunk_df.loc[(chunk_df['text'].str.contains(sentence))]

# %%
dataset = json.load(bf.BlobFile("all_dataset_t_200c.json", "rb"))

retriever_rows = []
for datapoint in dataset:
    if datapoint["category"] == "NOT_SOURCE_BASED":
        continue
    row = {
        "category": datapoint["category"],
        "input": {
            "question": datapoint["question"],
        },
        "ideal": {
            "paragraph": datapoint["sentences"] if "sentences" and len(datapoint["sentences"]) > 0 else [paragraph["text"] for paragraph in datapoint["t_250c_paragraph"]],
            "filename": list(set(paragraph["filename"] for paragraph in datapoint["paragraph"])),
            "ids": list(set(paragraph["id"] for paragraph in datapoint["t_250c_paragraph"])),
        }
    }
    retriever_rows.append(row)

# %%
import jsonlines
import datetime
with jsonlines.open(f"retriever_dataset_t_250c_{datetime.datetime.now().strftime('%Y%m%d')}.jsonl", "w") as writer:
    writer.write_all(retriever_rows)
